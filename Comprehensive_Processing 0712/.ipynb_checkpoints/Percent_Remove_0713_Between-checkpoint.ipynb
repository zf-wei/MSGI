# %%
# %%time
import warnings

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
# Out:
# CPU times: user 42 µs, sys: 20 µs, total: 62 µs
# Wall time: 66 µs

# %%
# %%time
### 生成输出目录的模块
import os
from datetime import datetime

def generate_output(random_disturb: bool, filename):
    slurm_job_id = os.environ.get('SLURM_JOB_ID')
    # Generate the folder name with the current date
    now = datetime.now()
    if random_disturb:
        folder_name = f"{slurm_job_id}_Graph_Rmv_Stoch_{now.strftime('%Y-%m-%d-%H-%M')}"
    else:
        folder_name = f"{slurm_job_id}_Graph_Rmv_Btwn_{now.strftime('%Y-%m-%d-%H-%M')}"

    # Create the output directory if it doesn't exist
    output_dir = os.path.join(os.getcwd(), folder_name)
    os.makedirs(output_dir, exist_ok=True)

    # Construct the full file path
    file_path = os.path.join(output_dir, filename)

    return file_path
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 6.68 µs

# %%
# %%time
### 生成删除顶点的顺序 模块
import random
import networkx as nx
import numpy as np

def nodes_sample(random_disturb: bool, graph, number_of_nodes: int, percent, betweenness):
    graph_copy = graph.copy()
    sample_size = int(number_of_nodes * percent)
    if random_disturb:
        removed_nodes = random.sample(range(number_of_nodes), sample_size)
        graph_copy.remove_nodes_from(removed_nodes)
        if nx.is_connected(graph_copy):
            return removed_nodes
    else: 
        removed_nodes = random.choices(range(number_of_nodes), betweenness, k=sample_size)
        graph_copy.remove_nodes_from(removed_nodes)
        if nx.is_connected(graph_copy):
            return removed_nodes
        

import numpy as np
import json

def generate_remove_list(random_disturb: bool, graph, number_of_nodes, betweenness):
    remove_procedure = []
    for percent in np.arange(0.05, 0.86, 0.05):
        ls = []
        while len(ls) < 2:
            temp = nodes_sample(random_disturb=random_disturb, graph=graph, number_of_nodes=number_of_nodes, percent=percent, betweenness=betweenness)
            if temp is not None:
                ls.append(temp)
        remove_procedure.append(ls)
    filename = generate_output(random_disturb, "0Remove_Procedure.txt")
    with open(filename, 'w') as file:
        json.dump(remove_procedure, file)
    return remove_procedure


import numpy as np

def remove_procedure_index(remove_procedure, num_nodes):
    index = []
    for sublist_list in remove_procedure:
        sublist_index = []
        for sublist in sublist_list:
            temp = np.ones(num_nodes, dtype=bool)
            temp[sublist] = False
            sublist_index.append(temp)
        index.append(sublist_index)
    return index
# Out:
# CPU times: user 1.71 s, sys: 7 s, total: 8.71 s
# Wall time: 591 ms

# %%
# %%time

import csv

def save_scores_to_csv(random_disturb: bool, scores, filename):
    """
    Saves a list of list of list to a CSV file with a double space separator.

    Args:
        scores (list): The list of list of list to be saved.
        disturb (bool): A boolean indicating if disturbance is present.
        filename (str): The name of the output CSV file.
    """
    # Construct the full file path
    file_path = generate_output(random_disturb, filename + ".csv")

    with open(file_path, 'a', newline='') as file:
        writer = csv.writer(file, delimiter=' ')
        for line in scores:
            writer.writerow(line)
            file.write('\n')
        file.write('----------------------------------------\n')
# Out:
# CPU times: user 1.72 ms, sys: 0 ns, total: 1.72 ms
# Wall time: 2.1 ms

# %%
# %%time
import os
import csv
from datetime import date

def save_to_csv(random_disturb: bool, content, filename):
    """
    Saves a list of 4-lists to a CSV file with a double space separator.
    
    Args:
        scores (list): The list of 4-lists to be saved.
        filename (str): The name of the output CSV file.
    """
    # Construct the full file path
    file_path = generate_output(random_disturb, filename+".csv")

    with open(file_path, 'w', newline='') as file:
        writer = csv.writer(file, delimiter=' ')
        for content_list in content:
            writer.writerow(content_list)
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 9.3 µs

# %%
# %%time
def Plot_Separate(output:bool, random_disturb:bool, MEAN, STD, filename):
    # Generate x-coordinates for the data points with a step size of 0.05
    x_values = np.arange(0.05, 0.86, 0.05)

    # Create a figure with four subplots
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, sharex=True)

    # Plot the lines for columns 1 in the first subplot
    ax1.plot(x_values, [MEAN[i][0] for i in range(len(MEAN))], label='Eucl & NMI', color='tab:red')
    ax1.fill_between(x_values, np.subtract([MEAN[i][0] for i in range(len(MEAN))], [STD[i][0] for i in range(len(STD))]),
                     np.add([MEAN[i][0] for i in range(len(MEAN))], [STD[i][0] for i in range(len(STD))]), alpha=0.2, color='tab:red')
    ax1.set_ylabel('NMI')
    ax1.legend()

    # Plot the lines for columns 2 in the second subplot
    ax2.plot(x_values, [MEAN[i][1] for i in range(len(MEAN))], label='Cosn & NMI', color='tab:green')
    ax2.fill_between(x_values, np.subtract([MEAN[i][1] for i in range(len(MEAN))], [STD[i][1] for i in range(len(STD))]),
                     np.add([MEAN[i][1] for i in range(len(MEAN))], [STD[i][1] for i in range(len(STD))]), alpha=0.2, color='tab:green')
    ax2.set_ylabel('NMI')
    ax2.legend()

    # Plot the lines for columns 3 in the third subplot
    ax3.plot(x_values, [MEAN[i][2] for i in range(len(MEAN))], label='Eucl & ECSim', color='tab:blue')
    ax3.fill_between(x_values, np.subtract([MEAN[i][2] for i in range(len(MEAN))], [STD[i][2] for i in range(len(STD))]),
                     np.add([MEAN[i][2] for i in range(len(MEAN))], [STD[i][2] for i in range(len(STD))]), alpha=0.2, color='tab:blue')
    ax3.set_ylabel('ECSim')
    ax3.legend()
    
    # Plot the lines for columns 4 in the fourth subplot
    ax4.plot(x_values, [MEAN[i][3] for i in range(len(MEAN))], label='Cosn & ECSim', color='tab:orange')
    ax4.fill_between(x_values, np.subtract([MEAN[i][3] for i in range(len(MEAN))], [STD[i][3] for i in range(len(STD))]),
                     np.add([MEAN[i][3] for i in range(len(MEAN))], [STD[i][3] for i in range(len(STD))]), alpha=0.2, color='tab:orange')
    ax4.set_xlabel('Percentage of Nodes Removed')
    ax4.set_ylabel('ECSim')

    # Remove the legend for "Column 4" in the fourth subplot
    #ax4.legend(handles=ax4.lines[:-1])

    # Set the x-axis scale
    plt.xticks(np.arange(0.0, 0.9, 0.05))

    # Automatically determine the lower bound for the y-axis
    y_min = min([min(y) for y in MEAN])
    y_max = max([max(y) for y in MEAN])
    y_range = y_max - y_min
    y_offset = y_range * 0.1  # Adjust the offset as needed
    y_lower = y_min - y_offset - 0.01
    y_upper = 1.02
    ax1.set_ylim(y_lower, y_upper)
    ax2.set_ylim(y_lower, y_upper)
    ax3.set_ylim(y_lower, y_upper)
    ax4.set_ylim(y_lower, y_upper)

    # Set the y-axis tick marks
    y_tick_step = 0.025
    y_ticks = np.arange(np.ceil(y_lower * 10) / 10, y_upper + 0.5*y_tick_step, y_tick_step)
    # Add horizontal reference lines
    for y in y_ticks:
        ax1.axhline(y=y, color='gray', linestyle='--', alpha=0.3)
        ax2.axhline(y=y, color='gray', linestyle='--', alpha=0.3)
        ax3.axhline(y=y, color='gray', linestyle='--', alpha=0.3)
        ax4.axhline(y=y, color='gray', linestyle='--', alpha=0.3)

    ax1.set_yticks(y_ticks)
    ax2.set_yticks(y_ticks)
    ax3.set_yticks(y_ticks)
    ax4.set_yticks(y_ticks)

    # Adjust the figure size
    fig.set_size_inches(10, 20)  # Increase the height of the figure
    fig.suptitle('Separate Plots',y=0.92)
    
    if output:
        filename = filename+"_SEPARATE"

        file_path = generate_output(random_disturb, filename+".png")
        plt.savefig(file_path)    

    # Show the plot
    plt.show()
# Out:
# CPU times: user 1 µs, sys: 2 µs, total: 3 µs
# Wall time: 5.72 µs

# %%
# %%time
import numpy as np
import matplotlib.pyplot as plt

def Plot_Combine(output:bool, random_disturb:bool, MEAN, STD, filename):
    # Generate x-coordinates for the data points with a step size of 0.05
    x_values = np.arange(0.05, 0.86, 0.05)

    # Create a figure with two subplots
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)

    # Plot the lines for columns 1 and 3 in the first subplot
    ax1.plot(x_values, [MEAN[i][0] for i in range(len(MEAN))], label='Eucl & NMI', color='tab:red')
    ax1.plot(x_values, [MEAN[i][2] for i in range(len(MEAN))], label='Eucl & ECSim', color='tab:blue')
    ax1.fill_between(x_values, np.subtract([MEAN[i][0] for i in range(len(MEAN))], [STD[i][0] for i in range(len(STD))]),
                     np.add([MEAN[i][0] for i in range(len(MEAN))], [STD[i][0] for i in range(len(STD))]), alpha=0.2, color='tab:red')
    ax1.fill_between(x_values, np.subtract([MEAN[i][2] for i in range(len(MEAN))], [STD[i][2] for i in range(len(STD))]),
                     np.add([MEAN[i][2] for i in range(len(MEAN))], [STD[i][2] for i in range(len(STD))]), alpha=0.2, color='tab:blue')
    ax1.set_ylabel('NMI&ECSim')
    ax1.legend()

    # Plot the lines for columns 2 and 4 in the second subplot
    ax2.plot(x_values, [MEAN[i][1] for i in range(len(MEAN))], label='Cosn & NMI', color='tab:green')
    ax2.plot(x_values, [MEAN[i][3] for i in range(len(MEAN))], label='Cosn & ECSim', color='tab:orange')
    ax2.fill_between(x_values, np.subtract([MEAN[i][1] for i in range(len(MEAN))], [STD[i][1] for i in range(len(STD))]),
                     np.add([MEAN[i][1] for i in range(len(MEAN))], [STD[i][1] for i in range(len(STD))]), alpha=0.2, color='tab:green')
    ax2.fill_between(x_values, np.subtract([MEAN[i][3] for i in range(len(MEAN))], [STD[i][3] for i in range(len(STD))]),
                     np.add([MEAN[i][3] for i in range(len(MEAN))], [STD[i][3] for i in range(len(STD))]), alpha=0.2, color='tab:orange')
    ax2.set_xlabel('Percentage of Nodes Removed')
    ax2.set_ylabel('NMI&ECSim')
    ax2.legend()
    # Set the x-axis scale
    plt.xticks(np.arange(0.0, 0.9, 0.05))

    # Automatically determine the lower bound for the y-axis
    y_min = min([min(y) for y in MEAN])
    y_max = max([max(y) for y in MEAN])
    y_range = y_max - y_min
    y_offset = y_range * 0.1  # Adjust the offset as needed
    y_lower = y_min - y_offset - 0.01
    y_upper = 1.02
    ax1.set_ylim(y_lower, y_upper)
    ax2.set_ylim(y_lower, y_upper)

    # Set the y-axis tick marks
    y_tick_step = 0.025
    y_ticks = np.arange(np.ceil(y_lower * 10) / 10, y_upper + 0.5*y_tick_step, y_tick_step)
    # Add horizontal reference lines
    for y in y_ticks:
        ax1.axhline(y=y, color='gray', linestyle='--', alpha=0.3)
        ax2.axhline(y=y, color='gray', linestyle='--', alpha=0.3)
    
    ax1.set_yticks(y_ticks)
    ax2.set_yticks(y_ticks)

    # Adjust the figure size
    fig.set_size_inches(10, 12)  # Increase the height of the figure

    fig.suptitle('Combined Plots', y=0.95)
    
    if output:
        filename = filename+"_COMBINE"

        file_path = generate_output(random_disturb, filename+".png")
        plt.savefig(file_path)    

    # Show the plot
    plt.show()
# Out:
# CPU times: user 209 ms, sys: 53 ms, total: 262 ms
# Wall time: 427 ms

# %%
# %%time
import numpy as np
import matplotlib.pyplot as plt

def Plot_Total(output:bool, random_disturb:bool, MEAN, STD, filename):
    # Generate x-coordinates for the data points with a step size of 0.05
    x_values = np.arange(0.05, 0.86, 0.05)

    # Create a figure and axes
    fig, ax = plt.subplots()

    # Plot the lines for columns 1 and 3 in the first subplot
    ax.plot(x_values, [MEAN[i][0] for i in range(len(MEAN))], label='Eucl & NMI', color='tab:red')
    ax.plot(x_values, [MEAN[i][2] for i in range(len(MEAN))], label='Eucl & ECSim', color='tab:blue')
    ax.fill_between(x_values, np.subtract([MEAN[i][0] for i in range(len(MEAN))], [STD[i][0] for i in range(len(STD))]),
                     np.add([MEAN[i][0] for i in range(len(MEAN))], [STD[i][0] for i in range(len(STD))]), alpha=0.2, color='tab:red')
    ax.fill_between(x_values, np.subtract([MEAN[i][2] for i in range(len(MEAN))], [STD[i][2] for i in range(len(STD))]),
                     np.add([MEAN[i][2] for i in range(len(MEAN))], [STD[i][2] for i in range(len(STD))]), alpha=0.2, color='tab:blue')

    # Plot the lines for columns 2 and 4 in the second subplot
    ax.plot(x_values, [MEAN[i][1] for i in range(len(MEAN))], label='Cosn & NMI', color='tab:green')
    ax.plot(x_values, [MEAN[i][3] for i in range(len(MEAN))], label='Cosn & ECSim', color='tab:orange')
    ax.fill_between(x_values, np.subtract([MEAN[i][1] for i in range(len(MEAN))], [STD[i][1] for i in range(len(STD))]),
                     np.add([MEAN[i][1] for i in range(len(MEAN))], [STD[i][1] for i in range(len(STD))]), alpha=0.2, color='tab:green')
    ax.fill_between(x_values, np.subtract([MEAN[i][3] for i in range(len(MEAN))], [STD[i][3] for i in range(len(STD))]),
                     np.add([MEAN[i][3] for i in range(len(MEAN))], [STD[i][3] for i in range(len(STD))]), alpha=0.2, color='tab:orange')

    # Set labels and title
    ax.set_xlabel('Percentage of Nodes Removed')
    ax.set_ylabel('NMI&ECSim')
    #ax.set_title('Total Plot')

    # Set the x-axis scale
    plt.xticks(np.arange(0.0, 0.9, 0.05))

    # Automatically determine the lower bound for the y-axis
    y_min = min([min(y) for y in MEAN])
    y_max = max([max(y) for y in MEAN])
    y_range = y_max - y_min
    y_offset = y_range * 0.1  # Adjust the offset as needed
    y_lower = y_min - y_offset - 0.01
    y_upper = 1.02
    ax.set_ylim(y_lower, y_upper)

    # Set the y-axis tick marks
    y_tick_step = 0.025
    y_ticks = np.arange(np.ceil(y_lower * 10) / 10, y_upper + 0.5*y_tick_step, y_tick_step)
    # Add horizontal reference lines
    for y in y_ticks:
        ax.axhline(y=y, color='gray', linestyle='--', alpha=0.3)
        
    ax.set_yticks(y_ticks)

    # Add a legend
    ax.legend()

    # Adjust the figure size
    fig.set_size_inches(10, 6)
    fig.suptitle('Total Plots', y=0.95)

    if output:
        filename = filename+"_TOTAL"

        file_path = generate_output(random_disturb, filename+".png")
        plt.savefig(file_path)    

    # Show the plot
    plt.show()
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 6.91 µs

# %%
# %%time
from gem.embedding.hope import HOPE
from gem.embedding.lap import LaplacianEigenmaps
from auxpack.lle import lles
from auxpack.DeepWalk import DeepWalk
from karateclub import MNMF
from ge import LINE
from node2vec import Node2Vec

def perform_hope_embedding(graph, nodes_to_remove, embedding_dimension, _, __, ___):
    graph_copy = graph.copy()
    graph_copy.remove_nodes_from(nodes_to_remove)
    hope_model = HOPE(d=embedding_dimension, beta=0.01)
    embd = hope_model.learn_embedding(graph=graph_copy, is_weighted=False, no_python=True)
    return embd

def perform_laplacian_embedding(graph, nodes_to_remove, embedding_dimension, _, __, ___):
    graph_copy = graph.copy()
    graph_copy.remove_nodes_from(nodes_to_remove)
    lap_model = LaplacianEigenmaps(d=embedding_dimension)
    embd = lap_model.learn_embedding(graph=graph_copy, is_weighted=False, no_python=True)
    return embd

def perform_lle_embedding(graph, nodes_to_remove, embedding_dimension, _, __, ___):
    graph_copy = graph.copy()
    graph_copy.remove_nodes_from(nodes_to_remove)
    embd = lles(graph_copy, embedding_dimension)
    return embd

def perform_deepwalk_embedding(graph, nodes_to_remove, embedding_dimension, _, __, wk=32):
    graph_copy = graph.copy()
    graph_copy.remove_nodes_from(nodes_to_remove)
    model = DeepWalk(dimensions=embedding_dimension, walk_length=16, window_size=10, walk_number=10, workers=wk)
    model.fit(graph_copy)
    embd = model.get_embedding()
    return embd

def perform_mnmf_embedding(graph, nodes_to_remove, embedding_dimension, number_of_intrinsic_clusters, _, __):
    graph_copy = graph.copy()
    graph_copy.remove_nodes_from(nodes_to_remove)
    H = nx.relabel.convert_node_labels_to_integers(graph_copy)
    MNMF_model = MNMF(dimensions=embedding_dimension, clusters=number_of_intrinsic_clusters, 
                      lambd=0.2, alpha=0.05, beta=0.05, iterations=100, lower_control=1e-15, eta=5.0, seed=42)
    MNMF_model.fit(H)
    embd = MNMF_model.get_embedding()
    return embd


def perform_line_embedding(graph, nodes_to_remove, embedding_dimension, _, __, ___):
    graph_copy = graph.copy()
    graph_copy.remove_nodes_from(nodes_to_remove)
    model = LINE(graph_copy, embedding_size=embedding_dimension, order='first')
    model.train(batch_size=8192, epochs=50, verbose=0)
    LINE_embd = model.get_embeddings()
    embd = list(LINE_embd.values())
    return embd

def perform_node2vec_embedding(graph, nodes_to_remove, embedding_dimension,_, idx, wk=32):
    graph_copy = graph.copy()
    graph_copy.remove_nodes_from(nodes_to_remove)
    node2vec_model = Node2Vec(graph_copy, dimensions=embedding_dimension, walk_length=16, num_walks=10, workers=wk, quiet=True)
    node2vec_fit = node2vec_model.fit(window=10, min_count=1, batch_words=80000)
    nodes_range = np.array(range(graph.number_of_nodes()))
    nodes = [str(x) for x in nodes_range[idx]]
    embd = np.array([node2vec_fit.wv[node] for node in nodes])
    return embd

def calculate_score(embd, intrinsic_membership, number_of_intrinsic_clusters):
    intrin_list = intrinsic_membership
    intrin_Clus = Clustering({i: [intrin_list[i]] for i in range(len(intrin_list))})
    score = EE(number_of_intrinsic_clusters, intrin_list, intrin_Clus, embd)
    return score

def Comprehensive_Processing(output:bool, random_disturb:bool, method: int, num_cpus:int, 
                             graph, embedding_dimension, intrinsic_membership, remove_procedure, remove_procedure_index_form):
    labels = ["1HOPE", "2LAP", "3LLE", "4DeepWalk", "5MNMF", "6LINE", "7Node2Vec"]
    print(labels[method-1])
    MEAN = []
    STD = []

    embedding_methods = {
        1: (perform_hope_embedding, "HOPE"),
        2: (perform_laplacian_embedding, "LAP"),
        3: (perform_lle_embedding, "LLE"),
        4: (perform_deepwalk_embedding, "DeepWalk"),
        5: (perform_mnmf_embedding, "MNMF"),
        6: (perform_line_embedding, "LINE"),
        7: (perform_node2vec_embedding, "Node2Vec")
    }

    embedding_func, method_label = embedding_methods[method]

    for rp, idx in zip(remove_procedure, remove_procedure_index_form):
        scores = []
        for nodes_to_remove, idxx in zip(rp, idx):
            number_of_intrinsic_clusters = len(np.unique(intrinsic_membership[idxx]))
            embd = embedding_func(graph, nodes_to_remove, embedding_dimension, number_of_intrinsic_clusters, idxx, num_cpus)
            score = calculate_score(embd, intrinsic_membership[idxx], number_of_intrinsic_clusters)
            scores.append(score)

        array = np.array(scores)
        mean = np.mean(array, axis=0)
        std = np.std(array, axis=0)
        MEAN.append(mean)
        STD.append(std)
        if output:
            save_scores_to_csv(random_disturb, scores, labels[method-1] + "_SCORES")
            save_to_csv(random_disturb, MEAN, labels[method-1] + "_MEAN")
            save_to_csv(random_disturb, STD, labels[method-1] + "_STD")
    Plot_Separate(output, random_disturb, MEAN, STD, labels[method-1])
    Plot_Combine(output, random_disturb, MEAN, STD, labels[method-1])
    Plot_Total(output, random_disturb, MEAN, STD, labels[method-1])
# Out:
# CPU times: user 3.8 s, sys: 8.25 s, total: 12.1 s
# Wall time: 9.05 s

# %%
# %%time
import os

slurm_job_id = os.environ.get('SLURM_JOB_ID')
    
from datetime import datetime

import networkx as nx
from networkx.generators.community import LFR_benchmark_graph

n = 1000
tau1 = 2  # Power-law exponent for the degree distribution
tau2 = 1.1  # Power-law exponent for the community size distribution
mu = 0.1  # Mixing parameter
avg_deg = 25  # Average Degree
max_deg = int(0.1 * n)  # Max Degree
min_commu = 60  # Min Community Size
max_commu = int(0.1 * n)  # Max Community Size

G = LFR_benchmark_graph(
    n, tau1, tau2, mu, average_degree=avg_deg, max_degree=max_deg, min_community=min_commu, max_community=max_commu,
    seed=7
)

# Remove multi-edges and self-loops from G
G = nx.Graph(G)
selfloop_edges = list(nx.selfloop_edges(G))
G.remove_edges_from(selfloop_edges)

# Generate a timestamp for the output file names
now = datetime.now()

# Write the graph's edge list to a file
edge_output_file = f"{slurm_job_id}_edgelist_{now.strftime('%Y-%m-%d-%H-%M')}.txt"
nx.write_edgelist(G, edge_output_file, delimiter=' ', data=False)

import numpy as np
# Get intrinsic membership and save it to a file
intrinsic_communities = {frozenset(G.nodes[v]["community"]) for v in G}
intrinsic_membership = np.empty(G.number_of_nodes(), dtype=int)
for node in range(G.number_of_nodes()):
    for index, inner_set in enumerate(intrinsic_communities):
        if node in inner_set:
            intrinsic_membership[node] = index
            break

membership_output_file = f"{slurm_job_id}_membership_{now.strftime('%Y-%m-%d-%H-%M')}.txt"
np.savetxt(membership_output_file, intrinsic_membership, delimiter=' ', fmt='%d')

# Get betweenness centrality and save it to a file
betweenness = list(nx.betweenness_centrality(G).values())
betweenness_output_file = f"{slurm_job_id}_betweenness_{now.strftime('%Y-%m-%d-%H-%M')}.txt"
np.savetxt(betweenness_output_file, betweenness, delimiter=' ')
# Out:
# CPU times: user 5.1 s, sys: 0 ns, total: 5.1 s
# Wall time: 5.1 s

# %%
'''
### 读取存储的图的相关信息
### 从文件中读入内容并转化成 边列表
with open('edgelist_2023-07-11-17.txt', 'r') as file:
    lines = file.readlines()

### Process the lines and create a list of number pairs
edge_list = []
for line in lines:
    pair = tuple(map(int, line.strip().split()))
    edge_list.append(pair)

### Print the list of number pairs
#print(edge_list)

import networkx as nx

### 新建一个图 
G0 = nx.Graph()

### 向图添加边
G0.add_edges_from(edge_list)

### 记录有几个结点
N = G0.number_of_nodes()

### Load Community Info
import numpy as np

membership_list = "membership_2023-07-11-17.txt"
intrinsic_membership = np.loadtxt(membership_list, dtype=int)

btwn_file = "betweenness_2023-07-11-17.txt"
betweenness = np.loadtxt(btwn_file)
'''
# Out:
# '\n### 读取存储的图的相关信息\n### 从文件中读入内容并转化成 边列表\nwith open(\'edgelist_2023-07-11-17.txt\', \'r\') as file:\n    lines = file.readlines()\n\n### Process the lines and create a list of number pairs\nedge_list = []\nfor line in lines:\n    pair = tuple(map(int, line.strip().split()))\n    edge_list.append(pair)\n\n### Print the list of number pairs\n#print(edge_list)\n\nimport networkx as nx\n\n### 新建一个图 \nG0 = nx.Graph()\n\n### 向图添加边\nG0.add_edges_from(edge_list)\n\n### 记录有几个结点\nN = G0.number_of_nodes()\n\n### Load Community Info\nimport numpy as np\n\nmembership_list = "membership_2023-07-11-17.txt"\nintrinsic_membership = np.loadtxt(membership_list, dtype=int)\n\nbtwn_file = "betweenness_2023-07-11-17.txt"\nbetweenness = np.loadtxt(btwn_file)\n'

# %%
# %%time
from auxpack.eval_embd import eval_embd as EE
from clusim.clustering import Clustering

D=20

output_flag=False
random_disturb=False

import multiprocessing
num_cpus = multiprocessing.cpu_count()
print(num_cpus)
# Out:
# 128
# CPU times: user 67.7 ms, sys: 22.6 ms, total: 90.2 ms
# Wall time: 236 ms

# %%
# %%time
remove_procedure = generate_remove_list(random_disturb=random_disturb, graph=G,  number_of_nodes=G.number_of_nodes(), betweenness=betweenness)

### 读取存储的删除顶点的顺序信息
'''
with open('Graph_Rmv_Stoch_2023-07-11-18/remove_procedure.txt', 'r') as file:
    loaded_data = json.load(file)
loaded_data == ls
'''
# Out:
# CPU times: user 925 ms, sys: 654 µs, total: 926 ms
# Wall time: 927 ms
# "\nwith open('Graph_Rmv_Stoch_2023-07-11-18/remove_procedure.txt', 'r') as file:\n    loaded_data = json.load(file)\nloaded_data == ls\n"

# %%
# %%time
index = remove_procedure_index(remove_procedure=remove_procedure, num_nodes=G.number_of_nodes())
# Out:
# CPU times: user 424 µs, sys: 533 µs, total: 957 µs
# Wall time: 808 µs

# %%
# %%time
Comprehensive_Processing(output=output_flag, random_disturb=random_disturb, method=1, num_cpus=num_cpus, graph = G, embedding_dimension=D, 
                        intrinsic_membership=intrinsic_membership, remove_procedure=remove_procedure, remove_procedure_index_form=index)
# Out:
# 1HOPE
# CPU times: user 17min 10s, sys: 20min 38s, total: 37min 49s
# Wall time: 22.6 s

# %%
# %%time
Comprehensive_Processing(output=output_flag, random_disturb=random_disturb, method=2, num_cpus=num_cpus, graph = G, embedding_dimension=D, 
                         intrinsic_membership=intrinsic_membership, remove_procedure=remove_procedure, remove_procedure_index_form=index)
# Out:
# 2LAP
# CPU times: user 16min 56s, sys: 21min 19s, total: 38min 15s
# Wall time: 23.8 s

# %%
# %%time
Comprehensive_Processing(output=output_flag, random_disturb=random_disturb, method=3, num_cpus=num_cpus, graph = G, embedding_dimension=D, 
                         intrinsic_membership=intrinsic_membership, remove_procedure=remove_procedure, remove_procedure_index_form=index)
# Out:
# 3LLE
# CPU times: user 17min 16s, sys: 22min 45s, total: 40min 1s
# Wall time: 24 s

# %%
# %%time
Comprehensive_Processing(output=output_flag, random_disturb=random_disturb, method=4, num_cpus=num_cpus, graph = G, embedding_dimension=D, 
                         intrinsic_membership=intrinsic_membership, remove_procedure=remove_procedure, remove_procedure_index_form=index)
# Out:
# 4DeepWalk
# CPU times: user 15min, sys: 15min 36s, total: 30min 37s
# Wall time: 31.4 s

# %%
# %%time
Comprehensive_Processing(output=output_flag, random_disturb=random_disturb, method=5, num_cpus=num_cpus, graph = G, embedding_dimension=D, 
                         intrinsic_membership=intrinsic_membership, remove_procedure=remove_procedure, remove_procedure_index_form=index)
# Out:
# 5MNMF
# CPU times: user 21min 19s, sys: 39min 57s, total: 1h 1min 16s
# Wall time: 54.4 s

# %%
# %%time
Comprehensive_Processing(output=output_flag, random_disturb=random_disturb, method=6, num_cpus=num_cpus, graph = G, embedding_dimension=D, 
                         intrinsic_membership=intrinsic_membership, remove_procedure=remove_procedure, remove_procedure_index_form=index)
# Out:
# 6LINE
# 2023-07-14 00:00:53.589748: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-14 00:00:55.271383: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 36960 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:02:00.0, compute capability: 8.0
# 2023-07-14 00:00:55.272645: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 37692 MB memory:  -> device: 1, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:41:00.0, compute capability: 8.0
# 2023-07-14 00:00:55.273727: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 37692 MB memory:  -> device: 2, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:81:00.0, compute capability: 8.0
# 2023-07-14 00:00:55.274916: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 37692 MB memory:  -> device: 3, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:c1:00.0, compute capability: 8.0
# CPU times: user 17min 16s, sys: 16min 18s, total: 33min 34s
# Wall time: 1min 37s

# %%
# %%time
Comprehensive_Processing(output=output_flag, random_disturb=random_disturb, method=7, num_cpus=num_cpus, graph = G, embedding_dimension=D, 
                         intrinsic_membership=intrinsic_membership, remove_procedure=remove_procedure, remove_procedure_index_form=index)
# Out:
# 7Node2Vec
# CPU times: user 26min 24s, sys: 15min 32s, total: 41min 56s
# Wall time: 13min 1s

# %%
import networkx as nx

# Assuming you have a graph G

# Calculate betweenness centrality
betweenness_dict = nx.betweenness_centrality(G)

# Sort the dictionary by values in descending order
sorted_betweenness = dict(sorted(betweenness_dict.items(), key=lambda x: x[1], reverse=True))

# Print the sorted dictionary
for node, value in sorted_betweenness.items():
    print(f"Node: {node}, Betweenness Centrality: {value}")
# Out:
# Node: 917, Betweenness Centrality: 0.010761039325864323
# Node: 297, Betweenness Centrality: 0.010194909454458593
# Node: 393, Betweenness Centrality: 0.008784406433313355
# Node: 360, Betweenness Centrality: 0.0084684243819742
# Node: 652, Betweenness Centrality: 0.00844385534325672
# Node: 21, Betweenness Centrality: 0.00842753403773572
# Node: 62, Betweenness Centrality: 0.0083600977850385
# Node: 352, Betweenness Centrality: 0.00831557882902515
# Node: 39, Betweenness Centrality: 0.008305324957562317
# Node: 235, Betweenness Centrality: 0.007889181581958716
# Node: 821, Betweenness Centrality: 0.007867022226069284
# Node: 979, Betweenness Centrality: 0.007847373538327589
# Node: 182, Betweenness Centrality: 0.00778212116253036
# Node: 495, Betweenness Centrality: 0.00769928521213503
# Node: 210, Betweenness Centrality: 0.007563664319696248
# Node: 57, Betweenness Centrality: 0.007461636499242675
# Node: 892, Betweenness Centrality: 0.007411027401749747
# Node: 975, Betweenness Centrality: 0.007208363635588359
# Node: 888, Betweenness Centrality: 0.007114024773133925
# Node: 497, Betweenness Centrality: 0.0070562728818247215
# Node: 356, Betweenness Centrality: 0.0070066352136844935
# Node: 40, Betweenness Centrality: 0.006791325904415849
# Node: 763, Betweenness Centrality: 0.006689855753091281
# Node: 96, Betweenness Centrality: 0.006629446870046726
# Node: 274, Betweenness Centrality: 0.006594704168360335
# Node: 573, Betweenness Centrality: 0.006588704618177485
# Node: 613, Betweenness Centrality: 0.006560067249296316
# Node: 691, Betweenness Centrality: 0.006469931787334495
# Node: 342, Betweenness Centrality: 0.006339768450646818
# Node: 394, Betweenness Centrality: 0.006334587876044797
# Node: 378, Betweenness Centrality: 0.00628570908795725
# Node: 952, Betweenness Centrality: 0.0062288597114690545
# Node: 820, Betweenness Centrality: 0.006226508555629214
# Node: 853, Betweenness Centrality: 0.006202842104209812
# Node: 170, Betweenness Centrality: 0.00617393113588674
# Node: 252, Betweenness Centrality: 0.006165354904417137
# Node: 609, Betweenness Centrality: 0.006116836144609169
# Node: 282, Betweenness Centrality: 0.0060364378097847535
# Node: 760, Betweenness Centrality: 0.006020676800765803
# Node: 113, Betweenness Centrality: 0.0060006756074547805
# Node: 185, Betweenness Centrality: 0.005988158106970828
# Node: 506, Betweenness Centrality: 0.0058105517430557104
# Node: 323, Betweenness Centrality: 0.005776992843266756
# Node: 661, Betweenness Centrality: 0.005758789312882274
# Node: 380, Betweenness Centrality: 0.005671032480574573
# Node: 965, Betweenness Centrality: 0.005656606728880809
# Node: 98, Betweenness Centrality: 0.0056427274171170685
# Node: 629, Betweenness Centrality: 0.005640347568446548
# Node: 416, Betweenness Centrality: 0.00561407823202071
# Node: 895, Betweenness Centrality: 0.005450793583482683
# Node: 162, Betweenness Centrality: 0.005420021652999934
# Node: 65, Betweenness Centrality: 0.0053676619008096406
# Node: 653, Betweenness Centrality: 0.005304713904031821
# Node: 988, Betweenness Centrality: 0.005243569036650023
# Node: 1, Betweenness Centrality: 0.005163622021010116
# Node: 803, Betweenness Centrality: 0.005140988218819021
# Node: 225, Betweenness Centrality: 0.005128202716535113
# Node: 722, Betweenness Centrality: 0.005112441350822196
# Node: 73, Betweenness Centrality: 0.005100305417463159
# Node: 889, Betweenness Centrality: 0.0050571518549733414
# Node: 728, Betweenness Centrality: 0.0049598178772488994
# Node: 725, Betweenness Centrality: 0.004901979522498873
# Node: 118, Betweenness Centrality: 0.004809835440978742
# Node: 527, Betweenness Centrality: 0.004798532026427738
# Node: 805, Betweenness Centrality: 0.004756706573238099
# Node: 822, Betweenness Centrality: 0.004721422879486497
# Node: 26, Betweenness Centrality: 0.004711212361639456
# Node: 108, Betweenness Centrality: 0.004697572688531231
# Node: 317, Betweenness Centrality: 0.004635364572183237
# Node: 600, Betweenness Centrality: 0.004610707586647096
# Node: 258, Betweenness Centrality: 0.004552324223929411
# Node: 72, Betweenness Centrality: 0.004542166272105737
# Node: 567, Betweenness Centrality: 0.004469879545788106
# Node: 560, Betweenness Centrality: 0.004433781918433666
# Node: 594, Betweenness Centrality: 0.004401233394523186
# Node: 974, Betweenness Centrality: 0.004396096091751712
# Node: 947, Betweenness Centrality: 0.004379145673872446
# Node: 193, Betweenness Centrality: 0.004370034764344735
# Node: 620, Betweenness Centrality: 0.004328195691492831
# Node: 328, Betweenness Centrality: 0.004180142053020349
# Node: 984, Betweenness Centrality: 0.004178592617853256
# Node: 941, Betweenness Centrality: 0.004113298163571466
# Node: 69, Betweenness Centrality: 0.004099313203879036
# Node: 561, Betweenness Centrality: 0.004090305137784039
# Node: 479, Betweenness Centrality: 0.004072180086795331
# Node: 654, Betweenness Centrality: 0.004052965309773995
# Node: 597, Betweenness Centrality: 0.004050386956107655
# Node: 704, Betweenness Centrality: 0.004003756656157113
# Node: 3, Betweenness Centrality: 0.0039837054151377
# Node: 724, Betweenness Centrality: 0.003967558169148942
# Node: 87, Betweenness Centrality: 0.003949921189413713
# Node: 223, Betweenness Centrality: 0.003947284211082654
# Node: 128, Betweenness Centrality: 0.003888368482741419
# Node: 513, Betweenness Centrality: 0.003803208290233629
# Node: 4, Betweenness Centrality: 0.003743384906942162
# Node: 385, Betweenness Centrality: 0.003704331380770727
# Node: 909, Betweenness Centrality: 0.0036448062528929093
# Node: 126, Betweenness Centrality: 0.0036394612118441794
# Node: 231, Betweenness Centrality: 0.0036276201310132226
# Node: 967, Betweenness Centrality: 0.0036087859602642134
# Node: 852, Betweenness Centrality: 0.0035942763227947796
# Node: 687, Betweenness Centrality: 0.0035928274640940265
# Node: 530, Betweenness Centrality: 0.0035317680273629945
# Node: 692, Betweenness Centrality: 0.00350662095608287
# Node: 308, Betweenness Centrality: 0.0034956951910034644
# Node: 227, Betweenness Centrality: 0.0034632716794983443
# Node: 89, Betweenness Centrality: 0.0034539582637722285
# Node: 540, Betweenness Centrality: 0.0034375434238120106
# Node: 7, Betweenness Centrality: 0.0034338500081767644
# Node: 269, Betweenness Centrality: 0.003416569304068772
# Node: 267, Betweenness Centrality: 0.0034120322415378914
# Node: 75, Betweenness Centrality: 0.0034116130498877146
# Node: 86, Betweenness Centrality: 0.0034039067939250225
# Node: 632, Betweenness Centrality: 0.003395749773601275
# Node: 903, Betweenness Centrality: 0.0033783336610507843
# Node: 428, Betweenness Centrality: 0.0033764926139362695
# Node: 993, Betweenness Centrality: 0.003364136401780189
# Node: 467, Betweenness Centrality: 0.0033546174268626206
# Node: 218, Betweenness Centrality: 0.0033324600744736722
# Node: 490, Betweenness Centrality: 0.003330962777791514
# Node: 457, Betweenness Centrality: 0.003296274603896266
# Node: 531, Betweenness Centrality: 0.0032943143418785502
# Node: 756, Betweenness Centrality: 0.003267845941044846
# Node: 591, Betweenness Centrality: 0.0032264464104875827
# Node: 240, Betweenness Centrality: 0.0032069120406184016
# Node: 862, Betweenness Centrality: 0.0031996153777796624
# Node: 125, Betweenness Centrality: 0.0031722529892858745
# Node: 640, Betweenness Centrality: 0.00316447286116807
# Node: 348, Betweenness Centrality: 0.0031327228191109662
# Node: 525, Betweenness Centrality: 0.0031296210921352955
# Node: 238, Betweenness Centrality: 0.0031247554199995567
# Node: 838, Betweenness Centrality: 0.0030930732887613924
# Node: 137, Betweenness Centrality: 0.0030630507164898335
# Node: 932, Betweenness Centrality: 0.003048307867367003
# Node: 233, Betweenness Centrality: 0.0030308194217112693
# Node: 169, Betweenness Centrality: 0.003018376879253066
# Node: 558, Betweenness Centrality: 0.0030122672829633965
# Node: 929, Betweenness Centrality: 0.003011694327481775
# Node: 300, Betweenness Centrality: 0.002993493894853161
# Node: 582, Betweenness Centrality: 0.0029894335578457038
# Node: 585, Betweenness Centrality: 0.0029859092224050294
# Node: 32, Betweenness Centrality: 0.0029497995212073116
# Node: 207, Betweenness Centrality: 0.0029488517425789776
# Node: 777, Betweenness Centrality: 0.002941253326925008
# Node: 921, Betweenness Centrality: 0.002919386911353055
# Node: 6, Betweenness Centrality: 0.002899737780659151
# Node: 202, Betweenness Centrality: 0.0028744018347150227
# Node: 369, Betweenness Centrality: 0.002857943419392846
# Node: 857, Betweenness Centrality: 0.0028397121826909725
# Node: 250, Betweenness Centrality: 0.0028318964390927847
# Node: 132, Betweenness Centrality: 0.0028058852359607606
# Node: 295, Betweenness Centrality: 0.002805102495389434
# Node: 766, Betweenness Centrality: 0.0027746382262211944
# Node: 408, Betweenness Centrality: 0.00276612160392371
# Node: 480, Betweenness Centrality: 0.0027306339686304654
# Node: 41, Betweenness Centrality: 0.0027039599494359085
# Node: 997, Betweenness Centrality: 0.0026614237122472564
# Node: 526, Betweenness Centrality: 0.0026572482666929183
# Node: 569, Betweenness Centrality: 0.0026524904939754894
# Node: 395, Betweenness Centrality: 0.0026471368949056617
# Node: 518, Betweenness Centrality: 0.0026412714757726246
# Node: 80, Betweenness Centrality: 0.0025984985521046696
# Node: 519, Betweenness Centrality: 0.002588198769657449
# Node: 243, Betweenness Centrality: 0.0025846035559442425
# Node: 215, Betweenness Centrality: 0.002559566104400464
# Node: 433, Betweenness Centrality: 0.002541369980856863
# Node: 38, Betweenness Centrality: 0.002504143401826654
# Node: 47, Betweenness Centrality: 0.0025029166259054516
# Node: 477, Betweenness Centrality: 0.002496959234217942
# Node: 542, Betweenness Centrality: 0.002470978805747056
# Node: 580, Betweenness Centrality: 0.002465449856528369
# Node: 254, Betweenness Centrality: 0.0024535001430357343
# Node: 515, Betweenness Centrality: 0.0024484496761255905
# Node: 626, Betweenness Centrality: 0.0024461617468197363
# Node: 158, Betweenness Centrality: 0.0024319603430620943
# Node: 986, Betweenness Centrality: 0.0024068184664561058
# Node: 968, Betweenness Centrality: 0.0023619554032335392
# Node: 188, Betweenness Centrality: 0.0023550354756976103
# Node: 146, Betweenness Centrality: 0.0023403764874403935
# Node: 699, Betweenness Centrality: 0.0023118751722378495
# Node: 859, Betweenness Centrality: 0.0023091799928558945
# Node: 402, Betweenness Centrality: 0.002295517578717966
# Node: 793, Betweenness Centrality: 0.002277093843629415
# Node: 30, Betweenness Centrality: 0.0022582577244861543
# Node: 801, Betweenness Centrality: 0.0022547181334820004
# Node: 331, Betweenness Centrality: 0.0022489739482605977
# Node: 579, Betweenness Centrality: 0.0022412316515781207
# Node: 581, Betweenness Centrality: 0.00224111813715605
# Node: 744, Betweenness Centrality: 0.0022390093180137054
# Node: 896, Betweenness Centrality: 0.0022382448948251505
# Node: 148, Betweenness Centrality: 0.002235177819544142
# Node: 396, Betweenness Centrality: 0.002211906540065217
# Node: 455, Betweenness Centrality: 0.0022033740754000062
# Node: 275, Betweenness Centrality: 0.0021976845948789223
# Node: 900, Betweenness Centrality: 0.002195229748048492
# Node: 20, Betweenness Centrality: 0.0021849910464394467
# Node: 325, Betweenness Centrality: 0.002176367616310493
# Node: 812, Betweenness Centrality: 0.0021522479402752014
# Node: 406, Betweenness Centrality: 0.002149398188383283
# Node: 551, Betweenness Centrality: 0.0021437915536546216
# Node: 82, Betweenness Centrality: 0.0021432703572393697
# Node: 376, Betweenness Centrality: 0.0021411979670748673
# Node: 664, Betweenness Centrality: 0.002126799735818904
# Node: 224, Betweenness Centrality: 0.0021208630095151423
# Node: 906, Betweenness Centrality: 0.00211620917852813
# Node: 621, Betweenness Centrality: 0.002114082480660193
# Node: 19, Betweenness Centrality: 0.0021042473071357227
# Node: 444, Betweenness Centrality: 0.002093120843700604
# Node: 799, Betweenness Centrality: 0.002075737486605537
# Node: 779, Betweenness Centrality: 0.0020731131488027775
# Node: 697, Betweenness Centrality: 0.0020709465489811376
# Node: 802, Betweenness Centrality: 0.0020680803267468075
# Node: 183, Betweenness Centrality: 0.0020645151410711134
# Node: 117, Betweenness Centrality: 0.0020590141121889158
# Node: 122, Betweenness Centrality: 0.0020580641329369354
# Node: 787, Betweenness Centrality: 0.0020572375535562876
# Node: 835, Betweenness Centrality: 0.0020536146673472352
# Node: 955, Betweenness Centrality: 0.002048699410024358
# Node: 604, Betweenness Centrality: 0.0020311187779132427
# Node: 259, Betweenness Centrality: 0.0020086723376686977
# Node: 514, Betweenness Centrality: 0.0020049185977130727
# Node: 270, Betweenness Centrality: 0.001999548328784734
# Node: 127, Betweenness Centrality: 0.001991614282003211
# Node: 103, Betweenness Centrality: 0.001988737851242325
# Node: 236, Betweenness Centrality: 0.0019701124819935766
# Node: 851, Betweenness Centrality: 0.001958155812127958
# Node: 887, Betweenness Centrality: 0.0019463622423281728
# Node: 712, Betweenness Centrality: 0.0019463381835132922
# Node: 292, Betweenness Centrality: 0.001942761261908773
# Node: 201, Betweenness Centrality: 0.0019408774429829675
# Node: 78, Betweenness Centrality: 0.0019340420431393026
# Node: 120, Betweenness Centrality: 0.0019332676569396184
# Node: 635, Betweenness Centrality: 0.0019240750844439465
# Node: 496, Betweenness Centrality: 0.0019239334568027272
# Node: 491, Betweenness Centrality: 0.0019200590902540722
# Node: 841, Betweenness Centrality: 0.0019183746409682728
# Node: 765, Betweenness Centrality: 0.001912372127733527
# Node: 456, Betweenness Centrality: 0.00189202622343863
# Node: 226, Betweenness Centrality: 0.0018904941857007924
# Node: 881, Betweenness Centrality: 0.001871053454340428
# Node: 529, Betweenness Centrality: 0.0018640782958130042
# Node: 313, Betweenness Centrality: 0.0018581522294276232
# Node: 248, Betweenness Centrality: 0.0018561230085662002
# Node: 775, Betweenness Centrality: 0.0018543639141731804
# Node: 245, Betweenness Centrality: 0.001849142884624172
# Node: 564, Betweenness Centrality: 0.001845668444539692
# Node: 596, Betweenness Centrality: 0.0018429952922088
# Node: 377, Betweenness Centrality: 0.0018413484665858507
# Node: 731, Betweenness Centrality: 0.001834244272044834
# Node: 893, Betweenness Centrality: 0.0018335917322131494
# Node: 22, Betweenness Centrality: 0.0018312184847935138
# Node: 191, Betweenness Centrality: 0.0018275833210793528
# Node: 566, Betweenness Centrality: 0.0018274516882124201
# Node: 796, Betweenness Centrality: 0.0018273873130887604
# Node: 298, Betweenness Centrality: 0.0018266528252124797
# Node: 797, Betweenness Centrality: 0.0018077188408274299
# Node: 199, Betweenness Centrality: 0.0018068271546670765
# Node: 312, Betweenness Centrality: 0.0018043412217575326
# Node: 800, Betweenness Centrality: 0.0017992629628104146
# Node: 97, Betweenness Centrality: 0.001795406820304378
# Node: 588, Betweenness Centrality: 0.0017918391919623763
# Node: 326, Betweenness Centrality: 0.0017902081199135567
# Node: 555, Betweenness Centrality: 0.001786678563224924
# Node: 198, Betweenness Centrality: 0.0017778803276153603
# Node: 14, Betweenness Centrality: 0.0017759575284634506
# Node: 764, Betweenness Centrality: 0.001775899464316495
# Node: 672, Betweenness Centrality: 0.001774156571698643
# Node: 702, Betweenness Centrality: 0.0017741482495384582
# Node: 686, Betweenness Centrality: 0.0017731300655566742
# Node: 715, Betweenness Centrality: 0.0017720971036415463
# Node: 713, Betweenness Centrality: 0.0017693346484000205
# Node: 329, Betweenness Centrality: 0.0017687595792675295
# Node: 761, Betweenness Centrality: 0.0017629424147700733
# Node: 655, Betweenness Centrality: 0.0017526183165673516
# Node: 572, Betweenness Centrality: 0.0017409488217589998
# Node: 933, Betweenness Centrality: 0.001736043499640752
# Node: 831, Betweenness Centrality: 0.0017313401405088778
# Node: 330, Betweenness Centrality: 0.0017105179402864842
# Node: 346, Betweenness Centrality: 0.0017099556038958138
# Node: 277, Betweenness Centrality: 0.0017032883563937028
# Node: 200, Betweenness Centrality: 0.00169526823981022
# Node: 93, Betweenness Centrality: 0.001682238754287673
# Node: 810, Betweenness Centrality: 0.0016712865005986668
# Node: 53, Betweenness Centrality: 0.0016666934620242016
# Node: 77, Betweenness Centrality: 0.0016626268538264565
# Node: 755, Betweenness Centrality: 0.001658221961406327
# Node: 167, Betweenness Centrality: 0.0016516585827440573
# Node: 388, Betweenness Centrality: 0.001646418439017641
# Node: 419, Betweenness Centrality: 0.0016462774378264607
# Node: 43, Betweenness Centrality: 0.0016427926638437659
# Node: 633, Betweenness Centrality: 0.001636180311958679
# Node: 971, Betweenness Centrality: 0.0016298605212064715
# Node: 730, Betweenness Centrality: 0.0016241833648996363
# Node: 471, Betweenness Centrality: 0.0016168069062821215
# Node: 995, Betweenness Centrality: 0.0016113509876737205
# Node: 84, Betweenness Centrality: 0.0016107437014604563
# Node: 708, Betweenness Centrality: 0.0016090505748644719
# Node: 628, Betweenness Centrality: 0.001601767435593984
# Node: 964, Betweenness Centrality: 0.0015968409223022471
# Node: 599, Betweenness Centrality: 0.0015953121288097504
# Node: 617, Betweenness Centrality: 0.001592241231254776
# Node: 665, Betweenness Centrality: 0.0015799352953772498
# Node: 811, Betweenness Centrality: 0.0015777924194596109
# Node: 61, Betweenness Centrality: 0.0015745802879714224
# Node: 870, Betweenness Centrality: 0.00156965187436015
# Node: 556, Betweenness Centrality: 0.0015590899688288872
# Node: 682, Betweenness Centrality: 0.001551945545583538
# Node: 310, Betweenness Centrality: 0.0015500168151887778
# Node: 520, Betweenness Centrality: 0.0015448956115874598
# Node: 111, Betweenness Centrality: 0.0015434081751773577
# Node: 438, Betweenness Centrality: 0.0015429114838993022
# Node: 840, Betweenness Centrality: 0.001540978576823163
# Node: 296, Betweenness Centrality: 0.0015334648412150468
# Node: 278, Betweenness Centrality: 0.0015309083430672893
# Node: 147, Betweenness Centrality: 0.001526941491891867
# Node: 413, Betweenness Centrality: 0.0015234995499427018
# Node: 465, Betweenness Centrality: 0.0015177581047383852
# Node: 638, Betweenness Centrality: 0.001511607932665345
# Node: 869, Betweenness Centrality: 0.0015089915962101567
# Node: 643, Betweenness Centrality: 0.0015034966023463206
# Node: 667, Betweenness Centrality: 0.001501375147002081
# Node: 784, Betweenness Centrality: 0.00150079619371897
# Node: 871, Betweenness Centrality: 0.001498668786277805
# Node: 739, Betweenness Centrality: 0.0014980179806840575
# Node: 335, Betweenness Centrality: 0.0014938291256664368
# Node: 440, Betweenness Centrality: 0.0014897258696478224
# Node: 230, Betweenness Centrality: 0.0014889498323171395
# Node: 13, Betweenness Centrality: 0.0014876402322704899
# Node: 623, Betweenness Centrality: 0.001479138810439038
# Node: 34, Betweenness Centrality: 0.001477076905103101
# Node: 149, Betweenness Centrality: 0.0014745690356715812
# Node: 574, Betweenness Centrality: 0.0014711282483182556
# Node: 114, Betweenness Centrality: 0.0014674036698234844
# Node: 156, Betweenness Centrality: 0.0014607634456250856
# Node: 322, Betweenness Centrality: 0.0014570431466632936
# Node: 970, Betweenness Centrality: 0.0014485968150645514
# Node: 791, Betweenness Centrality: 0.0014478417111640246
# Node: 315, Betweenness Centrality: 0.0014464199049524454
# Node: 634, Betweenness Centrality: 0.0014458519513535434
# Node: 749, Betweenness Centrality: 0.0014416298053694123
# Node: 846, Betweenness Centrality: 0.0014317214418983557
# Node: 129, Betweenness Centrality: 0.0014279657260495618
# Node: 603, Betweenness Centrality: 0.0014274854151987188
# Node: 347, Betweenness Centrality: 0.0014273965678054175
# Node: 334, Betweenness Centrality: 0.0014229088502572926
# Node: 446, Betweenness Centrality: 0.0014209988603501682
# Node: 837, Betweenness Centrality: 0.001419775380010529
# Node: 897, Betweenness Centrality: 0.0014174693409164975
# Node: 885, Betweenness Centrality: 0.001417098183440519
# Node: 418, Betweenness Centrality: 0.0014121701242807265
# Node: 552, Betweenness Centrality: 0.0014081440193134333
# Node: 163, Betweenness Centrality: 0.00140337301483547
# Node: 989, Betweenness Centrality: 0.0014022555231686387
# Node: 546, Betweenness Centrality: 0.0013937738514592619
# Node: 109, Betweenness Centrality: 0.0013900096168113472
# Node: 337, Betweenness Centrality: 0.0013870563841555663
# Node: 85, Betweenness Centrality: 0.0013834560508117415
# Node: 532, Betweenness Centrality: 0.0013784594331345658
# Node: 545, Betweenness Centrality: 0.0013781896424809653
# Node: 12, Betweenness Centrality: 0.0013738117273601781
# Node: 914, Betweenness Centrality: 0.0013732824659140404
# Node: 251, Betweenness Centrality: 0.0013718652140501685
# Node: 940, Betweenness Centrality: 0.0013703337647911825
# Node: 28, Betweenness Centrality: 0.0013697638398596447
# Node: 534, Betweenness Centrality: 0.0013676322012875718
# Node: 203, Betweenness Centrality: 0.0013636756960372586
# Node: 68, Betweenness Centrality: 0.0013605447150760723
# Node: 59, Betweenness Centrality: 0.0013559450634610065
# Node: 139, Betweenness Centrality: 0.0013551459931412408
# Node: 263, Betweenness Centrality: 0.0013518413882837703
# Node: 138, Betweenness Centrality: 0.0013493724109475357
# Node: 931, Betweenness Centrality: 0.001349101970968828
# Node: 689, Betweenness Centrality: 0.0013463037649937815
# Node: 8, Betweenness Centrality: 0.0013372487482922995
# Node: 592, Betweenness Centrality: 0.0013367348121997382
# Node: 401, Betweenness Centrality: 0.0013349963498400727
# Node: 642, Betweenness Centrality: 0.0013293676944474153
# Node: 17, Betweenness Centrality: 0.0013264035014051625
# Node: 305, Betweenness Centrality: 0.0013251881370957767
# Node: 536, Betweenness Centrality: 0.0013171145690237074
# Node: 364, Betweenness Centrality: 0.001316136680785468
# Node: 76, Betweenness Centrality: 0.001310539875574112
# Node: 789, Betweenness Centrality: 0.0013103445914737159
# Node: 969, Betweenness Centrality: 0.001302566215627496
# Node: 333, Betweenness Centrality: 0.0013007963270111125
# Node: 439, Betweenness Centrality: 0.0012897203623771214
# Node: 154, Betweenness Centrality: 0.0012869871858808026
# Node: 958, Betweenness Centrality: 0.001282201512656011
# Node: 521, Betweenness Centrality: 0.001278602597015023
# Node: 423, Betweenness Centrality: 0.001276773017895033
# Node: 195, Betweenness Centrality: 0.0012745496731573715
# Node: 606, Betweenness Centrality: 0.0012692554324940676
# Node: 124, Betweenness Centrality: 0.0012638977546803939
# Node: 780, Betweenness Centrality: 0.0012578816918192943
# Node: 140, Betweenness Centrality: 0.0012568028599479403
# Node: 174, Betweenness Centrality: 0.0012537265349042146
# Node: 459, Betweenness Centrality: 0.0012489732828017941
# Node: 663, Betweenness Centrality: 0.0012489462931912347
# Node: 453, Betweenness Centrality: 0.0012441420660196183
# Node: 503, Betweenness Centrality: 0.0012434987542564277
# Node: 732, Betweenness Centrality: 0.0012433943194249818
# Node: 398, Betweenness Centrality: 0.0012344689556170318
# Node: 943, Betweenness Centrality: 0.0012329868649833806
# Node: 586, Betweenness Centrality: 0.001232869343997449
# Node: 544, Betweenness Centrality: 0.0012322597328615246
# Node: 945, Betweenness Centrality: 0.0012317072916359592
# Node: 367, Betweenness Centrality: 0.0012266081903457807
# Node: 145, Betweenness Centrality: 0.0012246534243143996
# Node: 694, Betweenness Centrality: 0.0012245587142395756
# Node: 954, Betweenness Centrality: 0.0012228149444813035
# Node: 15, Betweenness Centrality: 0.0012216841758828517
# Node: 919, Betweenness Centrality: 0.001220931153834525
# Node: 719, Betweenness Centrality: 0.0012206342979665106
# Node: 407, Betweenness Centrality: 0.0012192087988413677
# Node: 131, Betweenness Centrality: 0.0012101638475675322
# Node: 336, Betweenness Centrality: 0.001208238341785616
# Node: 56, Betweenness Centrality: 0.001208135824779299
# Node: 289, Betweenness Centrality: 0.0012079576739368737
# Node: 930, Betweenness Centrality: 0.0012077140152712822
# Node: 36, Betweenness Centrality: 0.0012050087394305056
# Node: 618, Betweenness Centrality: 0.0012041703474517402
# Node: 696, Betweenness Centrality: 0.001201259882371546
# Node: 112, Betweenness Centrality: 0.0011965870517285128
# Node: 709, Betweenness Centrality: 0.0011951053829952374
# Node: 636, Betweenness Centrality: 0.001189971089948166
# Node: 153, Betweenness Centrality: 0.00118817874025281
# Node: 865, Betweenness Centrality: 0.0011843798913909452
# Node: 916, Betweenness Centrality: 0.0011835357233567698
# Node: 915, Betweenness Centrality: 0.0011746073883351583
# Node: 806, Betweenness Centrality: 0.001173019500870207
# Node: 850, Betweenness Centrality: 0.001172263139803683
# Node: 923, Betweenness Centrality: 0.0011717096505095355
# Node: 110, Betweenness Centrality: 0.0011668135094297612
# Node: 815, Betweenness Centrality: 0.0011649540226870661
# Node: 106, Betweenness Centrality: 0.0011625036901735024
# Node: 523, Betweenness Centrality: 0.0011584601326092934
# Node: 159, Betweenness Centrality: 0.001157846900479823
# Node: 430, Betweenness Centrality: 0.00115463205046508
# Node: 213, Betweenness Centrality: 0.0011515882094239528
# Node: 977, Betweenness Centrality: 0.001143101646521431
# Node: 257, Betweenness Centrality: 0.0011408471612866858
# Node: 627, Betweenness Centrality: 0.0011335192314058417
# Node: 645, Betweenness Centrality: 0.0011316118336537231
# Node: 705, Betweenness Centrality: 0.0011293510261599637
# Node: 64, Betweenness Centrality: 0.0011292603690551911
# Node: 876, Betweenness Centrality: 0.001125978252526549
# Node: 244, Betweenness Centrality: 0.0011257111479538735
# Node: 462, Betweenness Centrality: 0.0011247399676280934
# Node: 16, Betweenness Centrality: 0.0011196575101502923
# Node: 345, Betweenness Centrality: 0.0011191376992712159
# Node: 184, Betweenness Centrality: 0.0011157356430362376
# Node: 512, Betweenness Centrality: 0.001115246792898746
# Node: 587, Betweenness Centrality: 0.0011140607895200048
# Node: 370, Betweenness Centrality: 0.0011120384348378034
# Node: 785, Betweenness Centrality: 0.0011102590708225275
# Node: 11, Betweenness Centrality: 0.001108280531246974
# Node: 178, Betweenness Centrality: 0.0011063100451616588
# Node: 538, Betweenness Centrality: 0.0011000767638059824
# Node: 823, Betweenness Centrality: 0.001098367443240939
# Node: 212, Betweenness Centrality: 0.0010967098111872135
# Node: 946, Betweenness Centrality: 0.0010912083460701471
# Node: 447, Betweenness Centrality: 0.0010898069376124868
# Node: 842, Betweenness Centrality: 0.001087555791820334
# Node: 926, Betweenness Centrality: 0.0010867124968277151
# Node: 327, Betweenness Centrality: 0.0010810309958880385
# Node: 290, Betweenness Centrality: 0.0010787822062572057
# Node: 366, Betweenness Centrality: 0.0010773702887998233
# Node: 742, Betweenness Centrality: 0.0010749072376351997
# Node: 31, Betweenness Centrality: 0.001069839515691493
# Node: 492, Betweenness Centrality: 0.001068642922158544
# Node: 584, Betweenness Centrality: 0.0010673299060468123
# Node: 816, Betweenness Centrality: 0.001064981701426064
# Node: 152, Betweenness Centrality: 0.0010635770077546112
# Node: 461, Betweenness Centrality: 0.0010634122014765764
# Node: 949, Betweenness Centrality: 0.0010555265668587175
# Node: 983, Betweenness Centrality: 0.0010525144881194416
# Node: 130, Betweenness Centrality: 0.0010489783438595835
# Node: 219, Betweenness Centrality: 0.001046996405627818
# Node: 434, Betweenness Centrality: 0.00104562255211808
# Node: 452, Betweenness Centrality: 0.0010449548234377857
# Node: 403, Betweenness Centrality: 0.0010419554709410626
# Node: 890, Betweenness Centrality: 0.0010406653089283
# Node: 445, Betweenness Centrality: 0.0010372538993645636
# Node: 864, Betweenness Centrality: 0.0010368644637345722
# Node: 24, Betweenness Centrality: 0.0010361955613064292
# Node: 942, Betweenness Centrality: 0.0010348994607433867
# Node: 160, Betweenness Centrality: 0.0010334700318314896
# Node: 751, Betweenness Centrality: 0.0010332782365645326
# Node: 740, Betweenness Centrality: 0.0010322552230223392
# Node: 468, Betweenness Centrality: 0.0010265107856392234
# Node: 703, Betweenness Centrality: 0.001025387792870952
# Node: 570, Betweenness Centrality: 0.0010246558304415733
# Node: 944, Betweenness Centrality: 0.001024347827690773
# Node: 133, Betweenness Centrality: 0.0010195273632267797
# Node: 143, Betweenness Centrality: 0.0010191501813318095
# Node: 877, Betweenness Centrality: 0.0010187323285573645
# Node: 339, Betweenness Centrality: 0.0010168081477848385
# Node: 832, Betweenness Centrality: 0.0010118419197923166
# Node: 550, Betweenness Centrality: 0.0010102686731585416
# Node: 905, Betweenness Centrality: 0.0010087137123566648
# Node: 237, Betweenness Centrality: 0.0010059791382677915
# Node: 141, Betweenness Centrality: 0.0010056498528204674
# Node: 48, Betweenness Centrality: 0.0010053167849620327
# Node: 738, Betweenness Centrality: 0.0010022493238617282
# Node: 205, Betweenness Centrality: 0.001001924441466018
# Node: 35, Betweenness Centrality: 0.000993504150260722
# Node: 927, Betweenness Centrality: 0.000993242473125788
# Node: 660, Betweenness Centrality: 0.000991573614116805
# Node: 279, Betweenness Centrality: 0.0009896985574356374
# Node: 273, Betweenness Centrality: 0.0009888224368631655
# Node: 934, Betweenness Centrality: 0.0009870167619720584
# Node: 121, Betweenness Centrality: 0.0009863838060407961
# Node: 123, Betweenness Centrality: 0.0009850408738053373
# Node: 860, Betweenness Centrality: 0.000984239747432294
# Node: 144, Betweenness Centrality: 0.000980964475409392
# Node: 2, Betweenness Centrality: 0.0009809254182997255
# Node: 924, Betweenness Centrality: 0.0009791831295483805
# Node: 316, Betweenness Centrality: 0.0009775534859683176
# Node: 303, Betweenness Centrality: 0.0009738262912644604
# Node: 651, Betweenness Centrality: 0.00097295656553488
# Node: 648, Betweenness Centrality: 0.0009716649380611786
# Node: 533, Betweenness Centrality: 0.0009710370892945491
# Node: 666, Betweenness Centrality: 0.000969448358451788
# Node: 644, Betweenness Centrality: 0.0009690158898571828
# Node: 711, Betweenness Centrality: 0.0009684121162542155
# Node: 630, Betweenness Centrality: 0.0009674083393649143
# Node: 549, Betweenness Centrality: 0.0009598666211987401
# Node: 283, Betweenness Centrality: 0.0009569993542902983
# Node: 349, Betweenness Centrality: 0.0009560192144849615
# Node: 998, Betweenness Centrality: 0.0009532181006256645
# Node: 990, Betweenness Centrality: 0.000952652328618005
# Node: 610, Betweenness Centrality: 0.0009520709940327542
# Node: 276, Betweenness Centrality: 0.000943842087641877
# Node: 79, Betweenness Centrality: 0.0009413477013771621
# Node: 321, Betweenness Centrality: 0.0009407260052307267
# Node: 318, Betweenness Centrality: 0.0009398664630565009
# Node: 745, Betweenness Centrality: 0.0009395281711000169
# Node: 598, Betweenness Centrality: 0.0009387839937461192
# Node: 670, Betweenness Centrality: 0.000937285372291092
# Node: 553, Betweenness Centrality: 0.0009361346582674998
# Node: 368, Betweenness Centrality: 0.000933136419896023
# Node: 176, Betweenness Centrality: 0.0009323899025970168
# Node: 425, Betweenness Centrality: 0.0009313585191117598
# Node: 44, Betweenness Centrality: 0.0009261855155213041
# Node: 209, Betweenness Centrality: 0.000925621606561256
# Node: 172, Betweenness Centrality: 0.0009252719466693498
# Node: 767, Betweenness Centrality: 0.0009217903955394763
# Node: 746, Betweenness Centrality: 0.0009216062512126996
# Node: 571, Betweenness Centrality: 0.0009199679069539073
# Node: 359, Betweenness Centrality: 0.0009158896773137948
# Node: 601, Betweenness Centrality: 0.0009125794406482363
# Node: 908, Betweenness Centrality: 0.0009082776206042261
# Node: 769, Betweenness Centrality: 0.0009065991181405046
# Node: 669, Betweenness Centrality: 0.0009064608159053302
# Node: 309, Betweenness Centrality: 0.0009052311014522515
# Node: 286, Betweenness Centrality: 0.0009020758574411304
# Node: 228, Betweenness Centrality: 0.00090005170978528
# Node: 302, Betweenness Centrality: 0.0008963700249990035
# Node: 246, Betweenness Centrality: 0.0008943269885337171
# Node: 647, Betweenness Centrality: 0.0008914999718927772
# Node: 350, Betweenness Centrality: 0.0008911097584132754
# Node: 690, Betweenness Centrality: 0.0008892450930988645
# Node: 99, Betweenness Centrality: 0.0008848484275012958
# Node: 67, Betweenness Centrality: 0.0008823223848185277
# Node: 256, Betweenness Centrality: 0.0008815292158277248
# Node: 51, Betweenness Centrality: 0.0008807545717945793
# Node: 833, Betweenness Centrality: 0.0008803160065478879
# Node: 827, Betweenness Centrality: 0.0008780143948103636
# Node: 304, Betweenness Centrality: 0.000874599427544993
# Node: 701, Betweenness Centrality: 0.0008724367397337155
# Node: 825, Betweenness Centrality: 0.0008712012568915889
# Node: 717, Betweenness Centrality: 0.0008676314494658147
# Node: 262, Betweenness Centrality: 0.0008652585561746868
# Node: 60, Betweenness Centrality: 0.000861836986493458
# Node: 963, Betweenness Centrality: 0.000859705484739407
# Node: 902, Betweenness Centrality: 0.0008581967279465123
# Node: 557, Betweenness Centrality: 0.0008574311895112968
# Node: 631, Betweenness Centrality: 0.0008564746770300953
# Node: 913, Betweenness Centrality: 0.0008535582772025006
# Node: 976, Betweenness Centrality: 0.000849647591001422
# Node: 196, Betweenness Centrality: 0.0008491301519441367
# Node: 268, Betweenness Centrality: 0.0008438702082739112
# Node: 52, Betweenness Centrality: 0.0008392285477264393
# Node: 232, Betweenness Centrality: 0.0008367105660839072
# Node: 511, Betweenness Centrality: 0.0008362701698626109
# Node: 576, Betweenness Centrality: 0.000836126078196671
# Node: 676, Betweenness Centrality: 0.0008327971906821349
# Node: 563, Betweenness Centrality: 0.0008299376481331311
# Node: 81, Betweenness Centrality: 0.0008295393285733089
# Node: 994, Betweenness Centrality: 0.000828467094127222
# Node: 190, Betweenness Centrality: 0.0008266703497198018
# Node: 177, Betweenness Centrality: 0.0008261628274100479
# Node: 910, Betweenness Centrality: 0.0008230790343492589
# Node: 772, Betweenness Centrality: 0.0008207792233624768
# Node: 357, Betweenness Centrality: 0.0008202059339380059
# Node: 845, Betweenness Centrality: 0.00081822938389124
# Node: 959, Betweenness Centrality: 0.0008164248189298112
# Node: 90, Betweenness Centrality: 0.0008160298510051889
# Node: 206, Betweenness Centrality: 0.0008156561011736263
# Node: 29, Betweenness Centrality: 0.0008141898390583164
# Node: 216, Betweenness Centrality: 0.0008116541083891378
# Node: 422, Betweenness Centrality: 0.0008087555319263166
# Node: 671, Betweenness Centrality: 0.0008058407053861491
# Node: 673, Betweenness Centrality: 0.0008046035303038638
# Node: 119, Betweenness Centrality: 0.0008025433877946994
# Node: 136, Betweenness Centrality: 0.0008017381842391468
# Node: 776, Betweenness Centrality: 0.0007992723122781628
# Node: 482, Betweenness Centrality: 0.0007984916450551282
# Node: 105, Betweenness Centrality: 0.0007975866623425949
# Node: 826, Betweenness Centrality: 0.000795828961062659
# Node: 272, Betweenness Centrality: 0.0007950498781800786
# Node: 748, Betweenness Centrality: 0.0007941436383564098
# Node: 437, Betweenness Centrality: 0.0007928410784627949
# Node: 844, Betweenness Centrality: 0.00079039368243389
# Node: 679, Betweenness Centrality: 0.0007853064841584443
# Node: 646, Betweenness Centrality: 0.0007851966767279712
# Node: 879, Betweenness Centrality: 0.0007836895156881336
# Node: 736, Betweenness Centrality: 0.0007812150797590943
# Node: 9, Betweenness Centrality: 0.0007801262972190956
# Node: 861, Betweenness Centrality: 0.0007724024766135139
# Node: 55, Betweenness Centrality: 0.0007721126273989871
# Node: 953, Betweenness Centrality: 0.0007703466650839623
# Node: 168, Betweenness Centrality: 0.0007686983732715219
# Node: 683, Betweenness Centrality: 0.0007684231866922193
# Node: 115, Betweenness Centrality: 0.0007663768334859499
# Node: 972, Betweenness Centrality: 0.0007658878374018009
# Node: 220, Betweenness Centrality: 0.0007635029784844293
# Node: 483, Betweenness Centrality: 0.0007581092243021677
# Node: 657, Betweenness Centrality: 0.0007580078822983985
# Node: 54, Betweenness Centrality: 0.00075499695207152
# Node: 720, Betweenness Centrality: 0.0007527618003413581
# Node: 33, Betweenness Centrality: 0.0007524280378264875
# Node: 71, Betweenness Centrality: 0.0007516542770983561
# Node: 351, Betweenness Centrality: 0.0007516474710505151
# Node: 344, Betweenness Centrality: 0.000751556387086907
# Node: 522, Betweenness Centrality: 0.0007494960744988056
# Node: 920, Betweenness Centrality: 0.0007489108427300373
# Node: 161, Betweenness Centrality: 0.0007472227172446542
# Node: 421, Betweenness Centrality: 0.0007465289317332702
# Node: 771, Betweenness Centrality: 0.0007432917355077281
# Node: 400, Betweenness Centrality: 0.0007422426122253541
# Node: 649, Betweenness Centrality: 0.0007380716406538892
# Node: 752, Betweenness Centrality: 0.0007346293588635428
# Node: 150, Betweenness Centrality: 0.0007338460328876487
# Node: 469, Betweenness Centrality: 0.0007293238073074415
# Node: 987, Betweenness Centrality: 0.0007263152359366017
# Node: 547, Betweenness Centrality: 0.0007256176432546578
# Node: 373, Betweenness Centrality: 0.0007241525038190805
# Node: 102, Betweenness Centrality: 0.0007235814942569734
# Node: 849, Betweenness Centrality: 0.0007233250841198423
# Node: 493, Betweenness Centrality: 0.0007222589415722936
# Node: 807, Betweenness Centrality: 0.0007201396549766648
# Node: 614, Betweenness Centrality: 0.0007189325517958998
# Node: 650, Betweenness Centrality: 0.0007181610993784402
# Node: 891, Betweenness Centrality: 0.0007181243534172925
# Node: 66, Betweenness Centrality: 0.0007178798229845419
# Node: 770, Betweenness Centrality: 0.0007133781330807616
# Node: 436, Betweenness Centrality: 0.0007104572258680416
# Node: 466, Betweenness Centrality: 0.0007103694842083404
# Node: 798, Betweenness Centrality: 0.0007102191043258303
# Node: 171, Betweenness Centrality: 0.0007087480760629036
# Node: 355, Betweenness Centrality: 0.0007083969902589549
# Node: 249, Betweenness Centrality: 0.0007077972754498408
# Node: 543, Betweenness Centrality: 0.0007071522126134771
# Node: 575, Betweenness Centrality: 0.0007042005877223247
# Node: 116, Betweenness Centrality: 0.0007018566624006365
# Node: 786, Betweenness Centrality: 0.0006995157843711049
# Node: 454, Betweenness Centrality: 0.0006971793153575273
# Node: 726, Betweenness Centrality: 0.0006970975407863137
# Node: 343, Betweenness Centrality: 0.0006946984070811826
# Node: 615, Betweenness Centrality: 0.0006946397463224219
# Node: 539, Betweenness Centrality: 0.000694617407605077
# Node: 486, Betweenness Centrality: 0.0006934687078330911
# Node: 500, Betweenness Centrality: 0.0006908078890871406
# Node: 42, Betweenness Centrality: 0.0006892108731721728
# Node: 384, Betweenness Centrality: 0.0006891519107182483
# Node: 266, Betweenness Centrality: 0.0006889644938714196
# Node: 541, Betweenness Centrality: 0.0006889286303669865
# Node: 619, Betweenness Centrality: 0.0006871562566352829
# Node: 375, Betweenness Centrality: 0.0006863930024387455
# Node: 217, Betweenness Centrality: 0.0006862206545480897
# Node: 782, Betweenness Centrality: 0.0006855176646806449
# Node: 10, Betweenness Centrality: 0.0006853876076464391
# Node: 985, Betweenness Centrality: 0.0006840455231327861
# Node: 409, Betweenness Centrality: 0.00067689128323003
# Node: 27, Betweenness Centrality: 0.0006763307725393068
# Node: 886, Betweenness Centrality: 0.0006751239829550779
# Node: 155, Betweenness Centrality: 0.000674228630219995
# Node: 624, Betweenness Centrality: 0.0006693611195227934
# Node: 925, Betweenness Centrality: 0.0006649876741270645
# Node: 866, Betweenness Centrality: 0.0006615803756502217
# Node: 659, Betweenness Centrality: 0.0006573125905501389
# Node: 100, Betweenness Centrality: 0.000655537728039921
# Node: 399, Betweenness Centrality: 0.0006553081281229664
# Node: 743, Betweenness Centrality: 0.0006550190204790686
# Node: 265, Betweenness Centrality: 0.0006548657633583763
# Node: 294, Betweenness Centrality: 0.0006536806955083609
# Node: 830, Betweenness Centrality: 0.0006536510640366572
# Node: 135, Betweenness Centrality: 0.0006521045772801234
# Node: 382, Betweenness Centrality: 0.000650592302005176
# Node: 387, Betweenness Centrality: 0.0006502562529816117
# Node: 878, Betweenness Centrality: 0.0006499368115755629
# Node: 397, Betweenness Centrality: 0.0006490952534569914
# Node: 590, Betweenness Centrality: 0.0006488717749038673
# Node: 361, Betweenness Centrality: 0.0006473716917358673
# Node: 458, Betweenness Centrality: 0.0006465345215692084
# Node: 485, Betweenness Centrality: 0.0006450621439771728
# Node: 478, Betweenness Centrality: 0.0006412664863978421
# Node: 700, Betweenness Centrality: 0.0006398494343073666
# Node: 951, Betweenness Centrality: 0.0006389487246508347
# Node: 583, Betweenness Centrality: 0.0006364898912730161
# Node: 372, Betweenness Centrality: 0.0006352563135492226
# Node: 918, Betweenness Centrality: 0.0006328999373503647
# Node: 578, Betweenness Centrality: 0.0006314561027007798
# Node: 616, Betweenness Centrality: 0.0006304625277568363
# Node: 281, Betweenness Centrality: 0.0006295093155190832
# Node: 537, Betweenness Centrality: 0.0006275734983710635
# Node: 442, Betweenness Centrality: 0.0006253442444627182
# Node: 362, Betweenness Centrality: 0.0006219115677834459
# Node: 411, Betweenness Centrality: 0.0006178766774903398
# Node: 187, Betweenness Centrality: 0.0006164911305402655
# Node: 872, Betweenness Centrality: 0.0006156724749948929
# Node: 875, Betweenness Centrality: 0.0006141155419557214
# Node: 554, Betweenness Centrality: 0.0006124138637170191
# Node: 18, Betweenness Centrality: 0.0006122374199016344
# Node: 753, Betweenness Centrality: 0.0006112406582087332
# Node: 222, Betweenness Centrality: 0.0006101718161308229
# Node: 778, Betweenness Centrality: 0.0006096901849777153
# Node: 23, Betweenness Centrality: 0.0006074178483677783
# Node: 314, Betweenness Centrality: 0.0006048014187051442
# Node: 961, Betweenness Centrality: 0.0006043411651943674
# Node: 481, Betweenness Centrality: 0.0006037782282149163
# Node: 181, Betweenness Centrality: 0.0006028790978046919
# Node: 448, Betweenness Centrality: 0.0006018611603969857
# Node: 101, Betweenness Centrality: 0.0006002115899270973
# Node: 211, Betweenness Centrality: 0.0006000547551453388
# Node: 981, Betweenness Centrality: 0.0006000057617832588
# Node: 166, Betweenness Centrality: 0.0005997778511146949
# Node: 950, Betweenness Centrality: 0.0005986137252504183
# Node: 353, Betweenness Centrality: 0.0005932226969133645
# Node: 63, Betweenness Centrality: 0.0005900867496842873
# Node: 818, Betweenness Centrality: 0.0005854945736678748
# Node: 242, Betweenness Centrality: 0.0005854070401712945
# Node: 535, Betweenness Centrality: 0.0005845304698581691
# Node: 577, Betweenness Centrality: 0.0005840366001732217
# Node: 324, Betweenness Centrality: 0.0005835389105524393
# Node: 70, Betweenness Centrality: 0.0005834900156385295
# Node: 365, Betweenness Centrality: 0.0005831422719640541
# Node: 559, Betweenness Centrality: 0.0005814926681630079
# Node: 50, Betweenness Centrality: 0.0005814477226543125
# Node: 179, Betweenness Centrality: 0.0005813969626738121
# Node: 58, Betweenness Centrality: 0.0005797502415153826
# Node: 285, Betweenness Centrality: 0.0005790112985417233
# Node: 383, Betweenness Centrality: 0.0005780000782484124
# Node: 470, Betweenness Centrality: 0.0005749027365299883
# Node: 706, Betweenness Centrality: 0.0005742898952704292
# Node: 107, Betweenness Centrality: 0.000572542190586579
# Node: 685, Betweenness Centrality: 0.000572438352080087
# Node: 451, Betweenness Centrality: 0.0005712673629992205
# Node: 727, Betweenness Centrality: 0.0005705141726631387
# Node: 759, Betweenness Centrality: 0.0005659562935183722
# Node: 91, Betweenness Centrality: 0.0005639896255788871
# Node: 688, Betweenness Centrality: 0.0005610055807579846
# Node: 291, Betweenness Centrality: 0.000560766429098071
# Node: 92, Betweenness Centrality: 0.0005598990585986279
# Node: 88, Betweenness Centrality: 0.0005575697915085703
# Node: 260, Betweenness Centrality: 0.0005552886948373989
# Node: 639, Betweenness Centrality: 0.0005543677533595213
# Node: 494, Betweenness Centrality: 0.0005480935346577814
# Node: 714, Betweenness Centrality: 0.0005473998456486048
# Node: 674, Betweenness Centrality: 0.0005467301020723437
# Node: 973, Betweenness Centrality: 0.000546189188871589
# Node: 524, Betweenness Centrality: 0.0005461331173629207
# Node: 192, Betweenness Centrality: 0.0005411129603171738
# Node: 239, Betweenness Centrality: 0.000540784655981692
# Node: 271, Betweenness Centrality: 0.0005393278336847277
# Node: 299, Betweenness Centrality: 0.0005382650636758286
# Node: 95, Betweenness Centrality: 0.0005354815117233067
# Node: 956, Betweenness Centrality: 0.0005351174036059778
# Node: 197, Betweenness Centrality: 0.0005347159908437798
# Node: 622, Betweenness Centrality: 0.0005303890990239228
# Node: 792, Betweenness Centrality: 0.0005302858646756152
# Node: 189, Betweenness Centrality: 0.000529768560252
# Node: 319, Betweenness Centrality: 0.0005262912305854909
# Node: 999, Betweenness Centrality: 0.0005249505720276602
# Node: 637, Betweenness Centrality: 0.0005244368939261606
# Node: 134, Betweenness Centrality: 0.0005244165012207938
# Node: 516, Betweenness Centrality: 0.0005242380484317091
# Node: 443, Betweenness Centrality: 0.0005239887699352078
# Node: 794, Betweenness Centrality: 0.0005231722918214472
# Node: 404, Betweenness Centrality: 0.0005215894401297469
# Node: 741, Betweenness Centrality: 0.000517235907171112
# Node: 229, Betweenness Centrality: 0.000514028169934095
# Node: 734, Betweenness Centrality: 0.0005122961154523602
# Node: 528, Betweenness Centrality: 0.0005035813140565197
# Node: 504, Betweenness Centrality: 0.000503435953781401
# Node: 475, Betweenness Centrality: 0.0005027399222220308
# Node: 49, Betweenness Centrality: 0.0004998141161616651
# Node: 94, Betweenness Centrality: 0.000499552827879761
# Node: 678, Betweenness Centrality: 0.0004979639740701353
# Node: 668, Betweenness Centrality: 0.0004967587691589865
# Node: 608, Betweenness Centrality: 0.0004967466656795059
# Node: 982, Betweenness Centrality: 0.0004966147992485493
# Node: 340, Betweenness Centrality: 0.0004944556026764989
# Node: 165, Betweenness Centrality: 0.0004921065270918093
# Node: 729, Betweenness Centrality: 0.0004909728001553823
# Node: 675, Betweenness Centrality: 0.00048794238948995645
# Node: 938, Betweenness Centrality: 0.0004857735233631594
# Node: 773, Betweenness Centrality: 0.0004851013616885264
# Node: 46, Betweenness Centrality: 0.0004838568130153621
# Node: 762, Betweenness Centrality: 0.0004837426613812857
# Node: 656, Betweenness Centrality: 0.0004819220352782008
# Node: 358, Betweenness Centrality: 0.00048135460583295203
# Node: 432, Betweenness Centrality: 0.0004800943900812691
# Node: 843, Betweenness Centrality: 0.0004745127988467189
# Node: 164, Betweenness Centrality: 0.0004742533399336137
# Node: 856, Betweenness Centrality: 0.0004742000882345024
# Node: 484, Betweenness Centrality: 0.0004739305199764778
# Node: 517, Betweenness Centrality: 0.0004728520720012476
# Node: 307, Betweenness Centrality: 0.0004715696191535124
# Node: 855, Betweenness Centrality: 0.0004704362475450647
# Node: 707, Betweenness Centrality: 0.0004704061344139816
# Node: 817, Betweenness Centrality: 0.00047034629370270795
# Node: 25, Betweenness Centrality: 0.0004686193737687469
# Node: 427, Betweenness Centrality: 0.000467815472072444
# Node: 710, Betweenness Centrality: 0.00046777666378746135
# Node: 595, Betweenness Centrality: 0.00046710812630238694
# Node: 157, Betweenness Centrality: 0.00046486101951757094
# Node: 836, Betweenness Centrality: 0.00046359126680502004
# Node: 472, Betweenness Centrality: 0.00046093744222434674
# Node: 417, Betweenness Centrality: 0.0004607800175494639
# Node: 284, Betweenness Centrality: 0.00045879370275740146
# Node: 602, Betweenness Centrality: 0.0004584879349380228
# Node: 733, Betweenness Centrality: 0.0004580266008872874
# Node: 863, Betweenness Centrality: 0.0004576594600099513
# Node: 301, Betweenness Centrality: 0.0004548537617302338
# Node: 214, Betweenness Centrality: 0.00045328017657543713
# Node: 410, Betweenness Centrality: 0.0004517681764785245
# Node: 374, Betweenness Centrality: 0.0004513735284653003
# Node: 858, Betweenness Centrality: 0.00044912316284932474
# Node: 320, Betweenness Centrality: 0.0004482350314113129
# Node: 883, Betweenness Centrality: 0.0004473025790958156
# Node: 605, Betweenness Centrality: 0.00044646085563255133
# Node: 502, Betweenness Centrality: 0.0004456388604444055
# Node: 204, Betweenness Centrality: 0.0004415088407221747
# Node: 253, Betweenness Centrality: 0.0004414020143063558
# Node: 721, Betweenness Centrality: 0.00044067185957954606
# Node: 565, Betweenness Centrality: 0.00043950085121943766
# Node: 747, Betweenness Centrality: 0.00043845008428522545
# Node: 381, Betweenness Centrality: 0.0004381921807404725
# Node: 392, Betweenness Centrality: 0.00043699877779924533
# Node: 5, Betweenness Centrality: 0.00043644491345403954
# Node: 612, Betweenness Centrality: 0.00043223383227536204
# Node: 261, Betweenness Centrality: 0.0004259835850068231
# Node: 948, Betweenness Centrality: 0.00042435778532993844
# Node: 790, Betweenness Centrality: 0.0004236841974874731
# Node: 922, Betweenness Centrality: 0.0004196945353540356
# Node: 460, Betweenness Centrality: 0.00041491091682491134
# Node: 757, Betweenness Centrality: 0.00041346409879538924
# Node: 937, Betweenness Centrality: 0.00041302970026740177
# Node: 834, Betweenness Centrality: 0.000410957449651226
# Node: 880, Betweenness Centrality: 0.00041019150192772493
# Node: 435, Betweenness Centrality: 0.0004090078143009597
# Node: 695, Betweenness Centrality: 0.00040889015504027654
# Node: 698, Betweenness Centrality: 0.00040753233084073415
# Node: 899, Betweenness Centrality: 0.00040721675829406693
# Node: 904, Betweenness Centrality: 0.00040259946712027054
# Node: 498, Betweenness Centrality: 0.00039925659556547325
# Node: 750, Betweenness Centrality: 0.0003930493205454963
# Node: 473, Betweenness Centrality: 0.0003921431947551573
# Node: 854, Betweenness Centrality: 0.0003909376310611924
# Node: 966, Betweenness Centrality: 0.0003903201797418603
# Node: 658, Betweenness Centrality: 0.00038985716814701163
# Node: 449, Betweenness Centrality: 0.0003895648865982878
# Node: 737, Betweenness Centrality: 0.0003854198940479756
# Node: 241, Betweenness Centrality: 0.0003831023642775712
# Node: 847, Betweenness Centrality: 0.0003825065428427952
# Node: 0, Betweenness Centrality: 0.0003817935444844613
# Node: 874, Betweenness Centrality: 0.0003816224115406707
# Node: 180, Betweenness Centrality: 0.0003804079621584866
# Node: 363, Betweenness Centrality: 0.000379040235711929
# Node: 723, Betweenness Centrality: 0.00037890966924451595
# Node: 288, Betweenness Centrality: 0.00037871990671743574
# Node: 681, Betweenness Centrality: 0.00037828233963023406
# Node: 911, Betweenness Centrality: 0.0003781909293398177
# Node: 510, Betweenness Centrality: 0.00037496969473042977
# Node: 957, Betweenness Centrality: 0.00037284243268452956
# Node: 611, Betweenness Centrality: 0.00037206969058088847
# Node: 808, Betweenness Centrality: 0.0003702330926396514
# Node: 463, Betweenness Centrality: 0.00036816460536180277
# Node: 804, Betweenness Centrality: 0.0003657994464930997
# Node: 501, Betweenness Centrality: 0.0003639538398687925
# Node: 429, Betweenness Centrality: 0.0003599784397860097
# Node: 488, Betweenness Centrality: 0.00035892450784102796
# Node: 476, Betweenness Centrality: 0.0003583942375993711
# Node: 718, Betweenness Centrality: 0.00035783913164003393
# Node: 338, Betweenness Centrality: 0.00035699661724832217
# Node: 293, Betweenness Centrality: 0.0003566432303771475
# Node: 186, Betweenness Centrality: 0.00035498254074034746
# Node: 693, Betweenness Centrality: 0.0003474394692893374
# Node: 389, Betweenness Centrality: 0.00034700116387170244
# Node: 991, Betweenness Centrality: 0.0003456117754813483
# Node: 287, Betweenness Centrality: 0.0003439995896344984
# Node: 978, Betweenness Centrality: 0.0003426400241758022
# Node: 83, Betweenness Centrality: 0.00034163921860012024
# Node: 607, Betweenness Centrality: 0.0003408160604238162
# Node: 142, Betweenness Centrality: 0.0003389272833871376
# Node: 768, Betweenness Centrality: 0.0003378909916769286
# Node: 912, Betweenness Centrality: 0.00033665517498527995
# Node: 641, Betweenness Centrality: 0.0003366088162376551
# Node: 341, Betweenness Centrality: 0.0003358889086666974
# Node: 441, Betweenness Centrality: 0.00033435206787617636
# Node: 839, Betweenness Centrality: 0.00033382600638851484
# Node: 354, Betweenness Centrality: 0.00033363606590671054
# Node: 781, Betweenness Centrality: 0.00033151321680879457
# Node: 264, Betweenness Centrality: 0.00033115506517737464
# Node: 505, Betweenness Centrality: 0.0003245149049415969
# Node: 431, Betweenness Centrality: 0.00032430193308896366
# Node: 234, Betweenness Centrality: 0.00032018361416838795
# Node: 74, Betweenness Centrality: 0.0003200846834931748
# Node: 813, Betweenness Centrality: 0.0003183879639119919
# Node: 589, Betweenness Centrality: 0.0003183010338398277
# Node: 247, Betweenness Centrality: 0.0003149147478392213
# Node: 548, Betweenness Centrality: 0.0003126404716113463
# Node: 809, Betweenness Centrality: 0.000311096440101696
# Node: 332, Betweenness Centrality: 0.00031022745735524395
# Node: 499, Betweenness Centrality: 0.0003097608568715072
# Node: 509, Betweenness Centrality: 0.00030726916199569153
# Node: 829, Betweenness Centrality: 0.00030506331760147957
# Node: 379, Betweenness Centrality: 0.00030389772896710865
# Node: 221, Betweenness Centrality: 0.00029711844238735323
# Node: 194, Betweenness Centrality: 0.00029558957883239604
# Node: 677, Betweenness Centrality: 0.0002954516144421837
# Node: 255, Betweenness Centrality: 0.0002952339107218979
# Node: 783, Betweenness Centrality: 0.00029403814456204944
# Node: 474, Betweenness Centrality: 0.0002909319075564842
# Node: 390, Betweenness Centrality: 0.00028520899524026955
# Node: 104, Betweenness Centrality: 0.0002851628182356306
# Node: 208, Betweenness Centrality: 0.000284145069591178
# Node: 788, Betweenness Centrality: 0.0002840766483083921
# Node: 907, Betweenness Centrality: 0.0002831500111989992
# Node: 386, Betweenness Centrality: 0.00028121609489771115
# Node: 735, Betweenness Centrality: 0.0002811679252333338
# Node: 37, Betweenness Centrality: 0.00027905486603826106
# Node: 151, Betweenness Centrality: 0.0002770471141711109
# Node: 45, Betweenness Centrality: 0.0002714127756290656
# Node: 884, Betweenness Centrality: 0.0002695342058519593
# Node: 625, Betweenness Centrality: 0.00026865232641515226
# Node: 868, Betweenness Centrality: 0.00026768375436162596
# Node: 962, Betweenness Centrality: 0.00026766784852963357
# Node: 306, Betweenness Centrality: 0.000266413744759695
# Node: 814, Betweenness Centrality: 0.00026628516691965817
# Node: 489, Betweenness Centrality: 0.00026449319653821087
# Node: 939, Betweenness Centrality: 0.0002615278694126336
# Node: 935, Betweenness Centrality: 0.00026080253011653875
# Node: 568, Betweenness Centrality: 0.00025453629324911323
# Node: 992, Betweenness Centrality: 0.00025323187761828114
# Node: 593, Betweenness Centrality: 0.00025041904487160983
# Node: 662, Betweenness Centrality: 0.00024180562908026747
# Node: 774, Betweenness Centrality: 0.00024129119088992177
# Node: 824, Betweenness Centrality: 0.00024068620899885172
# Node: 936, Betweenness Centrality: 0.00022844613981506292
# Node: 426, Betweenness Centrality: 0.00021592104360486085
# Node: 758, Betweenness Centrality: 0.00021525625250754462
# Node: 412, Betweenness Centrality: 0.00021463021393366096
# Node: 960, Betweenness Centrality: 0.00020928355269543935
# Node: 173, Betweenness Centrality: 0.00020314034102202627
# Node: 311, Betweenness Centrality: 0.00019125138449012
# Node: 680, Betweenness Centrality: 0.0001907181056404246
# Node: 754, Betweenness Centrality: 0.0001898644784151984
# Node: 508, Betweenness Centrality: 0.00018556385789209105
# Node: 414, Betweenness Centrality: 0.0001818810624132141
# Node: 562, Betweenness Centrality: 0.00017635331825510716
# Node: 175, Betweenness Centrality: 0.00016969069303601086
# Node: 415, Betweenness Centrality: 0.00016815577243087847
# Node: 828, Betweenness Centrality: 0.0001672251264611407
# Node: 996, Betweenness Centrality: 0.00016666550477874
# Node: 795, Betweenness Centrality: 0.0001584843817115442
# Node: 391, Betweenness Centrality: 0.0001550202942492818
# Node: 898, Betweenness Centrality: 0.0001545778909111011
# Node: 507, Betweenness Centrality: 0.00015235545312941126
# Node: 280, Betweenness Centrality: 0.0001483898471767823
# Node: 716, Betweenness Centrality: 0.00014785180870658822
# Node: 928, Betweenness Centrality: 0.0001476635774887744
# Node: 819, Betweenness Centrality: 0.00014386785310942327
# Node: 464, Betweenness Centrality: 0.00013910640993963094
# Node: 684, Betweenness Centrality: 0.00013570717229137728
# Node: 420, Betweenness Centrality: 0.00012407993808046785
# Node: 424, Betweenness Centrality: 0.00012242204034894246
# Node: 873, Betweenness Centrality: 0.00011714438422589504
# Node: 980, Betweenness Centrality: 0.000104841990166721
# Node: 894, Betweenness Centrality: 9.756823734052948e-05
# Node: 867, Betweenness Centrality: 8.465942216724852e-05
# Node: 371, Betweenness Centrality: 7.861190048602473e-05
# Node: 487, Betweenness Centrality: 6.454183371993409e-05
# Node: 882, Betweenness Centrality: 3.270425788507188e-05
# Node: 848, Betweenness Centrality: 3.167827063136498e-05
# Node: 901, Betweenness Centrality: 2.8386515886483565e-05
# Node: 405, Betweenness Centrality: 2.0507718211923177e-05
# Node: 450, Betweenness Centrality: 2.0198787223368587e-05
