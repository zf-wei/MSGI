# %% [markdown]
# This page is taken from Github: https://github.com/eliorc/node2vec

# %%
### 导入必要的包
import networkx as nx
from node2vec import Node2Vec

# 导入 Karate 示例图
G1 = nx.karate_club_graph()
# Create a graph
G2 = nx.fast_gnp_random_graph(n=100, p=0.5)
graphs = []
graphs.append(G1)
graphs.append(G2)

# %%
### 把图画出来看一看
import matplotlib.pyplot as plt

# Iterate over the graphs in the list
for graph in graphs:
    # Create a new figure for each graph
    plt.figure()
    # Draw the graph with labels
    nx.draw(graph, with_labels=True)
    # Show the figure
    plt.show()

# %%
# Precompute probabilities and generate walks - **ON WINDOWS ONLY WORKS WITH workers=1**
node2vec_G1 = Node2Vec(G1, dimensions=7, walk_length=12, num_walks=50, workers=4)  #, temp_folder='test'
node2vec_G2 = Node2Vec(G2, dimensions=64, walk_length=30, num_walks=200, workers=8)  # Use temp_folder for big graphs
 
# Embed nodes
model_G1 = node2vec_G1.fit(window=10, min_count=1, batch_words=4)  
model_G2 = node2vec_G2.fit(window=10, min_count=1, batch_words=4)  
# Any keywords acceptable by gensim.Word2Vec can be passed, `dimensions` and `workers` are automatically passed (from the Node2Vec constructor)
# Out:
# Computing transition probabilities:   0%|          | 0/34 [00:00<?, ?it/s]
# Generating walks (CPU: 2): 100%|██████████| 13/13 [00:00<00:00, 560.30it/s]
# Computing transition probabilities:   0%|          | 0/100 [00:00<?, ?it/s]
# Generating walks (CPU: 1):  20%|██        | 5/25 [00:00<00:01, 14.32it/s]
# Generating walks (CPU: 2):  16%|█▌        | 4/25 [00:00<00:01, 12.16it/s]
# Generating walks (CPU: 2):  32%|███▏      | 8/25 [00:00<00:01, 12.48it/s]]
# Generating walks (CPU: 8): 100%|██████████| 25/25 [00:00<00:00, 30.84it/s]

# %%
model_G1.wv.save_word2vec_format('Karate_Embedding')

# %%
### 查看图 G1 中与 '0'最相似的顶点
### 注意 使用 node2vec 这个包时 输出的顶点嵌入其index均为文本格式 例如 '0'
model_G1.wv.most_similar('0') 
### 输出的好像是相似度？？
# Out:
# [('11', 0.9781743884086609),
#  ('17', 0.9697080254554749),
#  ('21', 0.9658861756324768),
#  ('19', 0.9620167016983032),
#  ('4', 0.9264954328536987),
#  ('10', 0.9132989645004272),
#  ('7', 0.9038665294647217),
#  ('13', 0.8970332741737366),
#  ('12', 0.8965588808059692),
#  ('1', 0.8957606554031372)]

# %%
### in graph G1, Access the embedding of sample nodes
for i in range(8):
    embedding = model_G1.wv[f'{i}']
    print(f"Node {i} is embedded as vector:\n {embedding}.\n")
# Out:
# Node 0 is embedded as vector:
#  [ 0.58130854  0.17012942 -0.51808506  0.94980943 -0.17053533 -0.25096315
#   0.75718343].
#
# Node 1 is embedded as vector:
#  [ 0.4555947  -0.14601655 -0.18386261  1.1550362  -0.23876141 -0.6585479
#   0.5519599 ].
#
# Node 2 is embedded as vector:
#  [ 0.33702278  0.06936426  0.07627969  0.871485   -0.4725693  -0.3961293
#   0.6318006 ].
#
# Node 3 is embedded as vector:
#  [ 0.8992968  -0.22063284  0.06661174  1.3000962  -0.48512283 -0.46900505
#   0.5905354 ].
#
# Node 4 is embedded as vector:
#  [ 0.7971111   0.68355864 -0.9905997   1.1204858  -0.11836357  0.1603641
#   0.87444043].
#
# Node 5 is embedded as vector:
#  [ 0.91963875  0.9157887  -1.3804488   1.1702656   0.16533582  0.23935913
#   1.2640755 ].
#
# Node 6 is embedded as vector:
#  [ 0.8250236   1.0133669  -1.0852433   0.96655375  0.09212242  0.13033246
#   1.2910007 ].
#
# Node 7 is embedded as vector:
#  [ 0.66968644  0.02717092 -0.08561844  1.2053046  -0.3451202  -0.5591486
#   0.49571612].

# %%
### in graph G2, Access the embedding of sample nodes
for i in range(2):
    embedding = model_G2.wv[f'{i}']
    print(f"Node {i} is embedded as vector:\n {embedding}.\n")
# Out:
# Node 0 is embedded as vector:
#  [-0.05893031 -0.11274283  0.05547985 -0.02056142  0.1235529  -0.04134427
#   0.01531917 -0.1839209  -0.00087034 -0.20024878 -0.00348196 -0.35369572
#  -0.08589537 -0.2854507  -0.02804914  0.25700116 -0.2187484  -0.09311688
#   0.05915911  0.0639288   0.1893801   0.12814215  0.11370027 -0.06116808
#  -0.27133483  0.05423549 -0.16609153 -0.11723673  0.03322718  0.13548282
#  -0.08440395  0.05422127  0.14095764  0.05697052  0.0320578  -0.12412903
#   0.04876497  0.08607432 -0.00248345 -0.20648442  0.18735135 -0.10578103
#   0.0373911  -0.17797825 -0.0485005  -0.0131372   0.41852063  0.07864247
#  -0.06458845  0.07386361 -0.02633422 -0.12083141 -0.02264646 -0.04890119
#   0.11091337  0.05925864  0.0538638  -0.0986519  -0.22258922 -0.02487442
#  -0.02769266  0.03722362 -0.01436724 -0.13231868].
#
# Node 1 is embedded as vector:
#  [ 0.08080408 -0.14673613  0.1589784   0.01940637  0.09003714  0.22091211
#   0.09950085  0.09212779 -0.0702621  -0.07415956  0.07426847 -0.06347225
#  -0.15184267 -0.12996733 -0.01730578  0.32622316 -0.01481719  0.03771228
#  -0.0113889   0.29722598  0.19381319  0.06968041  0.09566914 -0.06996812
#  -0.1053507   0.10970819 -0.00832417 -0.10780302  0.11356037  0.084078
#  -0.16194983  0.1320411   0.04927896 -0.08069386  0.09585831 -0.02183959
#   0.00842419 -0.07323283  0.15869074 -0.03598092  0.13302173 -0.08823489
#  -0.09976279  0.06732437 -0.01281354 -0.02327687  0.07616685 -0.08134413
#   0.0688101   0.07906291  0.0720458   0.04569209  0.06631958  0.16699308
#   0.10977298 -0.08644401  0.0497673  -0.01600136 -0.09075335  0.11225494
#  -0.20599128 -0.20052247 -0.03836557  0.12613618].
