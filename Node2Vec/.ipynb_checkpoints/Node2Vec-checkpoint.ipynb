# %% [markdown]
# This page is taken from Github: https://github.com/eliorc/node2vec

# %%
### 导入必要的包
import networkx as nx
from node2vec import Node2Vec

# 导入 Karate 示例图
G1 = nx.karate_club_graph()
# Create a graph
G2 = nx.fast_gnp_random_graph(n=100, p=0.5)
graphs = []
graphs.append(G1)
graphs.append(G2)

# %%
### 把图画出来看一看
import matplotlib.pyplot as plt

# Iterate over the graphs in the list
for graph in graphs:
    # Create a new figure for each graph
    plt.figure()
    # Draw the graph with labels
    nx.draw(graph, with_labels=True)
    # Show the figure
    plt.show()

# %%
# %%time
# Precompute probabilities and generate walks - **ON WINDOWS ONLY WORKS WITH workers=1**
node2vec_G1 = Node2Vec(G1, dimensions=2, walk_length=12, num_walks=50, workers=32)  #, temp_folder='test'
 
# Embed nodes
model_G1 = node2vec_G1.fit(window=10, min_count=1, batch_words=4)  
# Any keywords acceptable by gensim.Word2Vec can be passed, `dimensions` and `workers` are automatically passed (from the Node2Vec constructor)
model_G1.wv.save_word2vec_format('Karate_Embedding')
# Out:
# Computing transition probabilities:   0%|          | 0/34 [00:00<?, ?it/s]
# Generating walks (CPU: 1): 100%|██████████| 2/2 [00:00<00:00, 660.78it/s]
# Generating walks (CPU: 4): 100%|██████████| 2/2 [00:00<00:00, 500.04it/s]
# Generating walks (CPU: 2): 100%|██████████| 2/2 [00:00<00:00, 804.12it/s]
# Generating walks (CPU: 5): 100%|██████████| 2/2 [00:00<00:00, 782.30it/s]
# Generating walks (CPU: 3): 100%|██████████| 2/2 [00:00<00:00, 821.61it/s]
# Generating walks (CPU: 6): 100%|██████████| 2/2 [00:00<00:00, 815.62it/s]
# Generating walks (CPU: 8): 100%|██████████| 2/2 [00:00<00:00, 633.96it/s]
# Generating walks (CPU: 7): 100%|██████████| 2/2 [00:00<00:00, 800.06it/s]
# Generating walks (CPU: 9): 100%|██████████| 2/2 [00:00<00:00, 642.61it/s]
# Generating walks (CPU: 10): 100%|██████████| 2/2 [00:00<00:00, 801.59it/s]
# Generating walks (CPU: 13): 100%|██████████| 2/2 [00:00<00:00, 800.97it/s]
# Generating walks (CPU: 11): 100%|██████████| 2/2 [00:00<00:00, 792.65it/s]
# Generating walks (CPU: 18): 100%|██████████| 2/2 [00:00<00:00, 812.22it/s]
# Generating walks (CPU: 12): 100%|██████████| 2/2 [00:00<00:00, 801.51it/s]
# Generating walks (CPU: 14): 100%|██████████| 2/2 [00:00<00:00, 809.79it/s]
# Generating walks (CPU: 17): 100%|██████████| 2/2 [00:00<00:00, 805.67it/s]
# Generating walks (CPU: 20): 100%|██████████| 1/1 [00:00<00:00, 762.88it/s]
# Generating walks (CPU: 26): 100%|██████████| 1/1 [00:00<00:00, 765.38it/s]
# Generating walks (CPU: 16): 100%|██████████| 2/2 [00:00<00:00, 832.04it/s]
# Generating walks (CPU: 23): 100%|██████████| 1/1 [00:00<00:00, 781.94it/s]
# Generating walks (CPU: 22): 100%|██████████| 1/1 [00:00<00:00, 793.17it/s]
# Generating walks (CPU: 24): 100%|██████████| 1/1 [00:00<00:00, 797.70it/s]
# Generating walks (CPU: 19): 100%|██████████| 1/1 [00:00<00:00, 750.73it/s]
# Generating walks (CPU: 25): 100%|██████████| 1/1 [00:00<00:00, 795.73it/s]
# Generating walks (CPU: 31): 100%|██████████| 1/1 [00:00<00:00, 789.00it/s]
# Generating walks (CPU: 15): 100%|██████████| 2/2 [00:00<00:00, 800.97it/s]
# Generating walks (CPU: 27): 100%|██████████| 1/1 [00:00<00:00, 753.02it/s]
# Generating walks (CPU: 29): 100%|██████████| 1/1 [00:00<00:00, 796.64it/s]
# Generating walks (CPU: 21): 100%|██████████| 1/1 [00:00<00:00, 796.19it/s]
# Generating walks (CPU: 32): 100%|██████████| 1/1 [00:00<00:00, 714.29it/s]
# Generating walks (CPU: 28): 100%|██████████| 1/1 [00:00<00:00, 758.19it/s]
# Generating walks (CPU: 30): 100%|██████████| 1/1 [00:00<00:00, 766.22it/s]
# CPU times: user 926 ms, sys: 515 ms, total: 1.44 s
# Wall time: 7.41 s

# %%
# %%time
# Precompute probabilities and generate walks - **ON WINDOWS ONLY WORKS WITH workers=1**
node2vec_G2 = Node2Vec(G2, dimensions=64, walk_length=30, num_walks=200, workers=32) #, temp_folder='test' # Use temp_folder for big graphs
 
# Embed nodes 
model_G2 = node2vec_G2.fit(window=10, min_count=1, batch_words=4)  
# Any keywords acceptable by gensim.Word2Vec can be passed, `dimensions` and `workers` are automatically passed (from the Node2Vec constructor)
# Out:
# Computing transition probabilities:   0%|          | 0/100 [00:00<?, ?it/s]
# Generating walks (CPU: 1): 100%|██████████| 7/7 [00:00<00:00, 62.67it/s]
# Generating walks (CPU: 2): 100%|██████████| 7/7 [00:00<00:00, 60.59it/s]
# Generating walks (CPU: 3): 100%|██████████| 7/7 [00:00<00:00, 59.65it/s]
# Generating walks (CPU: 4): 100%|██████████| 7/7 [00:00<00:00, 60.70it/s]
# Generating walks (CPU: 5): 100%|██████████| 7/7 [00:00<00:00, 59.09it/s]
# Generating walks (CPU: 6): 100%|██████████| 7/7 [00:00<00:00, 58.40it/s]
# Generating walks (CPU: 7): 100%|██████████| 7/7 [00:00<00:00, 58.56it/s]
# Generating walks (CPU: 8): 100%|██████████| 7/7 [00:00<00:00, 58.53it/s]
# Generating walks (CPU: 9): 100%|██████████| 6/6 [00:00<00:00, 56.92it/s]
# Generating walks (CPU: 10): 100%|██████████| 6/6 [00:00<00:00, 55.46it/s]
# Generating walks (CPU: 11): 100%|██████████| 6/6 [00:00<00:00, 54.49it/s]
# Generating walks (CPU: 12): 100%|██████████| 6/6 [00:00<00:00, 57.88it/s]
# Generating walks (CPU: 13): 100%|██████████| 6/6 [00:00<00:00, 60.07it/s]
# Generating walks (CPU: 14): 100%|██████████| 6/6 [00:00<00:00, 60.05it/s]
# Generating walks (CPU: 15): 100%|██████████| 6/6 [00:00<00:00, 58.77it/s]
# Generating walks (CPU: 16): 100%|██████████| 6/6 [00:00<00:00, 58.83it/s]
# Generating walks (CPU: 17): 100%|██████████| 6/6 [00:00<00:00, 59.92it/s]
# Generating walks (CPU: 18): 100%|██████████| 6/6 [00:00<00:00, 57.19it/s]
# Generating walks (CPU: 19): 100%|██████████| 6/6 [00:00<00:00, 56.89it/s]
# Generating walks (CPU: 20): 100%|██████████| 6/6 [00:00<00:00, 58.56it/s]
# Generating walks (CPU: 21): 100%|██████████| 6/6 [00:00<00:00, 58.28it/s]
# Generating walks (CPU: 22): 100%|██████████| 6/6 [00:00<00:00, 56.01it/s]
# Generating walks (CPU: 23): 100%|██████████| 6/6 [00:00<00:00, 54.54it/s]
# Generating walks (CPU: 24): 100%|██████████| 6/6 [00:00<00:00, 56.39it/s]
# Generating walks (CPU: 25): 100%|██████████| 6/6 [00:00<00:00, 57.01it/s]
# Generating walks (CPU: 26): 100%|██████████| 6/6 [00:00<00:00, 57.50it/s]
# Generating walks (CPU: 27): 100%|██████████| 6/6 [00:00<00:00, 56.18it/s]
# Generating walks (CPU: 28): 100%|██████████| 6/6 [00:00<00:00, 57.37it/s]
# Generating walks (CPU: 29): 100%|██████████| 6/6 [00:00<00:00, 58.44it/s]
# Generating walks (CPU: 30): 100%|██████████| 6/6 [00:00<00:00, 59.11it/s]
# Generating walks (CPU: 31): 100%|██████████| 6/6 [00:00<00:00, 59.44it/s]
# Generating walks (CPU: 32): 100%|██████████| 6/6 [00:00<00:00, 59.24it/s]
# CPU times: user 29.4 s, sys: 4.31 s, total: 33.7 s
# Wall time: 18 s

# %%
### 查看图 G1 中与 '0'最相似的顶点
### 注意 使用 node2vec 这个包时 输出的顶点嵌入其index均为文本格式 例如 '0'
model_G1.wv.most_similar('0') 
### 输出的好像是相似度？？
# Out:
# [('17', 0.9999266862869263),
#  ('21', 0.9999251961708069),
#  ('11', 0.9992495775222778),
#  ('3', 0.9962749481201172),
#  ('12', 0.9955428242683411),
#  ('19', 0.9854784607887268),
#  ('1', 0.9852137565612793),
#  ('7', 0.9841011762619019),
#  ('4', 0.9838612079620361),
#  ('10', 0.9780518412590027)]

# %%
### in graph G1, Access the embedding of sample nodes
for i in range(8):
    embedding = model_G1.wv[f'{i}']
    print(f"Node {i} is embedded as vector:\n {embedding}.\n")
# Out:
# Node 0 is embedded as vector:
#  [0.5493765 1.3898652].
#
# Node 1 is embedded as vector:
#  [0.25047794 1.2092539 ].
#
# Node 2 is embedded as vector:
#  [-0.08778766  1.1098287 ].
#
# Node 3 is embedded as vector:
#  [0.38539177 1.2910795 ].
#
# Node 4 is embedded as vector:
#  [1.1501303 1.8495456].
#
# Node 5 is embedded as vector:
#  [1.3619592 1.9863718].
#
# Node 6 is embedded as vector:
#  [1.4530252 2.069444 ].
#
# Node 7 is embedded as vector:
#  [0.23989788 1.1965444 ].

# %%
### in graph G2, Access the embedding of sample nodes
for i in range(2):
    embedding = model_G2.wv[f'{i}']
    print(f"Node {i} is embedded as vector:\n {embedding}.\n")
# Out:
# Node 0 is embedded as vector:
#  [ 0.11251201 -0.09524635  0.07638573 -0.17831495 -0.08444777 -0.08059543
#   0.08088831  0.02025558 -0.04872738 -0.00075422  0.12084319 -0.10758826
#  -0.20305364  0.08765397  0.15490884  0.07603149  0.08459675 -0.05094089
#   0.10953616 -0.10000283  0.10614482  0.0651001   0.11386516 -0.17857072
#  -0.07356254 -0.03576253 -0.20323677 -0.08703682  0.02801951  0.0694361
#  -0.25196826  0.15002336 -0.04642775  0.07203269 -0.20573819  0.02571173
#   0.02929251  0.01423665  0.14780541  0.08620761  0.14996886 -0.01154684
#   0.08201016 -0.12465835 -0.13930683 -0.07045386  0.0246959  -0.01801174
#  -0.02598001  0.09009872 -0.0573309   0.00700131  0.02177969  0.2667991
#   0.24478269  0.07039394  0.01108678 -0.0138866   0.04642399  0.30247694
#   0.01077677 -0.08118538 -0.15410092  0.10456073].
#
# Node 1 is embedded as vector:
#  [ 0.08027326 -0.10476962  0.08032291  0.04215852  0.15366027  0.04179044
#  -0.1228387  -0.04937226 -0.07157284 -0.15474433 -0.13563597 -0.09481623
#  -0.17155449 -0.09394418  0.01963922  0.08860526  0.16447465 -0.17286558
#  -0.12536287  0.22480531  0.14370139  0.128908    0.32919148 -0.19538371
#   0.04645487 -0.05489663 -0.13119693 -0.05666509 -0.08541939 -0.01114355
#   0.0105097  -0.15222038 -0.24828222 -0.16881375  0.16300434  0.15555494
#  -0.10815749 -0.18574072  0.12527516  0.07476318 -0.07258266 -0.13239492
#   0.11481148 -0.15351185 -0.03218083 -0.04346339 -0.07576469 -0.00884444
#   0.21112147 -0.11722557 -0.24668707  0.09038484  0.16947374  0.07989712
#  -0.01320004  0.08529928  0.16047919 -0.04576084  0.09539156  0.24924329
#  -0.01986105  0.0565168  -0.1896296  -0.27180332].
