# %%
import warnings

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
### 使用 networkx 包中的函数 LFR_benchmark_graph 生成随机图
import networkx as nx
from networkx.generators.community import LFR_benchmark_graph

n = 1000
tau1 = 2  # Power-law exponent for the degree distribution
tau2 = 1.1 # Power-law exponent for the community size distribution 
            #S hould be >1
mu = 0.05 # Mixing parameter
avg_deg = 25 # Average Degree
max_deg = 100 # Max Degree
min_commu = 80 # Min Community Size
max_commu = 100 # Max Community Size

G = LFR_benchmark_graph(
    n, tau1, tau2, mu, average_degree=avg_deg, max_degree=max_deg, min_community=min_commu, max_community=max_commu, 
    seed=7
)
### 去掉 G 中的重边和自环 
G = nx.Graph(G) # Remove multi-edges

selfloop_edges = list(nx.selfloop_edges(G)) # a list of self loops

G.remove_edges_from(selfloop_edges) # Remove self-loops

# %%
betweenness = nx.betweenness_centrality(G)
top_nodes = sorted(betweenness, key=betweenness.get, reverse=True)

# %%
### LFR 图是有内在的社群结构的，每个节点的社群存储在其 community 属性中，是一个 set
# 通过运行循环，按照内在的社群结构给每个节点一个标签 即为其 intrinsic_membership
# 为了方便 intrinsic_membership 一开始是作为一个 np array 存储的
import numpy as np
intrinsic_communities = {frozenset(G.nodes[v]["community"]) for v in G}
intrinsic_membership = np.empty(G.number_of_nodes(), dtype=int)
for node in range(G.number_of_nodes()):
    for index, inner_set in enumerate(intrinsic_communities):
        if node in inner_set:
            intrinsic_membership[node] = index
            break
# intrinsic_membership = list(intrinsic_membership.values())

# 存储 list 和 clustering 格式的拷贝 省得以后需要再做类型转换了
#intrinsic_list = list(intrinsic_membership.values())
#from clusim.clustering import Clustering
#intrinsic_clustering = Clustering(elm2clu_dict={i: [intrinsic_membership[i]] for i in intrinsic_membership.keys()})

# %%
intrinsic_membership;

# %%
idx = [True] * G.number_of_nodes()

# %%
from auxpack.lle import lle
from auxpack.evaluate_embd702temp import evaluate_embd as EEE

from karateclub import DeepWalk

from ge import LINE

D=20
quxian =[]
for i in top_nodes:
    G.remove_node(i)
    print(f"Vertex {i}, ranking {top_nodes.index(i)+1} is removed.", end=' ')
    if not nx.is_connected(G):
        print("G is now disconnected!!")
        break
    embd = lle(G, 20)
    idx[i] = False
    K = len(np.unique(intrinsic_membership[idx]))
    defen = EEE(K, intrinsic_membership[idx], embd)
    quxian.append(defen)
    print(f"{K} clusters; {G.number_of_nodes()} vertices; NMI", defen)
# Out:
# Vertex 661, ranking 1 is removed. 11 clusters; 999 vertices; NMI 0.9616558117495001
# Vertex 822, ranking 2 is removed. 11 clusters; 998 vertices; NMI 1.0
# Vertex 979, ranking 3 is removed. 11 clusters; 997 vertices; NMI 1.0
# Vertex 39, ranking 4 is removed. 11 clusters; 996 vertices; NMI 1.0
# Vertex 853, ranking 5 is removed. 11 clusters; 995 vertices; NMI 1.0
# Vertex 888, ranking 6 is removed. 11 clusters; 994 vertices; NMI 0.97648219951477
# Vertex 57, ranking 7 is removed. 11 clusters; 993 vertices; NMI 1.0
# Vertex 252, ranking 8 is removed. 11 clusters; 992 vertices; NMI 1.0
# Vertex 40, ranking 9 is removed. 11 clusters; 991 vertices; NMI 1.0
# Vertex 591, ranking 10 is removed. 11 clusters; 990 vertices; NMI 1.0
# Vertex 652, ranking 11 is removed. 11 clusters; 989 vertices; NMI 1.0
# Vertex 352, ranking 12 is removed. 11 clusters; 988 vertices; NMI 1.0
# Vertex 917, ranking 13 is removed. 11 clusters; 987 vertices; NMI 0.9676529150830724
# Vertex 356, ranking 14 is removed. 11 clusters; 986 vertices; NMI 0.9999999999999998
# Vertex 297, ranking 15 is removed. 11 clusters; 985 vertices; NMI 1.0
# Vertex 274, ranking 16 is removed. 11 clusters; 984 vertices; NMI 0.9999999999999998
# Vertex 394, ranking 17 is removed. 11 clusters; 983 vertices; NMI 1.0
# Vertex 728, ranking 18 is removed. 11 clusters; 982 vertices; NMI 1.0
# Vertex 629, ranking 19 is removed. 11 clusters; 981 vertices; NMI 1.0
# Vertex 210, ranking 20 is removed. 11 clusters; 980 vertices; NMI 1.0
# Vertex 906, ranking 21 is removed. 11 clusters; 979 vertices; NMI 1.0
# Vertex 722, ranking 22 is removed. 11 clusters; 978 vertices; NMI 1.0
# Vertex 225, ranking 23 is removed. 11 clusters; 977 vertices; NMI 1.0
# Vertex 323, ranking 24 is removed. 11 clusters; 976 vertices; NMI 1.0
# Vertex 803, ranking 25 is removed. 11 clusters; 975 vertices; NMI 1.0
# Vertex 360, ranking 26 is removed. 11 clusters; 974 vertices; NMI 1.0
# Vertex 113, ranking 27 is removed. 11 clusters; 973 vertices; NMI 1.0
# Vertex 62, ranking 28 is removed. 11 clusters; 972 vertices; NMI 0.9586445867633907
# Vertex 889, ranking 29 is removed. 11 clusters; 971 vertices; NMI 0.9999999999999998
# Vertex 892, ranking 30 is removed. 11 clusters; 970 vertices; NMI 1.0
# Vertex 378, ranking 31 is removed. 11 clusters; 969 vertices; NMI 1.0000000000000002
# Vertex 185, ranking 32 is removed. 11 clusters; 968 vertices; NMI 1.0
# Vertex 561, ranking 33 is removed. 11 clusters; 967 vertices; NMI 0.9999999999999998
# Vertex 497, ranking 34 is removed. 11 clusters; 966 vertices; NMI 0.9606281289795302
# Vertex 182, ranking 35 is removed. 11 clusters; 965 vertices; NMI 1.0
# Vertex 613, ranking 36 is removed. 11 clusters; 964 vertices; NMI 1.0000000000000002
# Vertex 282, ranking 37 is removed. 11 clusters; 963 vertices; NMI 1.0
# Vertex 626, ranking 38 is removed. 11 clusters; 962 vertices; NMI 1.0
# Vertex 170, ranking 39 is removed. 11 clusters; 961 vertices; NMI 1.0
# Vertex 65, ranking 40 is removed. 11 clusters; 960 vertices; NMI 1.0
# Vertex 993, ranking 41 is removed. 11 clusters; 959 vertices; NMI 1.0
# Vertex 820, ranking 42 is removed. 11 clusters; 958 vertices; NMI 1.0
# Vertex 342, ranking 43 is removed. 11 clusters; 957 vertices; NMI 1.0
# Vertex 108, ranking 44 is removed. 11 clusters; 956 vertices; NMI 1.0
# Vertex 573, ranking 45 is removed. 11 clusters; 955 vertices; NMI 1.0
# Vertex 704, ranking 46 is removed. 11 clusters; 954 vertices; NMI 0.9999999999999998
# Vertex 96, ranking 47 is removed. 11 clusters; 953 vertices; NMI 0.9999999999999998
# Vertex 947, ranking 48 is removed. 11 clusters; 952 vertices; NMI 1.0
# Vertex 235, ranking 49 is removed. 11 clusters; 951 vertices; NMI 1.0
# Vertex 32, ranking 50 is removed. 11 clusters; 950 vertices; NMI 1.0
# Vertex 895, ranking 51 is removed. 11 clusters; 949 vertices; NMI 1.0
# Vertex 974, ranking 52 is removed. 11 clusters; 948 vertices; NMI 1.0
# Vertex 495, ranking 53 is removed. 11 clusters; 947 vertices; NMI 1.0
# Vertex 988, ranking 54 is removed. 11 clusters; 946 vertices; NMI 1.0
# Vertex 243, ranking 55 is removed. 11 clusters; 945 vertices; NMI 1.0
# Vertex 597, ranking 56 is removed. 11 clusters; 944 vertices; NMI 1.0
# Vertex 393, ranking 57 is removed. 11 clusters; 943 vertices; NMI 1.0
# Vertex 198, ranking 58 is removed. 11 clusters; 942 vertices; NMI 1.0
# Vertex 118, ranking 59 is removed. 11 clusters; 941 vertices; NMI 1.0
# Vertex 984, ranking 60 is removed. 11 clusters; 940 vertices; NMI 0.9724555677723071
# Vertex 126, ranking 61 is removed. 11 clusters; 939 vertices; NMI 1.0
# Vertex 7, ranking 62 is removed. 11 clusters; 938 vertices; NMI 1.0
# Vertex 965, ranking 63 is removed. 11 clusters; 937 vertices; NMI 0.9678954094174577
# Vertex 653, ranking 64 is removed. 11 clusters; 936 vertices; NMI 1.0
# Vertex 760, ranking 65 is removed. 11 clusters; 935 vertices; NMI 0.9590163337208094
# Vertex 821, ranking 66 is removed. 11 clusters; 934 vertices; NMI 1.0
# Vertex 38, ranking 67 is removed. 11 clusters; 933 vertices; NMI 0.9685904627891059
# Vertex 763, ranking 68 is removed. 11 clusters; 932 vertices; NMI 1.0
# Vertex 254, ranking 69 is removed. 11 clusters; 931 vertices; NMI 1.0
# Vertex 227, ranking 70 is removed. 11 clusters; 930 vertices; NMI 1.0
# Vertex 525, ranking 71 is removed. 11 clusters; 929 vertices; NMI 0.9999999999999998
# Vertex 691, ranking 72 is removed. 11 clusters; 928 vertices; NMI 1.0
# Vertex 248, ranking 73 is removed. 11 clusters; 927 vertices; NMI 1.0
# Vertex 21, ranking 74 is removed. 11 clusters; 926 vertices; NMI 1.0000000000000002
# Vertex 975, ranking 75 is removed. 11 clusters; 925 vertices; NMI 0.9999999999999998
# Vertex 433, ranking 76 is removed. 11 clusters; 924 vertices; NMI 1.0
# Vertex 542, ranking 77 is removed. 11 clusters; 923 vertices; NMI 1.0
# Vertex 258, ranking 78 is removed. 11 clusters; 922 vertices; NMI 1.0
# Vertex 380, ranking 79 is removed. 11 clusters; 921 vertices; NMI 1.0
# Vertex 4, ranking 80 is removed. 11 clusters; 920 vertices; NMI 1.0
# Vertex 527, ranking 81 is removed. 11 clusters; 919 vertices; NMI 1.0
# Vertex 326, ranking 82 is removed. 11 clusters; 918 vertices; NMI 1.0
# Vertex 98, ranking 83 is removed. 11 clusters; 917 vertices; NMI 1.0
# Vertex 41, ranking 84 is removed. 11 clusters; 916 vertices; NMI 1.0
# Vertex 467, ranking 85 is removed. 11 clusters; 915 vertices; NMI 1.0000000000000002
# Vertex 893, ranking 86 is removed. 11 clusters; 914 vertices; NMI 1.0
# Vertex 766, ranking 87 is removed. 11 clusters; 913 vertices; NMI 0.9613678319624678
# Vertex 609, ranking 88 is removed. 11 clusters; 912 vertices; NMI 1.0
# Vertex 3, ranking 89 is removed. 11 clusters; 911 vertices; NMI 1.0
# Vertex 526, ranking 90 is removed. 11 clusters; 910 vertices; NMI 1.0000000000000002
# Vertex 724, ranking 91 is removed. 11 clusters; 909 vertices; NMI 0.9754357025332105
# Vertex 317, ranking 92 is removed. 11 clusters; 908 vertices; NMI 0.9999999999999998
# Vertex 193, ranking 93 is removed. 11 clusters; 907 vertices; NMI 1.0
# Vertex 909, ranking 94 is removed. 11 clusters; 906 vertices; NMI 1.0
# Vertex 444, ranking 95 is removed. 11 clusters; 905 vertices; NMI 1.0
# Vertex 346, ranking 96 is removed. 11 clusters; 904 vertices; NMI 1.0
# Vertex 328, ranking 97 is removed. 11 clusters; 903 vertices; NMI 1.0
# Vertex 560, ranking 98 is removed. 11 clusters; 902 vertices; NMI 1.0
# Vertex 183, ranking 99 is removed. 11 clusters; 901 vertices; NMI 1.0
# Vertex 654, ranking 100 is removed. 11 clusters; 900 vertices; NMI 1.0
# Vertex 600, ranking 101 is removed. 11 clusters; 899 vertices; NMI 1.0
# Vertex 169, ranking 102 is removed. 11 clusters; 898 vertices; NMI 1.0
# Vertex 240, ranking 103 is removed. 11 clusters; 897 vertices; NMI 1.0
# Vertex 87, ranking 104 is removed. 11 clusters; 896 vertices; NMI 1.0
# Vertex 640, ranking 105 is removed. 11 clusters; 895 vertices; NMI 1.0
# Vertex 11, ranking 106 is removed. 11 clusters; 894 vertices; NMI 1.0
# Vertex 805, ranking 107 is removed. 11 clusters; 893 vertices; NMI 0.9999999999999998
# Vertex 900, ranking 108 is removed. 11 clusters; 892 vertices; NMI 0.9999999999999998
# Vertex 188, ranking 109 is removed. 11 clusters; 891 vertices; NMI 0.9999999999999998
# Vertex 114, ranking 110 is removed. 11 clusters; 890 vertices; NMI 0.9999999999999998
# Vertex 689, ranking 111 is removed. 11 clusters; 889 vertices; NMI 0.9764661097950629
# Vertex 125, ranking 112 is removed. 11 clusters; 888 vertices; NMI 1.0
# Vertex 73, ranking 113 is removed. 11 clusters; 887 vertices; NMI 1.0000000000000002
# Vertex 84, ranking 114 is removed. 11 clusters; 886 vertices; NMI 1.0
# Vertex 857, ranking 115 is removed. 11 clusters; 885 vertices; NMI 1.0
# Vertex 594, ranking 116 is removed. 11 clusters; 884 vertices; NMI 1.0
# Vertex 263, ranking 117 is removed. 11 clusters; 883 vertices; NMI 1.0
# Vertex 592, ranking 118 is removed. 11 clusters; 882 vertices; NMI 1.0
# Vertex 162, ranking 119 is removed. 11 clusters; 881 vertices; NMI 0.9718772460297973
# Vertex 347, ranking 120 is removed. 11 clusters; 880 vertices; NMI 1.0
# Vertex 139, ranking 121 is removed. 11 clusters; 879 vertices; NMI 1.0000000000000002
# Vertex 955, ranking 122 is removed. 11 clusters; 878 vertices; NMI 1.0
# Vertex 1, ranking 123 is removed. 11 clusters; 877 vertices; NMI 0.9999999999999998
# Vertex 408, ranking 124 is removed. 11 clusters; 876 vertices; NMI 0.9685297788220177
# Vertex 764, ranking 125 is removed. 11 clusters; 875 vertices; NMI 0.9293406756803925
# Vertex 558, ranking 126 is removed. 11 clusters; 874 vertices; NMI 1.0
# Vertex 269, ranking 127 is removed. 11 clusters; 873 vertices; NMI 1.0
# Vertex 603, ranking 128 is removed. 11 clusters; 872 vertices; NMI 1.0
# Vertex 202, ranking 129 is removed. 11 clusters; 871 vertices; NMI 0.9737727061769657
# Vertex 128, ranking 130 is removed. 11 clusters; 870 vertices; NMI 0.9780168494144871
# Vertex 333, ranking 131 is removed. 11 clusters; 869 vertices; NMI 0.9788618830631246
# Vertex 632, ranking 132 is removed. 11 clusters; 868 vertices; NMI 1.0
# Vertex 89, ranking 133 is removed. 11 clusters; 867 vertices; NMI 1.0
# Vertex 921, ranking 134 is removed. 11 clusters; 866 vertices; NMI 0.9741119057706872
# Vertex 75, ranking 135 is removed. 11 clusters; 865 vertices; NMI 1.0
# Vertex 812, ranking 136 is removed. 11 clusters; 864 vertices; NMI 1.0
# Vertex 459, ranking 137 is removed. 11 clusters; 863 vertices; NMI 0.9746255275319902
# Vertex 713, ranking 138 is removed. 11 clusters; 862 vertices; NMI 1.0
# Vertex 796, ranking 139 is removed. 11 clusters; 861 vertices; NMI 1.0
# Vertex 158, ranking 140 is removed. 11 clusters; 860 vertices; NMI 1.0
# Vertex 687, ranking 141 is removed. 11 clusters; 859 vertices; NMI 0.9684694033630021
# Vertex 506, ranking 142 is removed. 11 clusters; 858 vertices; NMI 1.0
# Vertex 416, ranking 143 is removed. 11 clusters; 857 vertices; NMI 0.9711593415554436
# Vertex 775, ranking 144 is removed. 11 clusters; 856 vertices; NMI 1.0
# Vertex 457, ranking 145 is removed. 11 clusters; 855 vertices; NMI 1.0
# Vertex 270, ranking 146 is removed. 11 clusters; 854 vertices; NMI 1.0
# Vertex 19, ranking 147 is removed. 11 clusters; 853 vertices; NMI 0.9800214121772439
# Vertex 967, ranking 148 is removed. 11 clusters; 852 vertices; NMI 1.0
# Vertex 418, ranking 149 is removed. 11 clusters; 851 vertices; NMI 0.9487972316396849
# Vertex 838, ranking 150 is removed. 11 clusters; 850 vertices; NMI 0.9777709790174061
# Vertex 26, ranking 151 is removed. 11 clusters; 849 vertices; NMI 1.0
# Vertex 520, ranking 152 is removed. 11 clusters; 848 vertices; NMI 1.0000000000000002
# Vertex 852, ranking 153 is removed. 11 clusters; 847 vertices; NMI 1.0000000000000002
# Vertex 916, ranking 154 is removed. 11 clusters; 846 vertices; NMI 1.0
# Vertex 231, ranking 155 is removed. 11 clusters; 845 vertices; NMI 1.0
# Vertex 325, ranking 156 is removed. 11 clusters; 844 vertices; NMI 0.9738530201485287
# Vertex 725, ranking 157 is removed. 11 clusters; 843 vertices; NMI 0.9999999999999998
# Vertex 430, ranking 158 is removed. 11 clusters; 842 vertices; NMI 0.9741285084377761
# Vertex 479, ranking 159 is removed. 11 clusters; 841 vertices; NMI 1.0000000000000002
# Vertex 536, ranking 160 is removed. 11 clusters; 840 vertices; NMI 0.9737957429598785
# Vertex 846, ranking 161 is removed. 11 clusters; 839 vertices; NMI 1.0
# Vertex 620, ranking 162 is removed. 11 clusters; 838 vertices; NMI 1.0
# Vertex 446, ranking 163 is removed. 11 clusters; 837 vertices; NMI 0.9606525198968252
# Vertex 952, ranking 164 is removed. 11 clusters; 836 vertices; NMI 1.0
# Vertex 298, ranking 165 is removed. 11 clusters; 835 vertices; NMI 0.9615752058475763
# Vertex 452, ranking 166 is removed. 11 clusters; 834 vertices; NMI 1.0000000000000002
# Vertex 742, ranking 167 is removed. 11 clusters; 833 vertices; NMI 0.9999999999999998
# Vertex 455, ranking 168 is removed. 11 clusters; 832 vertices; NMI 1.0
# Vertex 395, ranking 169 is removed. 11 clusters; 831 vertices; NMI 0.9727580026000594
# Vertex 109, ranking 170 is removed. 11 clusters; 830 vertices; NMI 1.0
# Vertex 296, ranking 171 is removed. 11 clusters; 829 vertices; NMI 1.0
# Vertex 995, ranking 172 is removed. 11 clusters; 828 vertices; NMI 0.9999999999999998
# Vertex 267, ranking 173 is removed. 11 clusters; 827 vertices; NMI 0.9718676190279973
# Vertex 862, ranking 174 is removed. 11 clusters; 826 vertices; NMI 0.9775834028633332
# Vertex 697, ranking 175 is removed. 11 clusters; 825 vertices; NMI 1.0
# Vertex 230, ranking 176 is removed. 11 clusters; 824 vertices; NMI 0.9610012147236586
# Vertex 755, ranking 177 is removed. 11 clusters; 823 vertices; NMI 0.9999999999999998
# Vertex 215, ranking 178 is removed. 11 clusters; 822 vertices; NMI 1.0
# Vertex 148, ranking 179 is removed. 11 clusters; 821 vertices; NMI 1.0
# Vertex 519, ranking 180 is removed. 11 clusters; 820 vertices; NMI 1.0
# Vertex 840, ranking 181 is removed. 11 clusters; 819 vertices; NMI 1.0
# Vertex 942, ranking 182 is removed. 11 clusters; 818 vertices; NMI 0.9768551412892321
# Vertex 515, ranking 183 is removed. 11 clusters; 817 vertices; NMI 0.9744386500011256
# Vertex 34, ranking 184 is removed. 11 clusters; 816 vertices; NMI 1.0
# Vertex 77, ranking 185 is removed. 11 clusters; 815 vertices; NMI 1.0000000000000002
# Vertex 789, ranking 186 is removed. 11 clusters; 814 vertices; NMI 0.9690936034618012
# Vertex 132, ranking 187 is removed. 11 clusters; 813 vertices; NMI 1.0
# Vertex 941, ranking 188 is removed. 11 clusters; 812 vertices; NMI 0.9409005344956863
# Vertex 671, ranking 189 is removed. 11 clusters; 811 vertices; NMI 0.9798029475610681
# Vertex 201, ranking 190 is removed. 11 clusters; 810 vertices; NMI 1.0
# Vertex 968, ranking 191 is removed. 11 clusters; 809 vertices; NMI 1.0
# Vertex 983, ranking 192 is removed. 11 clusters; 808 vertices; NMI 1.0
# Vertex 582, ranking 193 is removed. 11 clusters; 807 vertices; NMI 0.9692960575535088
# Vertex 233, ranking 194 is removed. 11 clusters; 806 vertices; NMI 0.9999999999999998
# Vertex 587, ranking 195 is removed. 11 clusters; 805 vertices; NMI 1.0
# Vertex 800, ranking 196 is removed. 11 clusters; 804 vertices; NMI 1.0
# Vertex 887, ranking 197 is removed. 11 clusters; 803 vertices; NMI 1.0
# Vertex 851, ranking 198 is removed. 11 clusters; 802 vertices; NMI 1.0000000000000002
# Vertex 767, ranking 199 is removed. 11 clusters; 801 vertices; NMI 1.0
# Vertex 551, ranking 200 is removed. 11 clusters; 800 vertices; NMI 1.0
# Vertex 195, ranking 201 is removed. 11 clusters; 799 vertices; NMI 0.9618467579090292
# Vertex 712, ranking 202 is removed. 11 clusters; 798 vertices; NMI 1.0
# Vertex 146, ranking 203 is removed. 11 clusters; 797 vertices; NMI 1.0
# Vertex 574, ranking 204 is removed. 11 clusters; 796 vertices; NMI 1.0
# Vertex 540, ranking 205 is removed. 11 clusters; 795 vertices; NMI 1.0000000000000002
# Vertex 60, ranking 206 is removed. 11 clusters; 794 vertices; NMI 1.0
# Vertex 649, ranking 207 is removed. 11 clusters; 793 vertices; NMI 0.969097820976547
# Vertex 348, ranking 208 is removed. 11 clusters; 792 vertices; NMI 1.0
# Vertex 557, ranking 209 is removed. 11 clusters; 791 vertices; NMI 1.0
# Vertex 903, ranking 210 is removed. 11 clusters; 790 vertices; NMI 1.0
# Vertex 480, ranking 211 is removed. 11 clusters; 789 vertices; NMI 1.0
# Vertex 788, ranking 212 is removed. 11 clusters; 788 vertices; NMI 0.9999999999999998
# Vertex 250, ranking 213 is removed. 11 clusters; 787 vertices; NMI 0.9752427433666639
# Vertex 200, ranking 214 is removed. 11 clusters; 786 vertices; NMI 1.0
# Vertex 364, ranking 215 is removed. 11 clusters; 785 vertices; NMI 1.0
# Vertex 191, ranking 216 is removed. 11 clusters; 784 vertices; NMI 1.0
# Vertex 556, ranking 217 is removed. 11 clusters; 783 vertices; NMI 1.0
# Vertex 223, ranking 218 is removed. 11 clusters; 782 vertices; NMI 1.0
# Vertex 648, ranking 219 is removed. 11 clusters; 781 vertices; NMI 1.0
# Vertex 147, ranking 220 is removed. 11 clusters; 780 vertices; NMI 0.9583922593365387
# Vertex 816, ranking 221 is removed. 11 clusters; 779 vertices; NMI 0.979654511081771
# Vertex 28, ranking 222 is removed. 11 clusters; 778 vertices; NMI 1.0
# Vertex 124, ranking 223 is removed. 11 clusters; 777 vertices; NMI 1.0
# Vertex 93, ranking 224 is removed. 11 clusters; 776 vertices; NMI 1.0
# Vertex 337, ranking 225 is removed. 11 clusters; 775 vertices; NMI 0.9798572671118491
# Vertex 308, ranking 226 is removed. 11 clusters; 774 vertices; NMI 1.0
# Vertex 12, ranking 227 is removed. 11 clusters; 773 vertices; NMI 1.0
# Vertex 354, ranking 228 is removed. 11 clusters; 772 vertices; NMI 1.0
# Vertex 286, ranking 229 is removed. 11 clusters; 771 vertices; NMI 1.0
# Vertex 706, ranking 230 is removed. 11 clusters; 770 vertices; NMI 0.9684836293119189
# Vertex 997, ranking 231 is removed. 11 clusters; 769 vertices; NMI 1.0
# Vertex 549, ranking 232 is removed. 11 clusters; 768 vertices; NMI 1.0
# Vertex 226, ranking 233 is removed. 11 clusters; 767 vertices; NMI 1.0
# Vertex 27, ranking 234 is removed. 11 clusters; 766 vertices; NMI 1.0
# Vertex 703, ranking 235 is removed. 11 clusters; 765 vertices; NMI 0.976682322405174
# Vertex 518, ranking 236 is removed. 11 clusters; 764 vertices; NMI 1.0
# Vertex 569, ranking 237 is removed. 11 clusters; 763 vertices; NMI 1.0
# Vertex 469, ranking 238 is removed. 11 clusters; 762 vertices; NMI 1.0
# Vertex 607, ranking 239 is removed. 11 clusters; 761 vertices; NMI 1.0
# Vertex 530, ranking 240 is removed. 11 clusters; 760 vertices; NMI 1.0
# Vertex 482, ranking 241 is removed. 11 clusters; 759 vertices; NMI 1.0
# Vertex 539, ranking 242 is removed. 11 clusters; 758 vertices; NMI 1.0000000000000002
# Vertex 868, ranking 243 is removed. 11 clusters; 757 vertices; NMI 1.0
# Vertex 929, ranking 244 is removed. 11 clusters; 756 vertices; NMI 1.0
# Vertex 142, ranking 245 is removed. 11 clusters; 755 vertices; NMI 0.959748948442123
# Vertex 47, ranking 246 is removed. 11 clusters; 754 vertices; NMI 1.0
# Vertex 45, ranking 247 is removed. 11 clusters; 753 vertices; NMI 1.0
# Vertex 744, ranking 248 is removed. 11 clusters; 752 vertices; NMI 1.0
# Vertex 488, ranking 249 is removed. 11 clusters; 751 vertices; NMI 1.0000000000000002
# Vertex 477, ranking 250 is removed. 11 clusters; 750 vertices; NMI 0.9606386211450864
# Vertex 177, ranking 251 is removed. 11 clusters; 749 vertices; NMI 1.0
# Vertex 969, ranking 252 is removed. 11 clusters; 748 vertices; NMI 1.0
# Vertex 398, ranking 253 is removed. 11 clusters; 747 vertices; NMI 1.0
# Vertex 207, ranking 254 is removed. 11 clusters; 746 vertices; NMI 1.0
# Vertex 835, ranking 255 is removed. 11 clusters; 745 vertices; NMI 0.9771611568522899
# Vertex 369, ranking 256 is removed. 11 clusters; 744 vertices; NMI 1.0
# Vertex 97, ranking 257 is removed. 11 clusters; 743 vertices; NMI 0.9999999999999998
# Vertex 877, ranking 258 is removed. 11 clusters; 742 vertices; NMI 1.0
# Vertex 810, ranking 259 is removed. 11 clusters; 741 vertices; NMI 1.0
# Vertex 82, ranking 260 is removed. 11 clusters; 740 vertices; NMI 1.0
# Vertex 31, ranking 261 is removed. 11 clusters; 739 vertices; NMI 1.0
# Vertex 523, ranking 262 is removed. 11 clusters; 738 vertices; NMI 0.9631066647343788
# Vertex 405, ranking 263 is removed. 11 clusters; 737 vertices; NMI 1.0
# Vertex 832, ranking 264 is removed. 11 clusters; 736 vertices; NMI 1.0
# Vertex 376, ranking 265 is removed. 11 clusters; 735 vertices; NMI 1.0000000000000002
# Vertex 30, ranking 266 is removed. 11 clusters; 734 vertices; NMI 1.0
# Vertex 69, ranking 267 is removed. 11 clusters; 733 vertices; NMI 1.0
# Vertex 586, ranking 268 is removed. 11 clusters; 732 vertices; NMI 1.0
# Vertex 565, ranking 269 is removed. 11 clusters; 731 vertices; NMI 1.0
# Vertex 88, ranking 270 is removed. 11 clusters; 730 vertices; NMI 1.0
# Vertex 664, ranking 271 is removed. 11 clusters; 729 vertices; NMI 0.9742358378473808
# Vertex 662, ranking 272 is removed. 11 clusters; 728 vertices; NMI 1.0
# Vertex 163, ranking 273 is removed. 11 clusters; 727 vertices; NMI 1.0
# Vertex 42, ranking 274 is removed. 11 clusters; 726 vertices; NMI 1.0000000000000002
# Vertex 80, ranking 275 is removed. 11 clusters; 725 vertices; NMI 0.9593098156436911
# Vertex 799, ranking 276 is removed. 11 clusters; 724 vertices; NMI 1.0
# Vertex 562, ranking 277 is removed. 11 clusters; 723 vertices; NMI 1.0
# Vertex 6, ranking 278 is removed. 11 clusters; 722 vertices; NMI 0.9665432672272111
# Vertex 511, ranking 279 is removed. 11 clusters; 721 vertices; NMI 1.0
# Vertex 795, ranking 280 is removed. 11 clusters; 720 vertices; NMI 1.0
# Vertex 545, ranking 281 is removed. 11 clusters; 719 vertices; NMI 1.0000000000000002
# Vertex 300, ranking 282 is removed. 11 clusters; 718 vertices; NMI 1.0
# Vertex 896, ranking 283 is removed. 11 clusters; 717 vertices; NMI 1.0
# Vertex 739, ranking 284 is removed. 11 clusters; 716 vertices; NMI 1.0000000000000002
# Vertex 595, ranking 285 is removed. 11 clusters; 715 vertices; NMI 0.9734248684695387
# Vertex 153, ranking 286 is removed. 11 clusters; 714 vertices; NMI 1.0
# Vertex 276, ranking 287 is removed. 11 clusters; 713 vertices; NMI 1.0
# Vertex 663, ranking 288 is removed. 11 clusters; 712 vertices; NMI 1.0
# Vertex 94, ranking 289 is removed. 11 clusters; 711 vertices; NMI 1.0
# Vertex 377, ranking 290 is removed. 11 clusters; 710 vertices; NMI 1.0
# Vertex 259, ranking 291 is removed. 11 clusters; 709 vertices; NMI 1.0
# Vertex 167, ranking 292 is removed. 11 clusters; 708 vertices; NMI 1.0
# Vertex 581, ranking 293 is removed. 11 clusters; 707 vertices; NMI 1.0
# Vertex 635, ranking 294 is removed. 11 clusters; 706 vertices; NMI 1.0
# Vertex 579, ranking 295 is removed. 11 clusters; 705 vertices; NMI 1.0
# Vertex 178, ranking 296 is removed. 11 clusters; 704 vertices; NMI 0.9791434192918906
# Vertex 490, ranking 297 is removed. 11 clusters; 703 vertices; NMI 1.0
# Vertex 865, ranking 298 is removed. 11 clusters; 702 vertices; NMI 0.9999999999999998
# Vertex 312, ranking 299 is removed. 11 clusters; 701 vertices; NMI 1.0
# Vertex 612, ranking 300 is removed. 11 clusters; 700 vertices; NMI 1.0000000000000002
# Vertex 15, ranking 301 is removed. 11 clusters; 699 vertices; NMI 1.0
# Vertex 63, ranking 302 is removed. 11 clusters; 698 vertices; NMI 1.0
# Vertex 546, ranking 303 is removed. 11 clusters; 697 vertices; NMI 0.9999999999999998
# Vertex 122, ranking 304 is removed. 11 clusters; 696 vertices; NMI 0.9821501106297624
# Vertex 72, ranking 305 is removed. 11 clusters; 695 vertices; NMI 1.0
# Vertex 140, ranking 306 is removed. 11 clusters; 694 vertices; NMI 0.98085098414578
# Vertex 547, ranking 307 is removed. 11 clusters; 693 vertices; NMI 1.0
# Vertex 421, ranking 308 is removed. 11 clusters; 692 vertices; NMI 1.0
# Vertex 678, ranking 309 is removed. 11 clusters; 691 vertices; NMI 1.0000000000000002
# Vertex 580, ranking 310 is removed. 11 clusters; 690 vertices; NMI 0.9999999999999998
# Vertex 388, ranking 311 is removed. 11 clusters; 689 vertices; NMI 0.9671364832835699
# Vertex 322, ranking 312 is removed. 11 clusters; 688 vertices; NMI 0.9999999999999998
# Vertex 618, ranking 313 is removed. 11 clusters; 687 vertices; NMI 1.0
# Vertex 682, ranking 314 is removed. 11 clusters; 686 vertices; NMI 0.9778256426314428
# Vertex 627, ranking 315 is removed. 11 clusters; 685 vertices; NMI 1.0
# Vertex 471, ranking 316 is removed. 11 clusters; 684 vertices; NMI 0.9999999999999998
# Vertex 734, ranking 317 is removed. 11 clusters; 683 vertices; NMI 1.0
# Vertex 699, ranking 318 is removed. 11 clusters; 682 vertices; NMI 0.9999999999999998
# Vertex 396, ranking 319 is removed. 11 clusters; 681 vertices; NMI 0.9821417020532102
# Vertex 172, ranking 320 is removed. 11 clusters; 680 vertices; NMI 1.0
# Vertex 564, ranking 321 is removed. 11 clusters; 679 vertices; NMI 0.9999999999999998
# Vertex 793, ranking 322 is removed. 11 clusters; 678 vertices; NMI 1.0
# Vertex 831, ranking 323 is removed. 11 clusters; 677 vertices; NMI 1.0
# Vertex 859, ranking 324 is removed. 11 clusters; 676 vertices; NMI 1.0
# Vertex 532, ranking 325 is removed. 11 clusters; 675 vertices; NMI 1.0
# Vertex 715, ranking 326 is removed. 11 clusters; 674 vertices; NMI 1.0
# Vertex 837, ranking 327 is removed. 11 clusters; 673 vertices; NMI 1.0
# Vertex 491, ranking 328 is removed. 11 clusters; 672 vertices; NMI 1.0
# Vertex 262, ranking 329 is removed. 11 clusters; 671 vertices; NMI 1.0
# Vertex 655, ranking 330 is removed. 11 clusters; 670 vertices; NMI 1.0
# Vertex 319, ranking 331 is removed. 11 clusters; 669 vertices; NMI 1.0
# Vertex 639, ranking 332 is removed. 11 clusters; 668 vertices; NMI 1.0
# Vertex 486, ranking 333 is removed. 11 clusters; 667 vertices; NMI 1.0
# Vertex 25, ranking 334 is removed. 11 clusters; 666 vertices; NMI 1.0000000000000002
# Vertex 614, ranking 335 is removed. 11 clusters; 665 vertices; NMI 1.0
# Vertex 121, ranking 336 is removed. 11 clusters; 664 vertices; NMI 1.0
# Vertex 930, ranking 337 is removed. 11 clusters; 663 vertices; NMI 1.0
# Vertex 310, ranking 338 is removed. 11 clusters; 662 vertices; NMI 0.9999999999999998
# Vertex 289, ranking 339 is removed. 11 clusters; 661 vertices; NMI 1.0
# Vertex 489, ranking 340 is removed. 11 clusters; 660 vertices; NMI 1.0
# Vertex 651, ranking 341 is removed. 11 clusters; 659 vertices; NMI 1.0
# Vertex 238, ranking 342 is removed. 11 clusters; 658 vertices; NMI 1.0
# Vertex 334, ranking 343 is removed. 11 clusters; 657 vertices; NMI 1.0
# Vertex 496, ranking 344 is removed. 11 clusters; 656 vertices; NMI 0.9999999999999998
# Vertex 647, ranking 345 is removed. 11 clusters; 655 vertices; NMI 1.0
# Vertex 370, ranking 346 is removed. 11 clusters; 654 vertices; NMI 1.0
# Vertex 275, ranking 347 is removed. 11 clusters; 653 vertices; NMI 0.9651477969547971
# Vertex 692, ranking 348 is removed. 11 clusters; 652 vertices; NMI 0.9772497244870612
# Vertex 738, ranking 349 is removed. 11 clusters; 651 vertices; NMI 1.0
# Vertex 331, ranking 350 is removed. 11 clusters; 650 vertices; NMI 0.9683583265754435
# Vertex 366, ranking 351 is removed. 11 clusters; 649 vertices; NMI 0.9967632194123144
# Vertex 548, ranking 352 is removed. 11 clusters; 648 vertices; NMI 0.9999999999999998
# Vertex 277, ranking 353 is removed. 11 clusters; 647 vertices; NMI 0.9413510180164147
# Vertex 414, ranking 354 is removed. 11 clusters; 646 vertices; NMI 0.9967483000639396
# Vertex 585, ranking 355 is removed. 11 clusters; 645 vertices; NMI 0.9967432467841798
# Vertex 292, ranking 356 is removed. 11 clusters; 644 vertices; NMI 0.9630249904906638
# Vertex 351, ranking 357 is removed. 11 clusters; 643 vertices; NMI 0.9807517969736137
# Vertex 413, ranking 358 is removed. 11 clusters; 642 vertices; NMI 1.0
# Vertex 780, ranking 359 is removed. 11 clusters; 641 vertices; NMI 0.9714416476322292
# Vertex 915, ranking 360 is removed. 11 clusters; 640 vertices; NMI 1.0
# Vertex 604, ranking 361 is removed. 11 clusters; 639 vertices; NMI 1.0
# Vertex 336, ranking 362 is removed. 11 clusters; 638 vertices; NMI 0.9766946516421119
# Vertex 599, ranking 363 is removed. 11 clusters; 637 vertices; NMI 1.0
# Vertex 154, ranking 364 is removed. 11 clusters; 636 vertices; NMI 0.9659104506663525
# Vertex 970, ranking 365 is removed. 11 clusters; 635 vertices; NMI 1.0
# Vertex 553, ranking 366 is removed. 11 clusters; 634 vertices; NMI 0.9611672857987681
# Vertex 335, ranking 367 is removed. 11 clusters; 633 vertices; NMI 0.943856296012644
# Vertex 513, ranking 368 is removed. 11 clusters; 632 vertices; NMI 0.9592267913552933
# Vertex 161, ranking 369 is removed. 11 clusters; 631 vertices; NMI 1.0
# Vertex 86, ranking 370 is removed. 11 clusters; 630 vertices; NMI 1.0
# Vertex 897, ranking 371 is removed. 11 clusters; 629 vertices; NMI 1.0
# Vertex 533, ranking 372 is removed. 11 clusters; 628 vertices; NMI 1.0
# Vertex 758, ranking 373 is removed. 11 clusters; 627 vertices; NMI 1.0
# Vertex 406, ranking 374 is removed. 11 clusters; 626 vertices; NMI 0.9784004350805705
# Vertex 708, ranking 375 is removed. 11 clusters; 625 vertices; NMI 0.9745289114688745
# Vertex 367, ranking 376 is removed. 11 clusters; 624 vertices; NMI 1.0000000000000002
# Vertex 972, ranking 377 is removed. 11 clusters; 623 vertices; NMI 1.0
# Vertex 208, ranking 378 is removed. 11 clusters; 622 vertices; NMI 0.9999999999999998
# Vertex 731, ranking 379 is removed. 11 clusters; 621 vertices; NMI 0.9743412708263358
# Vertex 791, ranking 380 is removed. 11 clusters; 620 vertices; NMI 1.0
# Vertex 750, ranking 381 is removed. 11 clusters; 619 vertices; NMI 1.0
# Vertex 155, ranking 382 is removed. 11 clusters; 618 vertices; NMI 0.9828282666608528
# Vertex 572, ranking 383 is removed. 11 clusters; 617 vertices; NMI 1.0
# Vertex 23, ranking 384 is removed. 11 clusters; 616 vertices; NMI 0.9585443936786313
# Vertex 272, ranking 385 is removed. 11 clusters; 615 vertices; NMI 0.973125259933256
# Vertex 926, ranking 386 is removed. 11 clusters; 614 vertices; NMI 1.0
# Vertex 567, ranking 387 is removed. G is now disconnected!!

# %%
import matplotlib.pyplot as plt

# Example list of numbers
numbers = quxian

# Generate x-axis values based on the index of each number
x = range(len(numbers))

# Plot the curve
plt.plot(x, numbers)

# Add labels and title to the plot
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Curve Plot')

# Display the plot
plt.show()
