# %%
import warnings

warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
### 使用 networkx 包中的函数 LFR_benchmark_graph 生成随机图
import networkx as nx
from networkx.generators.community import LFR_benchmark_graph

n = 1000
tau1 = 2  # Power-law exponent for the degree distribution
tau2 = 1.1 # Power-law exponent for the community size distribution 
            #S hould be >1
mu = 0.05 # Mixing parameter
avg_deg = 25 # Average Degree
max_deg = 100 # Max Degree
min_commu = 80 # Min Community Size
max_commu = 100 # Max Community Size

G = LFR_benchmark_graph(
    n, tau1, tau2, mu, average_degree=avg_deg, max_degree=max_deg, min_community=min_commu, max_community=max_commu, 
    seed=7
)
### 去掉 G 中的重边和自环 
G = nx.Graph(G) # Remove multi-edges

selfloop_edges = list(nx.selfloop_edges(G)) # a list of self loops

G.remove_edges_from(selfloop_edges) # Remove self-loops

# %%
import numpy as np
intrinsic_communities = {frozenset(G.nodes[v]["community"]) for v in G}
intrinsic_membership = np.empty(G.number_of_nodes(), dtype=int)
for node in range(G.number_of_nodes()):
    for index, inner_set in enumerate(intrinsic_communities):
        if node in inner_set:
            intrinsic_membership[node] = index
            break

# %%
remain_nodes = np.array(range(G.number_of_nodes()))
idx = [True] *(G.number_of_nodes())

# %%
import random

temp = list(range(G.number_of_nodes()))
random.shuffle(temp)

# %%
from auxpack.eval_embd import eval_embd as EE
from clusim.clustering import Clustering

D=20

# %%
from auxpack.lle import lle
from auxpack.eval_embd import eval_embd as EE

scores=[]
for i in temp:
    G.remove_node(i)
    print(f"Vertex {i} is removed.", end=' ')
    if not nx.is_connected(G):
        print(temp.index(i), "vertices are removed. G is now disconnected!!")
        break
    embd = lle(G, D)
    idx[i] = False
    intrin_list = intrinsic_membership[idx]
    intrin_Clus = Clustering({i: [intrin_list[i]] for i in range(len(intrin_list))})
    K = len(np.unique(intrinsic_membership[idx]))
    score = EE(K,intrin_list,intrin_Clus, embd)
    scores.append(score)
    print("NMI&ECS:", score)
# Out:
# Vertex 20 is removed. NMI&ECS: [0.9610555417273913, 1.0, 0.8672186602578948, 1.0]
# Vertex 903 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 521 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 841 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 64 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 129 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 572 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 448 is removed. NMI&ECS: [0.9999999999999998, 0.9999999999999998, 1.0, 1.0]
# Vertex 955 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 60 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 805 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 524 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 300 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 654 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 737 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 504 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 63 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 457 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 330 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 833 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 994 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 840 is removed. NMI&ECS: [0.9605361880312041, 1.0, 0.8655319030695152, 1.0]
# Vertex 672 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 287 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 355 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 81 is removed. NMI&ECS: [0.9737408985020922, 1.0, 0.9346510448121754, 1.0]
# Vertex 866 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 168 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 858 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 272 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 885 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 156 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 485 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 961 is removed. NMI&ECS: [0.9700299393293923, 0.9999999999999998, 0.9214830200855045, 1.0]
# Vertex 240 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 694 is removed. NMI&ECS: [0.9608216003446312, 1.0, 0.8663980472715628, 1.0]
# Vertex 528 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 183 is removed. NMI&ECS: [0.9999999999999998, 0.9999999999999998, 1.0, 1.0]
# Vertex 950 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 890 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 374 is removed. NMI&ECS: [0.9999999999999998, 1.0, 1.0, 1.0]
# Vertex 565 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 636 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 118 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 144 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 618 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 283 is removed. NMI&ECS: [0.9999999999999998, 1.0, 1.0, 1.0]
# Vertex 747 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 851 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 206 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 938 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 963 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 333 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 518 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 205 is removed. NMI&ECS: [0.9999999999999998, 0.9999999999999998, 1.0, 1.0]
# Vertex 561 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 450 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 356 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 893 is removed. NMI&ECS: [0.9999999999999998, 1.0000000000000002, 1.0, 1.0]
# Vertex 811 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 79 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 557 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 761 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 398 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 764 is removed. NMI&ECS: [0.96125387014258, 1.0, 0.869746686879554, 1.0]
# Vertex 161 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 680 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 513 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 386 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 674 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 469 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 900 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 255 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 310 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 993 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 802 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 976 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 290 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 506 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 152 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 583 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 497 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 464 is removed. NMI&ECS: [0.9616334844847901, 1.0, 0.8691384950926936, 1.0]
# Vertex 193 is removed. NMI&ECS: [0.9606188462700445, 1.0, 0.8658389014573579, 1.0]
# Vertex 50 is removed. NMI&ECS: [0.9999999999999998, 1.0000000000000002, 1.0, 1.0]
# Vertex 991 is removed. NMI&ECS: [0.9624938657652704, 0.9999999999999998, 0.874147361575373, 1.0]
# Vertex 218 is removed. NMI&ECS: [0.9999999999999998, 1.0, 1.0, 1.0]
# Vertex 321 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 499 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 320 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 303 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 324 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 305 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 671 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 103 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 215 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 405 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 551 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 24 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 571 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 473 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 685 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 137 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 174 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 496 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 77 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 828 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 718 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 723 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 69 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 431 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 517 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 652 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 540 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 741 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 958 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 726 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 284 is removed. NMI&ECS: [0.9603679993396061, 1.0, 0.8653913282484711, 1.0]
# Vertex 99 is removed. NMI&ECS: [0.9999999999999998, 1.0, 1.0, 1.0]
# Vertex 62 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 767 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 291 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 45 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 941 is removed. NMI&ECS: [0.9600965485449667, 1.0, 0.8647660963488658, 1.0]
# Vertex 133 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 699 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 292 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 911 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 934 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 916 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 629 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 898 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 136 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 465 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 758 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 932 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 980 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 902 is removed. NMI&ECS: [0.9590139680921813, 1.0, 0.8605987791093331, 1.0]
# Vertex 200 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 377 is removed. NMI&ECS: [0.961701815787251, 1.0, 0.8693500298151461, 1.0]
# Vertex 748 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 781 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 771 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 223 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 663 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 707 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 813 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 564 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 729 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 278 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 760 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 600 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 740 is removed. NMI&ECS: [0.9999999999999998, 0.9999999999999998, 1.0, 1.0]
# Vertex 32 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 428 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 336 is removed. NMI&ECS: [0.9999999999999998, 1.0, 1.0, 1.0]
# Vertex 808 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 836 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 835 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 134 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 477 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 869 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 162 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 238 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 17 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 775 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 716 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 360 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 115 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 354 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 148 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 882 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 234 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 53 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 89 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 327 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 268 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 635 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 577 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 119 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 556 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 523 is removed. NMI&ECS: [0.9600375577585993, 1.0, 0.8646016600698625, 1.0]
# Vertex 252 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 146 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 409 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 382 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 42 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 855 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 570 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 265 is removed. NMI&ECS: [0.9999999999999998, 1.0, 1.0, 1.0]
# Vertex 369 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 93 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 968 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 160 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 421 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 545 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 582 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 590 is removed. NMI&ECS: [0.9999999999999998, 0.9999999999999998, 1.0, 1.0]
# Vertex 897 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 779 is removed. NMI&ECS: [0.9999999999999998, 0.9999999999999998, 1.0, 1.0]
# Vertex 505 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 472 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 169 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 154 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 641 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 441 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 239 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 404 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 997 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 642 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 529 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 816 is removed. NMI&ECS: [0.960822043869009, 1.0, 0.8669300064345463, 1.0]
# Vertex 294 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 825 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 241 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 520 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 75 is removed. NMI&ECS: [0.9670426806315667, 1.0, 0.9098390026259425, 1.0]
# Vertex 217 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 607 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 213 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 495 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 631 is removed. NMI&ECS: [0.958346483391565, 1.0, 0.8582144255580983, 1.0]
# Vertex 923 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 640 is removed. NMI&ECS: [0.9999999999999998, 1.0, 1.0, 1.0]
# Vertex 943 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 966 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 974 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 14 is removed. NMI&ECS: [0.959769510823505, 0.9999999999999998, 0.8628042868610627, 1.0]
# Vertex 212 is removed. NMI&ECS: [0.9999999999999998, 1.0, 1.0, 1.0]
# Vertex 364 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 167 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 655 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 11 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 71 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 936 is removed. NMI&ECS: [0.9999999999999998, 0.9999999999999998, 1.0, 1.0]
# Vertex 860 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 402 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 480 is removed. NMI&ECS: [0.9999999999999998, 0.9999999999999998, 1.0, 1.0]
# Vertex 892 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 690 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 122 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 307 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 738 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 229 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 927 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 919 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 435 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 965 is removed. NMI&ECS: [0.9999999999999998, 0.9999999999999998, 1.0, 1.0]
# Vertex 352 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 494 is removed. NMI&ECS: [0.9583735953714762, 1.0, 0.8583817896817283, 1.0]
# Vertex 242 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 92 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 476 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 608 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 380 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 312 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 4 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 937 is removed. NMI&ECS: [0.9610472931632381, 1.0, 0.8671982365082471, 1.0]
# Vertex 992 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 925 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 406 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 9 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 983 is removed. NMI&ECS: [0.9714049473538654, 0.9999999999999998, 0.9261575644504749, 1.0]
# Vertex 323 is removed. NMI&ECS: [0.9626498164980776, 1.0, 0.8740287037622178, 1.0]
# Vertex 704 is removed. NMI&ECS: [0.9668508478280788, 1.0, 0.9100623582766441, 1.0]
# Vertex 210 is removed. NMI&ECS: [0.9999999999999998, 0.9999999999999998, 1.0, 1.0]
# Vertex 617 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 823 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 407 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 483 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 921 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 184 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 554 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 614 is removed. NMI&ECS: [0.9744161292600999, 1.0, 0.9355237468085352, 1.0]
# Vertex 67 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 843 is removed. NMI&ECS: [0.9729969230911458, 1.0, 0.9312621080576883, 1.0]
# Vertex 390 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 734 is removed. NMI&ECS: [0.9740254601008387, 1.0, 0.9348176643158284, 1.0]
# Vertex 566 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 19 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 65 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 350 is removed. NMI&ECS: [0.9411274189122857, 1.0000000000000002, 0.8620546049431842, 1.0]
# Vertex 348 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 366 is removed. NMI&ECS: [0.9999999999999998, 0.9999999999999998, 1.0, 1.0]
# Vertex 632 is removed. NMI&ECS: [0.9512849597258253, 1.0, 0.8819964839727684, 1.0]
# Vertex 879 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 179 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 351 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 539 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 0 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 273 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 246 is removed. NMI&ECS: [0.9999999999999998, 0.9999999999999998, 1.0, 1.0]
# Vertex 827 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 787 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 47 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 2 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 547 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 475 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 208 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 452 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 826 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 230 is removed. NMI&ECS: [0.9715213318010385, 1.0, 0.9271252737707076, 1.0]
# Vertex 54 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 530 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 87 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 782 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 368 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 928 is removed. NMI&ECS: [0.9741238610091958, 1.0, 0.9351421923202459, 1.0]
# Vertex 724 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 51 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 696 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 172 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 263 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 706 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 84 is removed. NMI&ECS: [0.975924946655612, 1.0, 0.9421791052660111, 1.0]
# Vertex 101 is removed. NMI&ECS: [0.9591034587968691, 1.0, 0.8609357156888777, 1.0]
# Vertex 197 is removed. NMI&ECS: [0.9475269290000354, 1.0000000000000002, 0.8682840792089781, 1.0]
# Vertex 772 is removed. NMI&ECS: [0.968353868196513, 1.0, 0.915560267994345, 1.0]
# Vertex 434 is removed. NMI&ECS: [0.9999999999999998, 1.0, 1.0, 1.0]
# Vertex 657 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 817 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 41 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 804 is removed. NMI&ECS: [0.9715417687089973, 0.9999999999999998, 0.9261593147724173, 1.0]
# Vertex 117 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 535 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 16 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 839 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 460 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 33 is removed. NMI&ECS: [0.9612205921250249, 0.9999999999999998, 0.867593401510869, 1.0]
# Vertex 653 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 867 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 732 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 872 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 91 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 138 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 125 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 400 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 155 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 793 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 309 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 922 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 996 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 588 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 560 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 622 is removed. NMI&ECS: [0.9691243748887358, 1.0, 0.91959212541075, 1.0]
# Vertex 488 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 30 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 957 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 711 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 38 is removed. NMI&ECS: [0.962859114925548, 1.0, 0.8743302752293578, 1.0]
# Vertex 227 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 989 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 763 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 444 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 970 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 319 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 359 is removed. NMI&ECS: [0.9715984389474217, 1.0000000000000002, 0.9290400113106176, 1.0]
# Vertex 735 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 705 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 999 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 379 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 463 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 712 is removed. NMI&ECS: [0.96103267626278, 1.0, 0.8683837623790965, 1.0]
# Vertex 470 is removed. NMI&ECS: [0.9727450043937006, 1.0, 0.9306961701692488, 1.0]
# Vertex 756 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 612 is removed. NMI&ECS: [0.9766575221901679, 1.0, 0.9443568173852085, 1.0]
# Vertex 579 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 329 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 507 is removed. NMI&ECS: [0.9765474371961549, 1.0, 0.9440922697658037, 1.0]
# Vertex 484 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 837 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 809 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 1 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 37 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 436 is removed. NMI&ECS: [0.9690933852116467, 1.0, 0.9190961038961039, 1.0]
# Vertex 57 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 647 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 74 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 358 is removed. NMI&ECS: [0.9686531055366977, 1.0000000000000002, 0.9180252025662654, 1.0]
# Vertex 542 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 338 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 865 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 455 is removed. NMI&ECS: [0.9788346624237665, 1.0000000000000002, 0.9501352599103502, 1.0]
# Vertex 426 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 247 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 447 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 541 is removed. NMI&ECS: [0.9593927220512525, 0.9999999999999998, 0.8619177615145481, 1.0]
# Vertex 516 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 785 is removed. NMI&ECS: [0.9698622983778541, 1.0, 0.9209057368431113, 1.0]
# Vertex 949 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 742 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 701 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 158 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 199 is removed. NMI&ECS: [0.9687779965834378, 1.0, 0.9176870517240404, 1.0]
# Vertex 831 is removed. NMI&ECS: [0.9999999999999998, 1.0, 1.0, 1.0]
# Vertex 372 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 710 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 567 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 818 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 623 is removed. NMI&ECS: [0.9999999999999998, 0.9999999999999998, 1.0, 1.0]
# Vertex 301 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 876 is removed. NMI&ECS: [0.9689524993348492, 1.0, 0.9186075862058846, 1.0]
# Vertex 433 is removed. NMI&ECS: [0.9758699030256256, 1.0, 0.9419202078726113, 1.0]
# Vertex 754 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 39 is removed. NMI&ECS: [0.9776117395738346, 1.0, 0.9475946491287133, 1.0]
# Vertex 185 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 157 is removed. NMI&ECS: [0.9713999552794281, 1.0, 0.9261604663621907, 1.0]
# Vertex 633 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 962 is removed. NMI&ECS: [0.9745375468940951, 1.0000000000000002, 0.9368841580001942, 1.0]
# Vertex 76 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 293 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 615 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 800 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 746 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 562 is removed. NMI&ECS: [0.9684253502472591, 0.9999999999999998, 0.9156248787966009, 1.0]
# Vertex 725 is removed. NMI&ECS: [0.9999999999999998, 1.0, 1.0, 1.0]
# Vertex 419 is removed. NMI&ECS: [0.973412105917924, 1.0, 0.932621658825545, 1.0]
# Vertex 443 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 964 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 940 is removed. NMI&ECS: [0.9586180844471915, 1.0, 0.859790263139363, 1.0]
# Vertex 646 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 94 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 909 is removed. NMI&ECS: [0.9999999999999998, 1.0, 1.0, 1.0]
# Vertex 673 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 178 is removed. NMI&ECS: [1.0, 0.9999999999999998, 1.0, 1.0]
# Vertex 187 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 40 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 889 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 799 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 367 is removed. NMI&ECS: [0.9789928915652528, 1.0, 0.9522527472527472, 1.0]
# Vertex 83 is removed. NMI&ECS: [0.9695799313050536, 1.0000000000000002, 0.9205711775043938, 1.0]
# Vertex 853 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 381 is removed. NMI&ECS: [0.9719343415151585, 1.0, 0.9289594356261024, 1.0]
# Vertex 257 is removed. NMI&ECS: [0.9610490548262115, 1.0, 0.8690190139660103, 1.0]
# Vertex 634 is removed. NMI&ECS: [0.9616883083658817, 1.0, 0.8713758913996048, 1.0]
# Vertex 534 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 403 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 719 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 73 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 786 is removed. NMI&ECS: [0.9601641113843725, 1.0000000000000002, 0.8646473424534649, 1.0]
# Vertex 361 is removed. NMI&ECS: [0.9554359898852227, 1.0, 0.8588032310916814, 1.0]
# Vertex 28 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 908 is removed. NMI&ECS: [0.9999999999999998, 1.0, 1.0, 1.0]
# Vertex 628 is removed. NMI&ECS: [0.9999999999999998, 1.0000000000000002, 1.0, 1.0]
# Vertex 135 is removed. NMI&ECS: [0.9571189039798909, 1.0, 0.8550378639509075, 1.0]
# Vertex 423 is removed. NMI&ECS: [0.9562184372146835, 1.0, 0.9046564203298648, 1.0]
# Vertex 127 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 139 is removed. NMI&ECS: [0.9803624254276389, 1.0, 0.9551771773543352, 1.0]
# Vertex 537 is removed. NMI&ECS: [0.9371422878368135, 1.0000000000000002, 0.8352655568767341, 1.0]
# Vertex 824 is removed. NMI&ECS: [0.9712395086318331, 1.0, 0.9270315398886828, 1.0]
# Vertex 490 is removed. NMI&ECS: [0.9999999999999998, 1.0000000000000002, 1.0, 1.0]
# Vertex 755 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 458 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 880 is removed. NMI&ECS: [0.9624524338230199, 1.0000000000000002, 0.9190741467527183, 1.0]
# Vertex 739 is removed. NMI&ECS: [0.9496868511234313, 1.0, 0.87374060956457, 1.0]
# Vertex 337 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 728 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 578 is removed. NMI&ECS: [0.967756223600422, 0.9999999999999998, 0.9092715672387975, 1.0]
# Vertex 131 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 797 is removed. NMI&ECS: [0.9808702424713652, 1.0, 0.9554850833920602, 1.0]
# Vertex 667 is removed. NMI&ECS: [0.9840598743519363, 1.0, 0.9660391288298267, 1.0]
# Vertex 237 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 538 is removed. NMI&ECS: [0.9732973451520632, 1.0000000000000002, 0.933975048303477, 1.0]
# Vertex 829 is removed. NMI&ECS: [0.9731436775877391, 1.0, 0.9336650082918739, 1.0]
# Vertex 874 is removed. NMI&ECS: [0.9444450357530101, 1.0, 0.8497784993927874, 1.0]
# Vertex 343 is removed. NMI&ECS: [0.9732378755252002, 1.0, 0.9326818039950062, 1.0]
# Vertex 945 is removed. NMI&ECS: [0.9798155150489207, 1.0000000000000002, 0.9537633854139809, 1.0]
# Vertex 830 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 515 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 31 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 173 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 514 is removed. NMI&ECS: [0.963797194709937, 1.0000000000000002, 0.9194762573744544, 1.0]
# Vertex 698 is removed. NMI&ECS: [0.9611914724390535, 1.0000000000000002, 0.869161048084299, 1.0]
# Vertex 12 is removed. NMI&ECS: [0.9589316739730147, 1.0000000000000002, 0.861579992821142, 1.0]
# Vertex 365 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 36 is removed. NMI&ECS: [0.9748828205780629, 1.0, 0.938980105815974, 1.0]
# Vertex 46 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 749 is removed. NMI&ECS: [0.9841339642059516, 1.0, 0.9655473625870503, 1.0]
# Vertex 644 is removed. NMI&ECS: [1.0000000000000002, 1.0, 1.0, 1.0]
# Vertex 306 is removed. NMI&ECS: [0.9708274882237976, 1.0, 0.9242999051564917, 1.0]
# Vertex 792 is removed. NMI&ECS: [0.9711981517973507, 1.0, 0.9268660467454135, 1.0]
# Vertex 610 is removed. NMI&ECS: [0.9826341989017023, 1.0, 0.9613556413556414, 1.0]
# Vertex 606 is removed. NMI&ECS: [0.979370170136902, 1.0000000000000002, 0.9525297397637824, 1.0]
# Vertex 383 is removed. NMI&ECS: [0.983470704921033, 0.9999999999999998, 0.9646265733099941, 1.0]
# Vertex 456 is removed. NMI&ECS: [0.9811517334042593, 0.9999999999999998, 0.9570825492514446, 1.0]
# Vertex 108 is removed. NMI&ECS: [0.983457538383492, 1.0, 0.9645393463885521, 1.0]
# Vertex 613 is removed. NMI&ECS: [0.9835298432166623, 1.0, 0.9645763813173863, 1.0]
# Vertex 170 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 326 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 959 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 177 is removed. NMI&ECS: [0.9834007014620418, 1.0, 0.9642980031744974, 1.0]
# Vertex 873 is removed. NMI&ECS: [0.9999999999999998, 0.9999999999999998, 1.0, 1.0]
# Vertex 221 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 917 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 396 is removed. NMI&ECS: [0.9804848757389899, 0.9999999999999998, 0.9557056385366646, 1.0]
# Vertex 260 is removed. NMI&ECS: [0.9605313682477828, 1.0, 0.8671147565884408, 1.0]
# Vertex 244 is removed. NMI&ECS: [0.9831680585358522, 1.0, 0.9638204360402955, 1.0]
# Vertex 638 is removed. NMI&ECS: [0.9607674145143272, 1.0, 0.8668337403075869, 1.0]
# Vertex 332 is removed. NMI&ECS: [0.9402775950176574, 0.9999999999999998, 0.8428687635492788, 1.0]
# Vertex 128 is removed. NMI&ECS: [0.941986256866061, 1.0, 0.8516878922111479, 1.0]
# Vertex 870 is removed. NMI&ECS: [0.9804198073222925, 1.0, 0.9553607214428859, 1.0]
# Vertex 627 is removed. NMI&ECS: [0.9999999999999998, 0.9999999999999998, 1.0, 1.0]
# Vertex 714 is removed. NMI&ECS: [0.9803785193593366, 1.0000000000000002, 0.9551965005670847, 1.0]
# Vertex 522 is removed. NMI&ECS: [0.9831959554570727, 0.9999999999999998, 0.9635432000112153, 1.0]
# Vertex 461 is removed. NMI&ECS: [0.9679578796367403, 1.0000000000000002, 0.9105102305102305, 1.0]
# Vertex 248 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 342 is removed. NMI&ECS: [0.9456644498115794, 1.0, 0.852348525934645, 1.0]
# Vertex 651 is removed. NMI&ECS: [0.9695446420934452, 1.0, 0.9178014905149051, 1.0]
# Vertex 61 is removed. NMI&ECS: [0.9822241010659621, 1.0000000000000002, 0.9596619438857117, 1.0]
# Vertex 569 is removed. NMI&ECS: [0.9464478861017083, 1.0000000000000002, 0.8548664343786296, 1.0]
# Vertex 563 is removed. NMI&ECS: [0.9999999999999998, 1.0, 1.0, 1.0]
# Vertex 438 is removed. NMI&ECS: [0.9604142636281271, 1.0, 0.8662612374405076, 1.0]
# Vertex 552 is removed. NMI&ECS: [0.9476665879929103, 1.0000000000000002, 0.8554550852279755, 1.0]
# Vertex 209 is removed. NMI&ECS: [0.944158666740209, 1.0, 0.8480531813865148, 1.0]
# Vertex 102 is removed. NMI&ECS: [0.9718737708986397, 0.9999999999999998, 0.9266653449643141, 1.0]
# Vertex 526 is removed. NMI&ECS: [0.9814072021661114, 1.0, 0.9583754174622718, 1.0]
# Vertex 645 is removed. NMI&ECS: [0.9637098858639256, 1.0000000000000002, 0.9236800793191772, 1.0]
# Vertex 445 is removed. NMI&ECS: [0.9458801862643229, 0.9999999999999998, 0.8844798827476121, 1.0]
# Vertex 414 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 346 is removed. NMI&ECS: [0.9527424532470121, 1.0, 0.8924327485380117, 1.0]
# Vertex 944 is removed. NMI&ECS: [0.9536575119820541, 1.0, 0.8878282676995389, 1.0]
# Vertex 857 is removed. NMI&ECS: [0.9676956921446934, 1.0, 0.9141595271302384, 1.0]
# Vertex 625 is removed. NMI&ECS: [0.9793670163175353, 1.0, 0.9531956690575174, 1.0]
# Vertex 969 is removed. NMI&ECS: [0.9567442732167157, 1.0, 0.897671568627451, 1.0]
# Vertex 863 is removed. NMI&ECS: [0.9827091456251646, 1.0, 0.9621883656509695, 1.0]
# Vertex 201 is removed. NMI&ECS: [0.956263552902461, 1.0, 0.9045092585513725, 1.0]
# Vertex 956 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 180 is removed. NMI&ECS: [0.959438131290421, 0.9999999999999998, 0.8624316751642093, 1.0]
# Vertex 429 is removed. NMI&ECS: [0.983333696225667, 1.0, 0.9627308227050739, 1.0]
# Vertex 498 is removed. NMI&ECS: [1.0, 1.0000000000000002, 1.0, 1.0]
# Vertex 525 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 228 is removed. NMI&ECS: [0.9600563500866562, 1.0, 0.8649207110745571, 1.0]
# Vertex 317 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 171 is removed. NMI&ECS: [0.9610359329336653, 1.0000000000000002, 0.8689794945159752, 1.0]
# Vertex 854 is removed. NMI&ECS: [0.9619325722185869, 1.0, 0.8712166435885602, 1.0]
# Vertex 548 is removed. NMI&ECS: [0.942746366010828, 1.0, 0.8655964088036732, 1.0]
# Vertex 439 is removed. NMI&ECS: [0.9715973178708049, 1.0, 0.9261022754543274, 1.0]
# Vertex 27 is removed. NMI&ECS: [0.9802626125104128, 1.0000000000000002, 0.9562108735041065, 1.0]
# Vertex 466 is removed. NMI&ECS: [0.9699147972867418, 1.0, 0.9205518520945343, 1.0]
# Vertex 587 is removed. NMI&ECS: [0.9607009666980526, 1.0, 0.8669638153896024, 1.0]
# Vertex 114 is removed. NMI&ECS: [0.9654464631706445, 1.0, 0.9063273203751313, 1.0]
# Vertex 952 is removed. NMI&ECS: [0.9698842009510236, 1.0, 0.9203774588640651, 1.0]
# Vertex 44 is removed. NMI&ECS: [1.0000000000000002, 1.0000000000000002, 1.0, 1.0]
# Vertex 97 is removed. NMI&ECS: [0.9704452530861217, 1.0, 0.9208893967306393, 1.0]
# Vertex 295 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 195 is removed. NMI&ECS: [0.9999999999999998, 0.9999999999999998, 1.0, 1.0]
# Vertex 21 is removed. NMI&ECS: [0.9755885512508403, 1.0, 0.9386190826588178, 1.0]
# Vertex 22 is removed. NMI&ECS: [0.9692956450594986, 1.0, 0.9178668517554514, 1.0]
# Vertex 601 is removed. NMI&ECS: [0.9999999999999998, 0.9999999999999998, 1.0, 1.0]
# Vertex 819 is removed. NMI&ECS: [0.9445549056812979, 1.0, 0.833497022595644, 1.0]
# Vertex 153 is removed. NMI&ECS: [0.9565708078277597, 1.0, 0.894710658329157, 1.0]
# Vertex 510 is removed. NMI&ECS: [0.9820184783885352, 1.0, 0.9602272727272727, 1.0]
# Vertex 140 is removed. NMI&ECS: [1.0, 1.0, 1.0, 1.0]
# Vertex 595 is removed. NMI&ECS: [0.9591050360302263, 1.0000000000000002, 0.8622354374550105, 1.0]
# Vertex 182 is removed. NMI&ECS: [0.9385055213231339, 0.9956043547192629, 0.8627719262265062, 0.9934203363807662]
# Vertex 575 is removed. NMI&ECS: [0.9488321351883229, 0.9955949230643875, 0.8502925897663451, 0.9934055173185607]
# Vertex 196 is removed. NMI&ECS: [0.9344607334879859, 0.9955856393843331, 0.8441247342740339, 0.9933906313531399]
# Vertex 637 is removed. NMI&ECS: [1.0, 0.9955756590740584, 1.0, 0.9933756780304095]
# Vertex 985 is removed. NMI&ECS: [0.9666113459511344, 0.9778960744983094, 0.9102930655725686, 0.9546266773418504]
# Vertex 861 is removed. NMI&ECS: [0.9435619350730111, 0.9778454277359168, 0.8719181158643515, 0.9545235561539909]
# Vertex 820 is removed. NMI&ECS: [0.94173407370901, 0.9955450763217917, 0.8678301704200541, 0.9933304093153553]
# Vertex 842 is removed. NMI&ECS: [0.9601357490717187, 0.9955346222887037, 0.8649476228847705, 0.993315181939363]
# Vertex 250 is removed. NMI&ECS: [0.9748390674152264, 0.9955241288514692, 0.9364527402621359, 0.9932998848728627]
# Vertex 335 is removed. NMI&ECS: [0.9255204260848975, 0.9489310192944838, 0.8487147776741781, 0.8685347470390218]
# Vertex 864 is removed. NMI&ECS: [0.8959058069768292, 0.9487635459851185, 0.8110678570331222, 0.8681065214593445]
# Vertex 449 is removed. NMI&ECS: [0.9002230309815403, 0.950876821682728, 0.8070958889114827, 0.8748594050656462]
# Vertex 145 is removed. NMI&ECS: [0.927971238084687, 0.9423915081640435, 0.8449193649137121, 0.8920937565236856]
# Vertex 930 is removed. NMI&ECS: [0.9215726787589958, 0.968437746404894, 0.8468201198919284, 0.9377248593177765]
# Vertex 744 is removed. NMI&ECS: [0.8980442370636386, 0.9589265362617511, 0.8040243434789356, 0.9299134745662719]
# Vertex 7 is removed. NMI&ECS: [0.8854855310192092, 0.9291336113807449, 0.7559783453039559, 0.8632801037925374]
# Vertex 378 is removed. NMI&ECS: [0.8989372727637519, 0.931378558858818, 0.7762147253050665, 0.8392935099664792]
# Vertex 803 is removed. NMI&ECS: [0.9032428419333703, 0.9195611113779377, 0.8165177324203192, 0.8253433525970472]
# Vertex 339 is removed. NMI&ECS: [0.8986334921860505, 0.9313469309643206, 0.8177212790672507, 0.8390905779211626]
# Vertex 604 is removed. NMI&ECS: [0.9022248008088143, 0.9317077663522427, 0.8202117478375411, 0.8401911801587801]
# Vertex 877 is removed. NMI&ECS: [0.9131741801880742, 0.9444822348456262, 0.8090832853904749, 0.8985097976368919]
# Vertex 322 is removed. NMI&ECS: [0.9075719806231649, 0.9378236254270509, 0.8063741326846166, 0.8453120044689812]
# Vertex 733 is removed. NMI&ECS: [0.9194051818204878, 0.9376343482683669, 0.8250055472301402, 0.8447876383824354]
# Vertex 668 is removed. NMI&ECS: [0.9118820454600559, 0.9374635201826952, 0.8328993257021025, 0.84426240467215]
# Vertex 888 is removed. NMI&ECS: [0.9244061445673675, 0.9151887816967031, 0.8535933833445959, 0.8230302472235614]
# Vertex 432 is removed. NMI&ECS: [0.889100621401578, 0.9536385790594413, 0.7744943918867386, 0.9121119181224352]
# Vertex 814 is removed. NMI&ECS: [0.9137644417632416, 0.9441102862269254, 0.8346243862430505, 0.8581432836941226]
# Vertex 203 is removed. NMI&ECS: [0.9055886013454787, 0.9547729670956074, 0.7933449211415206, 0.874172613187239]
# Vertex 688 is removed. NMI&ECS: [0.9241230599515007, 0.9552266694755246, 0.8495055631823467, 0.8760806453340761]
# Vertex 23 is removed. NMI&ECS: [0.8531460462329006, 0.9315749399311434, 0.7102224675829336, 0.8636781171503395]
# Vertex 105 is removed. NMI&ECS: [0.8685679760897519, 0.957432103878063, 0.7494683736451451, 0.9193924003776379]
# Vertex 226 is removed. NMI&ECS: [0.8819599866396928, 0.9545074657940106, 0.7665103297780818, 0.8732332178055862]
# Vertex 684 is removed. NMI&ECS: [0.9221276092915196, 0.9435518648839838, 0.857122100584297, 0.8567958089668616]
# Vertex 412 is removed. NMI&ECS: [0.935038796577912, 0.9400204697241786, 0.8685916403397762, 0.8602169731351069]
# Vertex 777 is removed. NMI&ECS: [0.9033589841930202, 0.9547022411685738, 0.8152917967458884, 0.8746780002882383]
# Vertex 621 is removed. NMI&ECS: [0.9127008887885959, 0.9304482587132563, 0.7911689685205922, 0.8611183725323797]
# Vertex 812 is removed. NMI&ECS: [0.9200080044478625, 0.9234807244872161, 0.8328090678013004, 0.8500024046299098]
# Vertex 753 is removed. NMI&ECS: [0.8976824449549692, 0.9282742197078835, 0.7827938450264931, 0.8636815285887183]
# Vertex 280 is removed. NMI&ECS: [0.8391826830638659, 0.9208794184184966, 0.697750754706712, 0.8108161696569093]
# Vertex 302 is removed. NMI&ECS: [0.8738857714249295, 0.9278464212385554, 0.7350396088122828, 0.8627423107379378]
# Vertex 912 is removed. NMI&ECS: [0.9398017072105107, 0.9074725210326833, 0.8634910468204983, 0.8195234142450332]
# Vertex 599 is removed. NMI&ECS: [0.8856377276713232, 0.9379048949195165, 0.7717839031675429, 0.877913758191295]
# Vertex 594 is removed. NMI&ECS: [0.8882313987569599, 0.943548838029688, 0.761155937379333, 0.858212968569505]
# Vertex 274 is removed. NMI&ECS: [0.8640691213853445, 0.9433303538957158, 0.7350818851493521, 0.8576954976518755]
# Vertex 536 is removed. NMI&ECS: [0.8482328767607636, 0.9494606777530946, 0.7275982864705998, 0.8655270091167527]
# Vertex 415 is removed. NMI&ECS: [0.9055980314060483, 0.9540803873705789, 0.8183209648338385, 0.8733262108262108]
# Vertex 759 is removed. NMI&ECS: [0.88029987144659, 0.9538983780371815, 0.7807012670524976, 0.8728587798698498]
# Vertex 899 is removed. NMI&ECS: [0.8769670731154633, 0.9205477758076532, 0.7660911964729685, 0.8192229083457153]
# Vertex 453 is removed. NMI&ECS: [0.9525561893834048, 0.943558378836286, 0.9078329396109168, 0.8588588603654148]
# Vertex 111 is removed. NMI&ECS: [0.914130268683776, 0.9458008115835426, 0.8157479771810567, 0.8589948870442952]
# Vertex 948 is removed. NMI&ECS: [0.851749564245267, 0.9196162727506552, 0.6959516985785668, 0.8071212502977696]
# Vertex 648 is removed. NMI&ECS: [0.9301202001516509, 0.9482361521342215, 0.8708485846841605, 0.8626151629781394]
# Vertex 543 is removed. NMI&ECS: [0.9260033822698782, 0.9129692672977928, 0.8205425282651532, 0.7988755058045883]
# Vertex 611 is removed. NMI&ECS: [0.8921067679244863, 0.9483801273693604, 0.7977370327664944, 0.863149807833716]
# Vertex 931 is removed. NMI&ECS: [0.8983943329100322, 0.949474952514287, 0.7877828629365647, 0.8660901297895259]
# Vertex 132 is removed. NMI&ECS: [0.9253290240935524, 0.9379040581414428, 0.8660903438367877, 0.8485531290874802]
# Vertex 670 is removed. NMI&ECS: [0.8734222290632815, 0.9343135930205888, 0.7345433923994398, 0.8422713585548836]
# Vertex 399 is removed. NMI&ECS: [0.8896305095275014, 0.9357712401626629, 0.800449424673779, 0.8393761359348404]
# Vertex 894 is removed. NMI&ECS: [0.880338399417422, 0.9338238787253295, 0.7694020436585869, 0.8410588767731626]
# Vertex 987 is removed. NMI&ECS: [0.8788867832483894, 0.9443370144639194, 0.7824623809343804, 0.8556671020624509]
# Vertex 285 is removed. NMI&ECS: [0.8754746686833949, 0.9460088977739419, 0.7310661254987636, 0.8603132146711914]
# Vertex 620 is removed. NMI&ECS: [0.9051247932799986, 0.9412453954900792, 0.8085901709091496, 0.8583124427655677]
# Vertex 883 is removed. NMI&ECS: [0.9247004841109796, 0.9442583140770454, 0.8248366013071896, 0.8556186166774401]
# Vertex 271 is removed. NMI&ECS: [0.9459908385901652, 0.9246186306891929, 0.8820326654972324, 0.8587588744882296]
# Vertex 468 is removed. NMI&ECS: [0.8707248053770605, 0.9391882549192481, 0.7386276917027795, 0.8459924133837178]
# Vertex 207 is removed. NMI&ECS: [0.9106415725860474, 0.9456486634214639, 0.8406871374151389, 0.8601342440628154]
# Vertex 924 is removed. NMI&ECS: [0.9482042272029056, 0.9374346028352958, 0.8699837438295371, 0.8410698470459426]
# Vertex 795 is removed. NMI&ECS: [0.8846169588068471, 0.9300291694006012, 0.7856249051761247, 0.8432483516483517]
# Vertex 730 is removed. NMI&ECS: [0.9136160593695472, 0.9009579866165328, 0.8261007787926823, 0.7897886399855975]
# Vertex 662 is removed. NMI&ECS: [0.8644482995169928, 0.9287440917401462, 0.7251997460300804, 0.8399541813591049]
# Vertex 553 is removed. NMI&ECS: [0.9520398129354524, 0.9489690086296215, 0.8960348693142216, 0.8731572230262395]
# Vertex 973 is removed. NMI&ECS: [0.9145100904787374, 0.9452329102876356, 0.8002171155447099, 0.8590655618094644]
# Vertex 745 is removed. NMI&ECS: [0.9215836950475484, 0.9265139027717848, 0.8468012531686002, 0.862658953236467]
# Vertex 109 is removed. NMI&ECS: [0.8791017814687426, 0.9434856033164576, 0.7417448668938541, 0.8543908711025395]
# Vertex 492 is removed. NMI&ECS: [0.9081344672514324, 0.9083265392585661, 0.8167866490111357, 0.7674615430493048]
# Vertex 850 is removed. NMI&ECS: [0.8737476667773054, 0.9267767461352341, 0.7534948891874278, 0.8362694749256014]
# Vertex 481 is removed. NMI&ECS: [0.8747160096813508, 0.9463681332153946, 0.7570863417537813, 0.8642667607678985]
# Vertex 88 is removed. NMI&ECS: [0.9289277074461249, 0.9112622279286822, 0.8509035800831779, 0.8111476153240861]
# Vertex 757 is removed. NMI&ECS: [0.8969755390953196, 0.9083467277060105, 0.7990637256746043, 0.7697824411959394]
# Vertex 977 is removed. NMI&ECS: [0.9080549189481475, 0.9457570674087344, 0.829930212684231, 0.862562840385421]
# Vertex 262 is removed. NMI&ECS: [0.9021528071407332, 0.9332180819854612, 0.7913409189470246, 0.8435161367961068]
# Vertex 467 is removed. 763 vertices are removed. G is now disconnected!!

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = scores

# Extract x and y coordinates for each curve
x = range(len(data))  # Use the length of data as x-coordinates
y = list(zip(*data))  # Transpose the data matrix

# Compute rolling mean with a window size of 5
y_smoothed = [pd.Series(curve).rolling(window=20, min_periods=1).mean() for curve in y]

# Create subplots
fig, axs = plt.subplots(len(y_smoothed), 1, sharex=True)

# Plot each curve with smoothed data on a separate subplot
for i, curve in enumerate(y_smoothed):
    axs[i].plot(x, curve)
    axs[i].set_ylabel(f'Curve {i+1}')

# Add x-axis label to the last subplot
axs[-1].set_xlabel('Index')

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()
