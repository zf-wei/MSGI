# %%
import networkx as nx

from networkx.generators.community import LFR_benchmark_graph

import matplotlib
import matplotlib.pyplot as plt

from pyspark.ml.clustering import KMeans

from pyspark.sql import SparkSession
from pyspark.ml.linalg import Vectors


from sklearn.metrics import normalized_mutual_info_score
from clusim.clustering import Clustering
import clusim.sim as sim

# %%
n = 1000
tau1 = 2  # Power-law exponent for the degree distribution
tau2 = 1.1 # Power-law exponent for the community size distribution 
            #S hould be >1
mu = 0.1 # Mixing parameter

G = LFR_benchmark_graph(
    n, tau1, tau2, mu, average_degree=25, max_degree=100, min_community=50, max_community=100, 
    seed=2
)

# %%
G = nx.Graph(G) # Remove multi-edges

selfloop_edges = list(nx.selfloop_edges(G)) # a list of self loops

G.remove_edges_from(selfloop_edges) # Remove self-loops

# %%
# Get the intrinsic community structure as a list
intrinsic_communities = {frozenset(G.nodes[v]["community"]) for v in G}
intrinsic_membership = {}
for node in range(G.number_of_nodes()):
    for index, inner_set in enumerate(intrinsic_communities):
        if node in inner_set:
            intrinsic_membership[node] = index
            break

# %%
#import matplotlib
#import matplotlib.pyplot as plt

pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G,
                      pos,
                      #intrinsic_membership.keys(),
                      node_size=10,
                      cmap=matplotlib.colormaps.get_cmap('gist_rainbow'),
                      node_color=list(intrinsic_membership.values())
                      )
nx.draw_networkx_edges(G, pos, alpha=0.5)
plt.show()

# %%
intrinsic_clustering = Clustering(elm2clu_dict={i: [intrinsic_membership[i]] for i in intrinsic_membership.keys()})

# %%
import warnings

# Suppress UserWarning in the next cell
warnings.filterwarnings("ignore", category=UserWarning)

# %%
from ge import LINE
for D in range(15,990,5):
    model = LINE(G,embedding_size=D,order='first');
    model.train(batch_size=1024,epochs=50,verbose=0);# train model
    MNMF_embd = model.get_embeddings();# get embedding vectors

    MNMF_vec = [Vectors.dense(MNMF_embd[i]) for i in range(len(MNMF_embd))]
    MNMF_prep = SparkSession.builder.getOrCreate().\
                        createDataFrame([(vector,) for vector in MNMF_vec], ["embd"])

    euclid_kmeans = KMeans(k=14, featuresCol="embd")
    cosine_kmeans = KMeans(k=14, featuresCol="embd", distanceMeasure="cosine")
    MNMF_euclid_model = euclid_kmeans.fit(MNMF_prep)
    MNMF_cosine_model = cosine_kmeans.fit(MNMF_prep)

    # Add the cluster assignment to the DataFrame
    MNMF_euclid = MNMF_euclid_model.transform(MNMF_prep)
    MNMF_cosine = MNMF_cosine_model.transform(MNMF_prep)

    # Extract the cluster assignment and convert it to a list
    MNMF_euclid_membership = MNMF_euclid.select("prediction").rdd.flatMap(lambda x: x).collect()
    MNMF_cosine_membership = MNMF_cosine.select("prediction").rdd.flatMap(lambda x: x).collect()
    #print(max(MNMF_euclid_membership)+1, max(MNMF_cosine_membership)+1)

    # Calculate the NMI
    MNMF_euclid_nmi = normalized_mutual_info_score(list(MNMF_euclid_membership), list(intrinsic_membership.values()))
    MNMF_cosine_nmi = normalized_mutual_info_score(list(MNMF_cosine_membership), list(intrinsic_membership.values()))

    print(f"{D}-dimensional NMIs:", MNMF_euclid_nmi, MNMF_cosine_nmi)

    MNMF_euclid_clustering = Clustering(elm2clu_dict={i: [MNMF_euclid_membership[i]] for i in range(len(MNMF_euclid_membership))})
    MNMF_cosine_clustering = Clustering(elm2clu_dict={i: [MNMF_cosine_membership[i]] for i in range(len(MNMF_cosine_membership))})

    MNMF_euclid_similarity = sim.element_sim(intrinsic_clustering, MNMF_euclid_clustering, alpha=0.9)
    MNMF_cosine_similarity = sim.element_sim(intrinsic_clustering, MNMF_cosine_clustering, alpha=0.9)

    print(f"{D}-dimensional ECSim:", MNMF_euclid_similarity, MNMF_cosine_similarity)
# Out:
# 2023-06-16 14:41:12.030868: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-16 14:41:13.602071: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-16 14:41:17.040198: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38223 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:02:00.0, compute capability: 8.0
# 2023-06-16 14:41:17.041575: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 38223 MB memory:  -> device: 1, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:41:00.0, compute capability: 8.0
# 2023-06-16 14:41:17.329318: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/06/16 14:41:27 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/06/16 14:41:36 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 15-dimensional NMIs: 0.9527115530595663 0.9443148969694793
# 15-dimensional ECSim: 0.834723752884786 0.8003500221970108
# 2023-06-16 14:41:41.374446: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 20-dimensional NMIs: 0.9529146743830725 0.9771093437549475
# 20-dimensional ECSim: 0.8403847092540719 0.9183869547819128
# 2023-06-16 14:41:55.224169: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 25-dimensional NMIs: 0.939317217397386 0.9796409697333394
# 25-dimensional ECSim: 0.7940352581548693 0.9289141456978607
# 2023-06-16 14:42:09.010156: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 30-dimensional NMIs: 0.9595390197581816 0.9752335227514342
# 30-dimensional ECSim: 0.8613273068815449 0.9133704573934837
# 2023-06-16 14:42:23.376396: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 35-dimensional NMIs: 0.9006551811100688 0.8935721533731005
# 35-dimensional ECSim: 0.7392399712526283 0.6624149936399019
# 2023-06-16 14:42:37.699423: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 40-dimensional NMIs: 0.903744685318355 0.94322992661982
# 40-dimensional ECSim: 0.7487812103218147 0.8263397299194244
# 2023-06-16 14:42:51.246592: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 45-dimensional NMIs: 0.9543150399976515 0.8959076163487852
# 45-dimensional ECSim: 0.8376199835811943 0.7362580109000817
# 2023-06-16 14:43:05.524873: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 50-dimensional NMIs: 0.9533587471016594 0.913350964587665
# 50-dimensional ECSim: 0.8442111199328642 0.7006843216226182
# 2023-06-16 14:43:19.506394: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 55-dimensional NMIs: 0.929412402040921 0.9754890432346159
# 55-dimensional ECSim: 0.7872634675095119 0.9136630055342698
# 2023-06-16 14:43:32.809184: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 60-dimensional NMIs: 0.9769621707333923 0.914342338200881
# 60-dimensional ECSim: 0.9194439102564101 0.7493725761641882
# 2023-06-16 14:43:47.037260: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 65-dimensional NMIs: 0.966824282526928 0.9583510365859804
# 65-dimensional ECSim: 0.8989589778575577 0.8550882947118241
# 2023-06-16 14:44:01.076587: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 70-dimensional NMIs: 0.913795597465393 0.9499637196311133
# 70-dimensional ECSim: 0.7478344116654171 0.8196698960406988
# 2023-06-16 14:44:14.924894: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 75-dimensional NMIs: 0.9377649762090089 0.9410222816347853
# 75-dimensional ECSim: 0.8273389869744243 0.7877497102544722
# 2023-06-16 14:44:28.223566: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 80-dimensional NMIs: 0.8977750366510722 0.9460809468684818
# 80-dimensional ECSim: 0.6969782715974762 0.8112758021371421
# 2023-06-16 14:44:41.966547: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 85-dimensional NMIs: 0.9312212409273224 0.9397192299712263
# 85-dimensional ECSim: 0.7838947116891004 0.7843991583329561
# 2023-06-16 14:44:56.102358: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 90-dimensional NMIs: 0.9087979986958576 0.9756485799816522
# 90-dimensional ECSim: 0.7191477843878942 0.9107008695652173
# 2023-06-16 14:45:09.561108: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 95-dimensional NMIs: 0.9349355671836206 0.951209718274014
# 95-dimensional ECSim: 0.796504704737491 0.8630408040664861
# 2023-06-16 14:45:22.362240: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 100-dimensional NMIs: 0.9507972707557247 0.9656034783546334
# 100-dimensional ECSim: 0.8361217453740244 0.8722641871165645
# 2023-06-16 14:45:36.240354: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 105-dimensional NMIs: 0.9479824734029979 0.9781108752657127
# 105-dimensional ECSim: 0.8558043139122427 0.9243319327731092
# 2023-06-16 14:45:50.396085: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 110-dimensional NMIs: 0.9423101949595855 0.9824276388655306
# 110-dimensional ECSim: 0.8025387646605691 0.9378522012578617
# 2023-06-16 14:46:03.262112: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 115-dimensional NMIs: 0.9019023077185209 0.9205452317973241
# 115-dimensional ECSim: 0.7110096787994988 0.7230004282011836
# 2023-06-16 14:46:16.356651: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 120-dimensional NMIs: 0.933958042458191 0.9461272288978687
# 120-dimensional ECSim: 0.7835659483154559 0.8295077441077441
# 2023-06-16 14:46:29.960716: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 125-dimensional NMIs: 0.9173018847892388 0.9597843416567174
# 125-dimensional ECSim: 0.757464013486727 0.8594793692318872
# 2023-06-16 14:46:43.650247: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 130-dimensional NMIs: 0.899215450757355 0.9764019798402038
# 130-dimensional ECSim: 0.6945705959164293 0.9173223706748886
# 2023-06-16 14:46:56.874037: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 135-dimensional NMIs: 0.9577470684851238 0.9756506758289714
# 135-dimensional ECSim: 0.8532059019832189 0.9111085120207927
# 2023-06-16 14:47:10.551271: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 140-dimensional NMIs: 0.9541038392366382 0.9707183123913392
# 140-dimensional ECSim: 0.8411453685103865 0.906053541343944
# 2023-06-16 14:47:24.692365: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 145-dimensional NMIs: 0.9594808272749262 0.9751524473837956
# 145-dimensional ECSim: 0.8667737318840579 0.9132637654742918
# 2023-06-16 14:47:38.343396: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 150-dimensional NMIs: 0.9135582208730038 0.9756506758289714
# 150-dimensional ECSim: 0.7487366492203156 0.9111085120207928
# 2023-06-16 14:47:51.632653: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 155-dimensional NMIs: 0.9535219386833663 0.9007300967844655
# 155-dimensional ECSim: 0.8661173799759424 0.7327608141027155
# 2023-06-16 14:48:05.115587: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 160-dimensional NMIs: 0.9217038886286045 0.9740615055070555
# 160-dimensional ECSim: 0.7782358250540025 0.9117973506168628
# 2023-06-16 14:48:18.304006: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 165-dimensional NMIs: 0.9509788670819693 0.9747511936767012
# 165-dimensional ECSim: 0.8594716051926078 0.9053998203054806
# 2023-06-16 14:48:31.514009: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 170-dimensional NMIs: 0.9222818849123281 0.9508299154791874
# 170-dimensional ECSim: 0.7775901829620764 0.8253301122357726
# 2023-06-16 14:48:45.782748: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 175-dimensional NMIs: 0.942982581317447 0.9107947580139121
# 175-dimensional ECSim: 0.805206441259379 0.7096053773387107
# 2023-06-16 14:48:59.772422: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 180-dimensional NMIs: 0.9492304130258311 0.9780422351436633
# 180-dimensional ECSim: 0.8358697603919377 0.9229784638841243
# 2023-06-16 14:49:12.847989: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 185-dimensional NMIs: 0.9533282277663518 0.9387425884374072
# 185-dimensional ECSim: 0.8384583695652172 0.8105731930706023
# 2023-06-16 14:49:26.578756: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 190-dimensional NMIs: 0.9796554935996507 0.9431848943243363
# 190-dimensional ECSim: 0.9298909120734907 0.828462872421696
# 2023-06-16 14:49:40.181912: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 195-dimensional NMIs: 0.9396977868464695 0.9787562345317046
# 195-dimensional ECSim: 0.8334306668433503 0.9259279588336192
# 2023-06-16 14:49:53.896917: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 200-dimensional NMIs: 0.9757246796178632 0.9469543414551345
# 200-dimensional ECSim: 0.9160904535864979 0.820000024896149
# 2023-06-16 14:50:07.962694: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 205-dimensional NMIs: 0.9530568275842225 0.9748994113348086
# 205-dimensional ECSim: 0.8708700973996927 0.9061855345911949
# 2023-06-16 14:50:21.937811: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 210-dimensional NMIs: 0.9580937722846601 0.9464750106609356
# 210-dimensional ECSim: 0.8610164198858465 0.8063197539302802
# 2023-06-16 14:50:36.224741: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 215-dimensional NMIs: 0.9207210178016888 0.9123526236253254
# 215-dimensional ECSim: 0.7697007843436404 0.7352613341226921
# 2023-06-16 14:50:50.227667: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 220-dimensional NMIs: 0.9241966193298092 0.9753430401373097
# 220-dimensional ECSim: 0.780011131359378 0.9114638447971781
# 2023-06-16 14:51:04.014208: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 225-dimensional NMIs: 0.9636288342926086 0.9372789207157275
# 225-dimensional ECSim: 0.8735352105707257 0.8121401824255476
# 2023-06-16 14:51:17.785391: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 230-dimensional NMIs: 0.9523581702587702 0.9742028482813098
# 230-dimensional ECSim: 0.8471981625935399 0.912228602552132
# 2023-06-16 14:51:31.424107: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 235-dimensional NMIs: 0.9348862155835083 0.9744563988286199
# 235-dimensional ECSim: 0.8051008362159982 0.908680808080808
# 2023-06-16 14:51:45.104053: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 240-dimensional NMIs: 0.9156434927600279 0.9425933888888554
# 240-dimensional ECSim: 0.7997669006130758 0.8228268406575833
# 2023-06-16 14:51:58.852555: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 245-dimensional NMIs: 0.9460553072575617 0.9795936961248819
# 245-dimensional ECSim: 0.8357122924448516 0.9293272727272727
# 2023-06-16 14:52:12.654419: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 250-dimensional NMIs: 0.9160724622157466 0.8792879449199281
# 250-dimensional ECSim: 0.7884492641936607 0.6618905502749096
# 2023-06-16 14:52:27.590481: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 255-dimensional NMIs: 0.9497009699580969 0.9354515954847706
# 255-dimensional ECSim: 0.8591542645846217 0.8069325490465546
# 2023-06-16 14:52:41.790600: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 260-dimensional NMIs: 0.9494120168044818 0.9769058481008305
# 260-dimensional ECSim: 0.8449073342116821 0.9174244359301831
# 2023-06-16 14:52:56.351299: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 265-dimensional NMIs: 0.9233180530447337 0.9388457918899048
# 265-dimensional ECSim: 0.7825618787077121 0.8187904130678769
# 2023-06-16 14:53:10.342764: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 270-dimensional NMIs: 0.9013825192767687 0.8997711858586847
# 270-dimensional ECSim: 0.7085969901882663 0.6868271124159391
# 2023-06-16 14:53:24.722384: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 275-dimensional NMIs: 0.9427890180286601 0.9730431728820667
# 275-dimensional ECSim: 0.8393389888234608 0.8987031857031856
# 2023-06-16 14:53:38.661855: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 280-dimensional NMIs: 0.8236202612494339 0.919903169376375
# 280-dimensional ECSim: 0.6392316829079673 0.7307875682685809
# 2023-06-16 14:53:53.816144: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 285-dimensional NMIs: 0.9283052327080406 0.9332512581758516
# 285-dimensional ECSim: 0.7862921913650168 0.7783965861051287
# 2023-06-16 14:54:08.463001: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 290-dimensional NMIs: 0.9113715005241718 0.9429259184266012
# 290-dimensional ECSim: 0.7856220094065292 0.8253184867096857
# 2023-06-16 14:54:23.294751: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 295-dimensional NMIs: 0.951798110510255 0.9457207047359537
# 295-dimensional ECSim: 0.87199487482632 0.822084822076979
# 2023-06-16 14:54:37.532729: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 300-dimensional NMIs: 0.964130597217162 0.946797730972656
# 300-dimensional ECSim: 0.8758075787401574 0.8063340644540644
# 2023-06-16 14:54:52.527199: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 305-dimensional NMIs: 0.9573170514985682 0.936699412318608
# 305-dimensional ECSim: 0.8513307442067735 0.8009170200941035
# 2023-06-16 14:55:06.565370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
